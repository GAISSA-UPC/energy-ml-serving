# %%
pwd
# Out:
# 'D:\\GAISSA\\energy-repo\\last_repo\\gpu_june_phi2_01'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
device = 'gpu'
#new_directory = f"D:/GAISSA/energy-repo/last_repo/june_{device}/" # change
new_directory = f"D:/GAISSA/energy-repo/last_repo/june_{device}_test/" # change
new_results = f"D:/GAISSA/energy-repo/last_repo/{device}_june_phi2_01/" # change
os.chdir(new_directory)

# %%
results_dir = 'results_10/' #change
ENERGIBRIDGE_SAVE_CSV = 'energibridge_dataset.csv'
NVIDIA_SAVE_CSV = 'nvidia-smi_dataset.csv'
WATTMETER_SAVE_CSV = 'wattmeter_dataset.csv'

# %%
pwd
# Out:
# 'D:\\GAISSA\\energy-repo\\last_repo\\june_gpu_test'

# %%
processed_dir = new_directory + results_dir +"processed/"
try:
    os.mkdir(processed_dir)
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'D:/GAISSA/energy-repo/last_repo/june_gpu_test/results_10/processed/'

# %%
#energibridge_df = pd.read_csv(results_dir + ENERGIBRIDGE_SAVE_CSV, )
#nvidia_df = pd.read_csv(results_dir + NVIDIA_SAVE_CSV, )
#wattmeter_df = pd.read_csv(results_dir + WATTMETER_SAVE_CSV, )
#dfs = [energibridge_df,nvidia_df,wattmeter_df]

# %%
os.chdir(new_directory)
runall_df = pd.read_csv(results_dir + 'runall_timestamps.csv', )
load_times = pd.read_csv(results_dir + 'load_times.csv', )

# %%
results_dir
# Out:
# 'results_10/'

# %%
os.chdir(new_results)

runall_df_new = pd.read_csv(results_dir + 'runall_timestamps.csv', )
load_times_new = pd.read_csv(results_dir + 'load_times.csv', )

# %%
runall_df
# Out:
#               timestamp      runtime             model
# 0   2024-06-23 16:46:53            -              IDLE
# 1   2024-06-23 16:51:54        torch             START
# 2   2024-06-23 16:55:08        torch        pythia1-4b
# 3   2024-06-23 16:58:20        torch         tinyllama
# 4   2024-06-23 16:59:56        torch  codeparrot-small
# 5   2024-06-23 17:03:08        torch       pythia-410m
# 6   2024-06-23 17:07:23        torch              phi2
# 7   2024-06-23 17:07:24         onnx             START
# 8   2024-06-23 17:16:29         onnx        pythia1-4b
# 9   2024-06-23 17:23:25         onnx         tinyllama
# 10  2024-06-23 17:26:40         onnx  codeparrot-small
# 11  2024-06-23 17:34:13         onnx       pythia-410m
# 12  2024-06-23 17:41:57         onnx              phi2
# 13  2024-06-23 17:41:58  torchscript             START
# 14  2024-06-23 17:43:41  torchscript        pythia1-4b
# 15  2024-06-23 17:45:30  torchscript         tinyllama
# 16  2024-06-23 17:47:07  torchscript  codeparrot-small
# 17  2024-06-23 17:48:47  torchscript       pythia-410m
# 18  2024-06-23 17:50:37  torchscript              phi2
# 19  2024-06-23 17:50:37            -            FINISH

# %%
#runall_df.loc[runall_df['model'] == 'phi2', 'model'] = 'error_phi2'
#runall_df

# %%
def add_new_model_times(old,new, column_name, model):
    # change old -> phi2 to error_phi2
    # add at the end other df
    try:
        old.loc[old[column_name] == model, column_name] = f'error_{model}'
        old = old[old[column_name] != 'FINISH']
        
        new = new[new[column_name] != 'IDLE']
    
    except:
        print("check dfs")
    
    return pd.concat([old, new], ignore_index=True)#ignore_index=True

# %%
runall_df = add_new_model_times(runall_df, runall_df_new, 'model', 'phi2')
runall_df
# Out:
#               timestamp      runtime             model
# 0   2024-06-23 16:46:53            -              IDLE
# 1   2024-06-23 16:51:54        torch             START
# 2   2024-06-23 16:55:08        torch        pythia1-4b
# 3   2024-06-23 16:58:20        torch         tinyllama
# 4   2024-06-23 16:59:56        torch  codeparrot-small
# 5   2024-06-23 17:03:08        torch       pythia-410m
# 6   2024-06-23 17:07:23        torch        error_phi2
# 7   2024-06-23 17:07:24         onnx             START
# 8   2024-06-23 17:16:29         onnx        pythia1-4b
# 9   2024-06-23 17:23:25         onnx         tinyllama
# 10  2024-06-23 17:26:40         onnx  codeparrot-small
# 11  2024-06-23 17:34:13         onnx       pythia-410m
# 12  2024-06-23 17:41:57         onnx        error_phi2
# 13  2024-06-23 17:41:58  torchscript             START
# 14  2024-06-23 17:43:41  torchscript        pythia1-4b
# 15  2024-06-23 17:45:30  torchscript         tinyllama
# 16  2024-06-23 17:47:07  torchscript  codeparrot-small
# 17  2024-06-23 17:48:47  torchscript       pythia-410m
# 18  2024-06-23 17:50:37  torchscript        error_phi2
# 19  2024-06-30 15:30:42         onnx             START
# 20  2024-06-30 15:44:10         onnx              phi2
# 21  2024-06-30 15:44:10        torch             START
# 22  2024-06-30 15:48:27        torch              phi2
# 23  2024-06-30 15:48:28  torchscript             START
# 24  2024-06-30 15:50:16  torchscript              phi2
# 25  2024-06-30 15:50:17            -            FINISH

# %%
runall_df.iloc[0]
# Out:
# timestamp    2024-06-23 16:46:53
# runtime                        -
# model                       IDLE
# Name: 0, dtype: object

# %%
#print(load_times)

# %%
load_times
# Out:
#                     start_time                    end_time       engine  \
# 0   2024-06-23 16:51:54.862842  2024-06-23 16:51:56.727207        torch
# 1   2024-06-23 16:55:09.145398  2024-06-23 16:55:10.507139        torch
# 2   2024-06-23 16:58:21.094631  2024-06-23 16:58:21.283208        torch
# 3   2024-06-23 16:59:57.418073  2024-06-23 16:59:58.011860        torch
# 4   2024-06-23 17:03:08.951462  2024-06-23 17:03:12.407967        torch
# 5   2024-06-23 17:07:25.293045  2024-06-23 17:07:32.508933         onnx
# 6   2024-06-23 17:16:30.896322  2024-06-23 17:16:36.242586         onnx
# 7   2024-06-23 17:23:26.315983  2024-06-23 17:23:27.724942         onnx
# 8   2024-06-23 17:26:40.725283  2024-06-23 17:26:44.458125         onnx
# 9   2024-06-23 17:41:59.307629  2024-06-23 17:42:03.551629  torchscript
# 10  2024-06-23 17:43:42.776044  2024-06-23 17:43:46.073415  torchscript
# 11  2024-06-23 17:45:31.582783  2024-06-23 17:45:32.008281  torchscript
# 12  2024-06-23 17:47:08.203822  2024-06-23 17:47:09.276123  torchscript
# 13  2024-06-23 17:48:47.921375  2024-06-23 17:48:55.811190  torchscript
#
#           model_name
# 0         pythia1-4b
# 1          tinyllama
# 2   codeparrot-small
# 3        pythia-410m
# 4               phi2
# 5         pythia1-4b
# 6          tinyllama
# 7   codeparrot-small
# 8        pythia-410m
# 9         pythia1-4b
# 10         tinyllama
# 11  codeparrot-small
# 12       pythia-410m
# 13              phi2

# %%
load_times_new
# Out:
#                    start_time                    end_time       engine  \
# 0  2024-06-30 15:30:42.943662  2024-06-30 15:30:55.897983         onnx
# 1  2024-06-30 15:44:11.503720  2024-06-30 15:44:15.052154        torch
# 2  2024-06-30 15:48:28.578192  2024-06-30 15:48:34.885348  torchscript
#
#   model_name
# 0       phi2
# 1       phi2
# 2       phi2

# %%
load_times = add_new_model_times(load_times, load_times_new, 'model_name','phi2')

# %%
# transform start_time, end_time to start_end, time

# Define a function to transform the dataframe
def transform_dataframe(df):
    # Convert start_time and end_time columns to datetime
    df['start_time'] = pd.to_datetime(df['start_time'])
    df['end_time'] = pd.to_datetime(df['end_time'])
    
    # Melt the DataFrame to have separate rows for start and end times
    melted_df = df.melt(id_vars=['engine', 'model_name'], value_vars=['start_time', 'end_time'], var_name='start_end')
    
    # Rename the 'value' column to 'time'
    melted_df.rename(columns={'value': 'time'}, inplace=True)
    
    # Convert start_end column to indicate 1 for start_time and 0 for end_time
    melted_df['start_end'] = melted_df['start_end'].apply(lambda x: 1 if x == 'start_time' else 0)
    
    # Sort the DataFrame by time
    melted_df.sort_values(by='time', inplace=True)
    
    # Reset index
    melted_df.reset_index(drop=True, inplace=True)
    
    return melted_df.copy()

# from two columns to two rows with different time
# Apply the transformation
transformed_df = transform_dataframe(load_times)

# Display the transformed DataFrame
print(transformed_df)
# Out:
#          engine        model_name  start_end                       time
# 0         torch        pythia1-4b          1 2024-06-23 16:51:54.862842
# 1         torch        pythia1-4b          0 2024-06-23 16:51:56.727207
# 2         torch         tinyllama          1 2024-06-23 16:55:09.145398
# 3         torch         tinyllama          0 2024-06-23 16:55:10.507139
# 4         torch  codeparrot-small          1 2024-06-23 16:58:21.094631
# 5         torch  codeparrot-small          0 2024-06-23 16:58:21.283208
# 6         torch       pythia-410m          1 2024-06-23 16:59:57.418073
# 7         torch       pythia-410m          0 2024-06-23 16:59:58.011860
# 8         torch        error_phi2          1 2024-06-23 17:03:08.951462
# 9         torch        error_phi2          0 2024-06-23 17:03:12.407967
# 10         onnx        pythia1-4b          1 2024-06-23 17:07:25.293045
# 11         onnx        pythia1-4b          0 2024-06-23 17:07:32.508933
# 12         onnx         tinyllama          1 2024-06-23 17:16:30.896322
# 13         onnx         tinyllama          0 2024-06-23 17:16:36.242586
# 14         onnx  codeparrot-small          1 2024-06-23 17:23:26.315983
# 15         onnx  codeparrot-small          0 2024-06-23 17:23:27.724942
# 16         onnx       pythia-410m          1 2024-06-23 17:26:40.725283
# 17         onnx       pythia-410m          0 2024-06-23 17:26:44.458125
# 18  torchscript        pythia1-4b          1 2024-06-23 17:41:59.307629
# 19  torchscript        pythia1-4b          0 2024-06-23 17:42:03.551629
# 20  torchscript         tinyllama          1 2024-06-23 17:43:42.776044
# 21  torchscript         tinyllama          0 2024-06-23 17:43:46.073415
# 22  torchscript  codeparrot-small          1 2024-06-23 17:45:31.582783
# 23  torchscript  codeparrot-small          0 2024-06-23 17:45:32.008281
# 24  torchscript       pythia-410m          1 2024-06-23 17:47:08.203822
# 25  torchscript       pythia-410m          0 2024-06-23 17:47:09.276123
# 26  torchscript        error_phi2          1 2024-06-23 17:48:47.921375
# 27  torchscript        error_phi2          0 2024-06-23 17:48:55.811190
# 28         onnx              phi2          1 2024-06-30 15:30:42.943662
# 29         onnx              phi2          0 2024-06-30 15:30:55.897983
# 30        torch              phi2          1 2024-06-30 15:44:11.503720
# 31        torch              phi2          0 2024-06-30 15:44:15.052154
# 32  torchscript              phi2          1 2024-06-30 15:48:28.578192
# 33  torchscript              phi2          0 2024-06-30 15:48:34.885348

# %%
transform_dataframe(load_times_new)
# Out:
#         engine model_name  start_end                       time
# 0         onnx       phi2          1 2024-06-30 15:30:42.943662
# 1         onnx       phi2          0 2024-06-30 15:30:55.897983
# 2        torch       phi2          1 2024-06-30 15:44:11.503720
# 3        torch       phi2          0 2024-06-30 15:44:15.052154
# 4  torchscript       phi2          1 2024-06-30 15:48:28.578192
# 5  torchscript       phi2          0 2024-06-30 15:48:34.885348

# %%
# add source file column 
load_times = transformed_df
load_times['file'] = 'load_times'
load_times.head()
# Out:
#   engine        model_name  start_end                       time        file
# 0  torch        pythia1-4b          1 2024-06-23 16:51:54.862842  load_times
# 1  torch        pythia1-4b          0 2024-06-23 16:51:56.727207  load_times
# 2  torch         tinyllama          1 2024-06-23 16:55:09.145398  load_times
# 3  torch         tinyllama          0 2024-06-23 16:55:10.507139  load_times
# 4  torch  codeparrot-small          1 2024-06-23 16:58:21.094631  load_times

# %%
runall_df['file'] = 'runall'
runall_df
# Out:
#               timestamp      runtime             model    file
# 0   2024-06-23 16:46:53            -              IDLE  runall
# 1   2024-06-23 16:51:54        torch             START  runall
# 2   2024-06-23 16:55:08        torch        pythia1-4b  runall
# 3   2024-06-23 16:58:20        torch         tinyllama  runall
# 4   2024-06-23 16:59:56        torch  codeparrot-small  runall
# 5   2024-06-23 17:03:08        torch       pythia-410m  runall
# 6   2024-06-23 17:07:23        torch        error_phi2  runall
# 7   2024-06-23 17:07:24         onnx             START  runall
# 8   2024-06-23 17:16:29         onnx        pythia1-4b  runall
# 9   2024-06-23 17:23:25         onnx         tinyllama  runall
# 10  2024-06-23 17:26:40         onnx  codeparrot-small  runall
# 11  2024-06-23 17:34:13         onnx       pythia-410m  runall
# 12  2024-06-23 17:41:57         onnx        error_phi2  runall
# 13  2024-06-23 17:41:58  torchscript             START  runall
# 14  2024-06-23 17:43:41  torchscript        pythia1-4b  runall
# 15  2024-06-23 17:45:30  torchscript         tinyllama  runall
# 16  2024-06-23 17:47:07  torchscript  codeparrot-small  runall
# 17  2024-06-23 17:48:47  torchscript       pythia-410m  runall
# 18  2024-06-23 17:50:37  torchscript        error_phi2  runall
# 19  2024-06-30 15:30:42         onnx             START  runall
# 20  2024-06-30 15:44:10         onnx              phi2  runall
# 21  2024-06-30 15:44:10        torch             START  runall
# 22  2024-06-30 15:48:27        torch              phi2  runall
# 23  2024-06-30 15:48:28  torchscript             START  runall
# 24  2024-06-30 15:50:16  torchscript              phi2  runall
# 25  2024-06-30 15:50:17            -            FINISH  runall

# %%
load_times.head()
# Out:
#   engine        model_name  start_end                       time        file
# 0  torch        pythia1-4b          1 2024-06-23 16:51:54.862842  load_times
# 1  torch        pythia1-4b          0 2024-06-23 16:51:56.727207  load_times
# 2  torch         tinyllama          1 2024-06-23 16:55:09.145398  load_times
# 3  torch         tinyllama          0 2024-06-23 16:55:10.507139  load_times
# 4  torch  codeparrot-small          1 2024-06-23 16:58:21.094631  load_times

# %%
# Concatenate (runall and load times) and sort (by time)
#df1 = runall_df
#df2 = load_times
# Convert 'timestamp' and 'time' columns to datetime
runall_df['time'] = pd.to_datetime(runall_df['timestamp'])
load_times['time'] = pd.to_datetime(load_times['time'])

general_df = pd.concat([runall_df, load_times,], ignore_index=True)
general_df = general_df.sort_values(by='time')

general_df
# Out:
#               timestamp      runtime             model        file  \
# 0   2024-06-23 16:46:53            -              IDLE      runall
# 1   2024-06-23 16:51:54        torch             START      runall
# 26                  NaN          NaN               NaN  load_times
# 27                  NaN          NaN               NaN  load_times
# 2   2024-06-23 16:55:08        torch        pythia1-4b      runall
# 28                  NaN          NaN               NaN  load_times
# 29                  NaN          NaN               NaN  load_times
# 3   2024-06-23 16:58:20        torch         tinyllama      runall
# 30                  NaN          NaN               NaN  load_times
# 31                  NaN          NaN               NaN  load_times
# 4   2024-06-23 16:59:56        torch  codeparrot-small      runall
# 32                  NaN          NaN               NaN  load_times
# 33                  NaN          NaN               NaN  load_times
# 5   2024-06-23 17:03:08        torch       pythia-410m      runall
# 34                  NaN          NaN               NaN  load_times
# 35                  NaN          NaN               NaN  load_times
# 6   2024-06-23 17:07:23        torch        error_phi2      runall
# 7   2024-06-23 17:07:24         onnx             START      runall
# 36                  NaN          NaN               NaN  load_times
# 37                  NaN          NaN               NaN  load_times
# 8   2024-06-23 17:16:29         onnx        pythia1-4b      runall
# 38                  NaN          NaN               NaN  load_times
# 39                  NaN          NaN               NaN  load_times
# 9   2024-06-23 17:23:25         onnx         tinyllama      runall
# 40                  NaN          NaN               NaN  load_times
# 41                  NaN          NaN               NaN  load_times
# 10  2024-06-23 17:26:40         onnx  codeparrot-small      runall
# 42                  NaN          NaN               NaN  load_times
# 43                  NaN          NaN               NaN  load_times
# 11  2024-06-23 17:34:13         onnx       pythia-410m      runall
# 12  2024-06-23 17:41:57         onnx        error_phi2      runall
# 13  2024-06-23 17:41:58  torchscript             START      runall
# 44                  NaN          NaN               NaN  load_times
# 45                  NaN          NaN               NaN  load_times
# 14  2024-06-23 17:43:41  torchscript        pythia1-4b      runall
# 46                  NaN          NaN               NaN  load_times
# 47                  NaN          NaN               NaN  load_times
# 15  2024-06-23 17:45:30  torchscript         tinyllama      runall
# 48                  NaN          NaN               NaN  load_times
# 49                  NaN          NaN               NaN  load_times
# 16  2024-06-23 17:47:07  torchscript  codeparrot-small      runall
# 50                  NaN          NaN               NaN  load_times
# 51                  NaN          NaN               NaN  load_times
# 17  2024-06-23 17:48:47  torchscript       pythia-410m      runall
# 52                  NaN          NaN               NaN  load_times
# 53                  NaN          NaN               NaN  load_times
# 18  2024-06-23 17:50:37  torchscript        error_phi2      runall
# 19  2024-06-30 15:30:42         onnx             START      runall
# 54                  NaN          NaN               NaN  load_times
# 55                  NaN          NaN               NaN  load_times
# 21  2024-06-30 15:44:10        torch             START      runall
# 20  2024-06-30 15:44:10         onnx              phi2      runall
# 56                  NaN          NaN               NaN  load_times
# 57                  NaN          NaN               NaN  load_times
# 22  2024-06-30 15:48:27        torch              phi2      runall
# 23  2024-06-30 15:48:28  torchscript             START      runall
# 58                  NaN          NaN               NaN  load_times
# 59                  NaN          NaN               NaN  load_times
# 24  2024-06-30 15:50:16  torchscript              phi2      runall
# 25  2024-06-30 15:50:17            -            FINISH      runall
#
#                          time       engine        model_name  start_end
# 0  2024-06-23 16:46:53.000000          NaN               NaN        NaN
# 1  2024-06-23 16:51:54.000000          NaN               NaN        NaN
# 26 2024-06-23 16:51:54.862842        torch        pythia1-4b        1.0
# 27 2024-06-23 16:51:56.727207        torch        pythia1-4b        0.0
# 2  2024-06-23 16:55:08.000000          NaN               NaN        NaN
# 28 2024-06-23 16:55:09.145398        torch         tinyllama        1.0
# 29 2024-06-23 16:55:10.507139        torch         tinyllama        0.0
# 3  2024-06-23 16:58:20.000000          NaN               NaN        NaN
# 30 2024-06-23 16:58:21.094631        torch  codeparrot-small        1.0
# 31 2024-06-23 16:58:21.283208        torch  codeparrot-small        0.0
# 4  2024-06-23 16:59:56.000000          NaN               NaN        NaN
# 32 2024-06-23 16:59:57.418073        torch       pythia-410m        1.0
# 33 2024-06-23 16:59:58.011860        torch       pythia-410m        0.0
# 5  2024-06-23 17:03:08.000000          NaN               NaN        NaN
# 34 2024-06-23 17:03:08.951462        torch        error_phi2        1.0
# 35 2024-06-23 17:03:12.407967        torch        error_phi2        0.0
# 6  2024-06-23 17:07:23.000000          NaN               NaN        NaN
# 7  2024-06-23 17:07:24.000000          NaN               NaN        NaN
# 36 2024-06-23 17:07:25.293045         onnx        pythia1-4b        1.0
# 37 2024-06-23 17:07:32.508933         onnx        pythia1-4b        0.0
# 8  2024-06-23 17:16:29.000000          NaN               NaN        NaN
# 38 2024-06-23 17:16:30.896322         onnx         tinyllama        1.0
# 39 2024-06-23 17:16:36.242586         onnx         tinyllama        0.0
# 9  2024-06-23 17:23:25.000000          NaN               NaN        NaN
# 40 2024-06-23 17:23:26.315983         onnx  codeparrot-small        1.0
# 41 2024-06-23 17:23:27.724942         onnx  codeparrot-small        0.0
# 10 2024-06-23 17:26:40.000000          NaN               NaN        NaN
# 42 2024-06-23 17:26:40.725283         onnx       pythia-410m        1.0
# 43 2024-06-23 17:26:44.458125         onnx       pythia-410m        0.0
# 11 2024-06-23 17:34:13.000000          NaN               NaN        NaN
# 12 2024-06-23 17:41:57.000000          NaN               NaN        NaN
# 13 2024-06-23 17:41:58.000000          NaN               NaN        NaN
# 44 2024-06-23 17:41:59.307629  torchscript        pythia1-4b        1.0
# 45 2024-06-23 17:42:03.551629  torchscript        pythia1-4b        0.0
# 14 2024-06-23 17:43:41.000000          NaN               NaN        NaN
# 46 2024-06-23 17:43:42.776044  torchscript         tinyllama        1.0
# 47 2024-06-23 17:43:46.073415  torchscript         tinyllama        0.0
# 15 2024-06-23 17:45:30.000000          NaN               NaN        NaN
# 48 2024-06-23 17:45:31.582783  torchscript  codeparrot-small        1.0
# 49 2024-06-23 17:45:32.008281  torchscript  codeparrot-small        0.0
# 16 2024-06-23 17:47:07.000000          NaN               NaN        NaN
# 50 2024-06-23 17:47:08.203822  torchscript       pythia-410m        1.0
# 51 2024-06-23 17:47:09.276123  torchscript       pythia-410m        0.0
# 17 2024-06-23 17:48:47.000000          NaN               NaN        NaN
# 52 2024-06-23 17:48:47.921375  torchscript        error_phi2        1.0
# 53 2024-06-23 17:48:55.811190  torchscript        error_phi2        0.0
# 18 2024-06-23 17:50:37.000000          NaN               NaN        NaN
# 19 2024-06-30 15:30:42.000000          NaN               NaN        NaN
# 54 2024-06-30 15:30:42.943662         onnx              phi2        1.0
# 55 2024-06-30 15:30:55.897983         onnx              phi2        0.0
# 21 2024-06-30 15:44:10.000000          NaN               NaN        NaN
# 20 2024-06-30 15:44:10.000000          NaN               NaN        NaN
# 56 2024-06-30 15:44:11.503720        torch              phi2        1.0
# 57 2024-06-30 15:44:15.052154        torch              phi2        0.0
# 22 2024-06-30 15:48:27.000000          NaN               NaN        NaN
# 23 2024-06-30 15:48:28.000000          NaN               NaN        NaN
# 58 2024-06-30 15:48:28.578192  torchscript              phi2        1.0
# 59 2024-06-30 15:48:34.885348  torchscript              phi2        0.0
# 24 2024-06-30 15:50:16.000000          NaN               NaN        NaN
# 25 2024-06-30 15:50:17.000000          NaN               NaN        NaN

# %%
# Add index as a column for sorting purposes
general_df['index_col'] = general_df.index

general_df = general_df.sort_values(by=['time', 'index_col'])
general_df
# Out:
#               timestamp      runtime             model        file  \
# 0   2024-06-23 16:46:53            -              IDLE      runall
# 1   2024-06-23 16:51:54        torch             START      runall
# 26                  NaN          NaN               NaN  load_times
# 27                  NaN          NaN               NaN  load_times
# 2   2024-06-23 16:55:08        torch        pythia1-4b      runall
# 28                  NaN          NaN               NaN  load_times
# 29                  NaN          NaN               NaN  load_times
# 3   2024-06-23 16:58:20        torch         tinyllama      runall
# 30                  NaN          NaN               NaN  load_times
# 31                  NaN          NaN               NaN  load_times
# 4   2024-06-23 16:59:56        torch  codeparrot-small      runall
# 32                  NaN          NaN               NaN  load_times
# 33                  NaN          NaN               NaN  load_times
# 5   2024-06-23 17:03:08        torch       pythia-410m      runall
# 34                  NaN          NaN               NaN  load_times
# 35                  NaN          NaN               NaN  load_times
# 6   2024-06-23 17:07:23        torch        error_phi2      runall
# 7   2024-06-23 17:07:24         onnx             START      runall
# 36                  NaN          NaN               NaN  load_times
# 37                  NaN          NaN               NaN  load_times
# 8   2024-06-23 17:16:29         onnx        pythia1-4b      runall
# 38                  NaN          NaN               NaN  load_times
# 39                  NaN          NaN               NaN  load_times
# 9   2024-06-23 17:23:25         onnx         tinyllama      runall
# 40                  NaN          NaN               NaN  load_times
# 41                  NaN          NaN               NaN  load_times
# 10  2024-06-23 17:26:40         onnx  codeparrot-small      runall
# 42                  NaN          NaN               NaN  load_times
# 43                  NaN          NaN               NaN  load_times
# 11  2024-06-23 17:34:13         onnx       pythia-410m      runall
# 12  2024-06-23 17:41:57         onnx        error_phi2      runall
# 13  2024-06-23 17:41:58  torchscript             START      runall
# 44                  NaN          NaN               NaN  load_times
# 45                  NaN          NaN               NaN  load_times
# 14  2024-06-23 17:43:41  torchscript        pythia1-4b      runall
# 46                  NaN          NaN               NaN  load_times
# 47                  NaN          NaN               NaN  load_times
# 15  2024-06-23 17:45:30  torchscript         tinyllama      runall
# 48                  NaN          NaN               NaN  load_times
# 49                  NaN          NaN               NaN  load_times
# 16  2024-06-23 17:47:07  torchscript  codeparrot-small      runall
# 50                  NaN          NaN               NaN  load_times
# 51                  NaN          NaN               NaN  load_times
# 17  2024-06-23 17:48:47  torchscript       pythia-410m      runall
# 52                  NaN          NaN               NaN  load_times
# 53                  NaN          NaN               NaN  load_times
# 18  2024-06-23 17:50:37  torchscript        error_phi2      runall
# 19  2024-06-30 15:30:42         onnx             START      runall
# 54                  NaN          NaN               NaN  load_times
# 55                  NaN          NaN               NaN  load_times
# 20  2024-06-30 15:44:10         onnx              phi2      runall
# 21  2024-06-30 15:44:10        torch             START      runall
# 56                  NaN          NaN               NaN  load_times
# 57                  NaN          NaN               NaN  load_times
# 22  2024-06-30 15:48:27        torch              phi2      runall
# 23  2024-06-30 15:48:28  torchscript             START      runall
# 58                  NaN          NaN               NaN  load_times
# 59                  NaN          NaN               NaN  load_times
# 24  2024-06-30 15:50:16  torchscript              phi2      runall
# 25  2024-06-30 15:50:17            -            FINISH      runall
#
#                          time       engine        model_name  start_end  \
# 0  2024-06-23 16:46:53.000000          NaN               NaN        NaN
# 1  2024-06-23 16:51:54.000000          NaN               NaN        NaN
# 26 2024-06-23 16:51:54.862842        torch        pythia1-4b        1.0
# 27 2024-06-23 16:51:56.727207        torch        pythia1-4b        0.0
# 2  2024-06-23 16:55:08.000000          NaN               NaN        NaN
# 28 2024-06-23 16:55:09.145398        torch         tinyllama        1.0
# 29 2024-06-23 16:55:10.507139        torch         tinyllama        0.0
# 3  2024-06-23 16:58:20.000000          NaN               NaN        NaN
# 30 2024-06-23 16:58:21.094631        torch  codeparrot-small        1.0
# 31 2024-06-23 16:58:21.283208        torch  codeparrot-small        0.0
# 4  2024-06-23 16:59:56.000000          NaN               NaN        NaN
# 32 2024-06-23 16:59:57.418073        torch       pythia-410m        1.0
# 33 2024-06-23 16:59:58.011860        torch       pythia-410m        0.0
# 5  2024-06-23 17:03:08.000000          NaN               NaN        NaN
# 34 2024-06-23 17:03:08.951462        torch        error_phi2        1.0
# 35 2024-06-23 17:03:12.407967        torch        error_phi2        0.0
# 6  2024-06-23 17:07:23.000000          NaN               NaN        NaN
# 7  2024-06-23 17:07:24.000000          NaN               NaN        NaN
# 36 2024-06-23 17:07:25.293045         onnx        pythia1-4b        1.0
# 37 2024-06-23 17:07:32.508933         onnx        pythia1-4b        0.0
# 8  2024-06-23 17:16:29.000000          NaN               NaN        NaN
# 38 2024-06-23 17:16:30.896322         onnx         tinyllama        1.0
# 39 2024-06-23 17:16:36.242586         onnx         tinyllama        0.0
# 9  2024-06-23 17:23:25.000000          NaN               NaN        NaN
# 40 2024-06-23 17:23:26.315983         onnx  codeparrot-small        1.0
# 41 2024-06-23 17:23:27.724942         onnx  codeparrot-small        0.0
# 10 2024-06-23 17:26:40.000000          NaN               NaN        NaN
# 42 2024-06-23 17:26:40.725283         onnx       pythia-410m        1.0
# 43 2024-06-23 17:26:44.458125         onnx       pythia-410m        0.0
# 11 2024-06-23 17:34:13.000000          NaN               NaN        NaN
# 12 2024-06-23 17:41:57.000000          NaN               NaN        NaN
# 13 2024-06-23 17:41:58.000000          NaN               NaN        NaN
# 44 2024-06-23 17:41:59.307629  torchscript        pythia1-4b        1.0
# 45 2024-06-23 17:42:03.551629  torchscript        pythia1-4b        0.0
# 14 2024-06-23 17:43:41.000000          NaN               NaN        NaN
# 46 2024-06-23 17:43:42.776044  torchscript         tinyllama        1.0
# 47 2024-06-23 17:43:46.073415  torchscript         tinyllama        0.0
# 15 2024-06-23 17:45:30.000000          NaN               NaN        NaN
# 48 2024-06-23 17:45:31.582783  torchscript  codeparrot-small        1.0
# 49 2024-06-23 17:45:32.008281  torchscript  codeparrot-small        0.0
# 16 2024-06-23 17:47:07.000000          NaN               NaN        NaN
# 50 2024-06-23 17:47:08.203822  torchscript       pythia-410m        1.0
# 51 2024-06-23 17:47:09.276123  torchscript       pythia-410m        0.0
# 17 2024-06-23 17:48:47.000000          NaN               NaN        NaN
# 52 2024-06-23 17:48:47.921375  torchscript        error_phi2        1.0
# 53 2024-06-23 17:48:55.811190  torchscript        error_phi2        0.0
# 18 2024-06-23 17:50:37.000000          NaN               NaN        NaN
# 19 2024-06-30 15:30:42.000000          NaN               NaN        NaN
# 54 2024-06-30 15:30:42.943662         onnx              phi2        1.0
# 55 2024-06-30 15:30:55.897983         onnx              phi2        0.0
# 20 2024-06-30 15:44:10.000000          NaN               NaN        NaN
# 21 2024-06-30 15:44:10.000000          NaN               NaN        NaN
# 56 2024-06-30 15:44:11.503720        torch              phi2        1.0
# 57 2024-06-30 15:44:15.052154        torch              phi2        0.0
# 22 2024-06-30 15:48:27.000000          NaN               NaN        NaN
# 23 2024-06-30 15:48:28.000000          NaN               NaN        NaN
# 58 2024-06-30 15:48:28.578192  torchscript              phi2        1.0
# 59 2024-06-30 15:48:34.885348  torchscript              phi2        0.0
# 24 2024-06-30 15:50:16.000000          NaN               NaN        NaN
# 25 2024-06-30 15:50:17.000000          NaN               NaN        NaN
#
#     index_col
# 0           0
# 1           1
# 26         26
# 27         27
# 2           2
# 28         28
# 29         29
# 3           3
# 30         30
# 31         31
# 4           4
# 32         32
# 33         33
# 5           5
# 34         34
# 35         35
# 6           6
# 7           7
# 36         36
# 37         37
# 8           8
# 38         38
# 39         39
# 9           9
# 40         40
# 41         41
# 10         10
# 42         42
# 43         43
# 11         11
# 12         12
# 13         13
# 44         44
# 45         45
# 14         14
# 46         46
# 47         47
# 15         15
# 48         48
# 49         49
# 16         16
# 50         50
# 51         51
# 17         17
# 52         52
# 53         53
# 18         18
# 19         19
# 54         54
# 55         55
# 20         20
# 21         21
# 56         56
# 57         57
# 22         22
# 23         23
# 58         58
# 59         59
# 24         24
# 25         25

# %%
# Optionally, you can drop the 'index_col' if not needed afterward
#df_sorted.drop(columns=['index_col'], inplace=True)

# %%
# Drop the redundant 'timestamp' column
general_df.drop(columns='timestamp', inplace=True)

# %%
general_df = general_df[['time', 'runtime', 'model', 'engine', 'model_name', 'start_end', 'file']]

general_df
# Out:
#                          time      runtime             model       engine  \
# 0  2024-06-23 16:46:53.000000            -              IDLE          NaN
# 1  2024-06-23 16:51:54.000000        torch             START          NaN
# 26 2024-06-23 16:51:54.862842          NaN               NaN        torch
# 27 2024-06-23 16:51:56.727207          NaN               NaN        torch
# 2  2024-06-23 16:55:08.000000        torch        pythia1-4b          NaN
# 28 2024-06-23 16:55:09.145398          NaN               NaN        torch
# 29 2024-06-23 16:55:10.507139          NaN               NaN        torch
# 3  2024-06-23 16:58:20.000000        torch         tinyllama          NaN
# 30 2024-06-23 16:58:21.094631          NaN               NaN        torch
# 31 2024-06-23 16:58:21.283208          NaN               NaN        torch
# 4  2024-06-23 16:59:56.000000        torch  codeparrot-small          NaN
# 32 2024-06-23 16:59:57.418073          NaN               NaN        torch
# 33 2024-06-23 16:59:58.011860          NaN               NaN        torch
# 5  2024-06-23 17:03:08.000000        torch       pythia-410m          NaN
# 34 2024-06-23 17:03:08.951462          NaN               NaN        torch
# 35 2024-06-23 17:03:12.407967          NaN               NaN        torch
# 6  2024-06-23 17:07:23.000000        torch        error_phi2          NaN
# 7  2024-06-23 17:07:24.000000         onnx             START          NaN
# 36 2024-06-23 17:07:25.293045          NaN               NaN         onnx
# 37 2024-06-23 17:07:32.508933          NaN               NaN         onnx
# 8  2024-06-23 17:16:29.000000         onnx        pythia1-4b          NaN
# 38 2024-06-23 17:16:30.896322          NaN               NaN         onnx
# 39 2024-06-23 17:16:36.242586          NaN               NaN         onnx
# 9  2024-06-23 17:23:25.000000         onnx         tinyllama          NaN
# 40 2024-06-23 17:23:26.315983          NaN               NaN         onnx
# 41 2024-06-23 17:23:27.724942          NaN               NaN         onnx
# 10 2024-06-23 17:26:40.000000         onnx  codeparrot-small          NaN
# 42 2024-06-23 17:26:40.725283          NaN               NaN         onnx
# 43 2024-06-23 17:26:44.458125          NaN               NaN         onnx
# 11 2024-06-23 17:34:13.000000         onnx       pythia-410m          NaN
# 12 2024-06-23 17:41:57.000000         onnx        error_phi2          NaN
# 13 2024-06-23 17:41:58.000000  torchscript             START          NaN
# 44 2024-06-23 17:41:59.307629          NaN               NaN  torchscript
# 45 2024-06-23 17:42:03.551629          NaN               NaN  torchscript
# 14 2024-06-23 17:43:41.000000  torchscript        pythia1-4b          NaN
# 46 2024-06-23 17:43:42.776044          NaN               NaN  torchscript
# 47 2024-06-23 17:43:46.073415          NaN               NaN  torchscript
# 15 2024-06-23 17:45:30.000000  torchscript         tinyllama          NaN
# 48 2024-06-23 17:45:31.582783          NaN               NaN  torchscript
# 49 2024-06-23 17:45:32.008281          NaN               NaN  torchscript
# 16 2024-06-23 17:47:07.000000  torchscript  codeparrot-small          NaN
# 50 2024-06-23 17:47:08.203822          NaN               NaN  torchscript
# 51 2024-06-23 17:47:09.276123          NaN               NaN  torchscript
# 17 2024-06-23 17:48:47.000000  torchscript       pythia-410m          NaN
# 52 2024-06-23 17:48:47.921375          NaN               NaN  torchscript
# 53 2024-06-23 17:48:55.811190          NaN               NaN  torchscript
# 18 2024-06-23 17:50:37.000000  torchscript        error_phi2          NaN
# 19 2024-06-30 15:30:42.000000         onnx             START          NaN
# 54 2024-06-30 15:30:42.943662          NaN               NaN         onnx
# 55 2024-06-30 15:30:55.897983          NaN               NaN         onnx
# 20 2024-06-30 15:44:10.000000         onnx              phi2          NaN
# 21 2024-06-30 15:44:10.000000        torch             START          NaN
# 56 2024-06-30 15:44:11.503720          NaN               NaN        torch
# 57 2024-06-30 15:44:15.052154          NaN               NaN        torch
# 22 2024-06-30 15:48:27.000000        torch              phi2          NaN
# 23 2024-06-30 15:48:28.000000  torchscript             START          NaN
# 58 2024-06-30 15:48:28.578192          NaN               NaN  torchscript
# 59 2024-06-30 15:48:34.885348          NaN               NaN  torchscript
# 24 2024-06-30 15:50:16.000000  torchscript              phi2          NaN
# 25 2024-06-30 15:50:17.000000            -            FINISH          NaN
#
#           model_name  start_end        file
# 0                NaN        NaN      runall
# 1                NaN        NaN      runall
# 26        pythia1-4b        1.0  load_times
# 27        pythia1-4b        0.0  load_times
# 2                NaN        NaN      runall
# 28         tinyllama        1.0  load_times
# 29         tinyllama        0.0  load_times
# 3                NaN        NaN      runall
# 30  codeparrot-small        1.0  load_times
# 31  codeparrot-small        0.0  load_times
# 4                NaN        NaN      runall
# 32       pythia-410m        1.0  load_times
# 33       pythia-410m        0.0  load_times
# 5                NaN        NaN      runall
# 34        error_phi2        1.0  load_times
# 35        error_phi2        0.0  load_times
# 6                NaN        NaN      runall
# 7                NaN        NaN      runall
# 36        pythia1-4b        1.0  load_times
# 37        pythia1-4b        0.0  load_times
# 8                NaN        NaN      runall
# 38         tinyllama        1.0  load_times
# 39         tinyllama        0.0  load_times
# 9                NaN        NaN      runall
# 40  codeparrot-small        1.0  load_times
# 41  codeparrot-small        0.0  load_times
# 10               NaN        NaN      runall
# 42       pythia-410m        1.0  load_times
# 43       pythia-410m        0.0  load_times
# 11               NaN        NaN      runall
# 12               NaN        NaN      runall
# 13               NaN        NaN      runall
# 44        pythia1-4b        1.0  load_times
# 45        pythia1-4b        0.0  load_times
# 14               NaN        NaN      runall
# 46         tinyllama        1.0  load_times
# 47         tinyllama        0.0  load_times
# 15               NaN        NaN      runall
# 48  codeparrot-small        1.0  load_times
# 49  codeparrot-small        0.0  load_times
# 16               NaN        NaN      runall
# 50       pythia-410m        1.0  load_times
# 51       pythia-410m        0.0  load_times
# 17               NaN        NaN      runall
# 52        error_phi2        1.0  load_times
# 53        error_phi2        0.0  load_times
# 18               NaN        NaN      runall
# 19               NaN        NaN      runall
# 54              phi2        1.0  load_times
# 55              phi2        0.0  load_times
# 20               NaN        NaN      runall
# 21               NaN        NaN      runall
# 56              phi2        1.0  load_times
# 57              phi2        0.0  load_times
# 22               NaN        NaN      runall
# 23               NaN        NaN      runall
# 58              phi2        1.0  load_times
# 59              phi2        0.0  load_times
# 24               NaN        NaN      runall
# 25               NaN        NaN      runall

# %%
# Add new column "label"
df = general_df.copy()

# Add new column "label"
label_values = ['idle'] + [f"{runtime} {model}" for runtime, model in zip(df["runtime"][1:-2], df["model"][1:-2])] + ['name3'] * 2
df['label'] = label_values

df
# Out:
#                          time      runtime             model       engine  \
# 0  2024-06-23 16:46:53.000000            -              IDLE          NaN
# 1  2024-06-23 16:51:54.000000        torch             START          NaN
# 26 2024-06-23 16:51:54.862842          NaN               NaN        torch
# 27 2024-06-23 16:51:56.727207          NaN               NaN        torch
# 2  2024-06-23 16:55:08.000000        torch        pythia1-4b          NaN
# 28 2024-06-23 16:55:09.145398          NaN               NaN        torch
# 29 2024-06-23 16:55:10.507139          NaN               NaN        torch
# 3  2024-06-23 16:58:20.000000        torch         tinyllama          NaN
# 30 2024-06-23 16:58:21.094631          NaN               NaN        torch
# 31 2024-06-23 16:58:21.283208          NaN               NaN        torch
# 4  2024-06-23 16:59:56.000000        torch  codeparrot-small          NaN
# 32 2024-06-23 16:59:57.418073          NaN               NaN        torch
# 33 2024-06-23 16:59:58.011860          NaN               NaN        torch
# 5  2024-06-23 17:03:08.000000        torch       pythia-410m          NaN
# 34 2024-06-23 17:03:08.951462          NaN               NaN        torch
# 35 2024-06-23 17:03:12.407967          NaN               NaN        torch
# 6  2024-06-23 17:07:23.000000        torch        error_phi2          NaN
# 7  2024-06-23 17:07:24.000000         onnx             START          NaN
# 36 2024-06-23 17:07:25.293045          NaN               NaN         onnx
# 37 2024-06-23 17:07:32.508933          NaN               NaN         onnx
# 8  2024-06-23 17:16:29.000000         onnx        pythia1-4b          NaN
# 38 2024-06-23 17:16:30.896322          NaN               NaN         onnx
# 39 2024-06-23 17:16:36.242586          NaN               NaN         onnx
# 9  2024-06-23 17:23:25.000000         onnx         tinyllama          NaN
# 40 2024-06-23 17:23:26.315983          NaN               NaN         onnx
# 41 2024-06-23 17:23:27.724942          NaN               NaN         onnx
# 10 2024-06-23 17:26:40.000000         onnx  codeparrot-small          NaN
# 42 2024-06-23 17:26:40.725283          NaN               NaN         onnx
# 43 2024-06-23 17:26:44.458125          NaN               NaN         onnx
# 11 2024-06-23 17:34:13.000000         onnx       pythia-410m          NaN
# 12 2024-06-23 17:41:57.000000         onnx        error_phi2          NaN
# 13 2024-06-23 17:41:58.000000  torchscript             START          NaN
# 44 2024-06-23 17:41:59.307629          NaN               NaN  torchscript
# 45 2024-06-23 17:42:03.551629          NaN               NaN  torchscript
# 14 2024-06-23 17:43:41.000000  torchscript        pythia1-4b          NaN
# 46 2024-06-23 17:43:42.776044          NaN               NaN  torchscript
# 47 2024-06-23 17:43:46.073415          NaN               NaN  torchscript
# 15 2024-06-23 17:45:30.000000  torchscript         tinyllama          NaN
# 48 2024-06-23 17:45:31.582783          NaN               NaN  torchscript
# 49 2024-06-23 17:45:32.008281          NaN               NaN  torchscript
# 16 2024-06-23 17:47:07.000000  torchscript  codeparrot-small          NaN
# 50 2024-06-23 17:47:08.203822          NaN               NaN  torchscript
# 51 2024-06-23 17:47:09.276123          NaN               NaN  torchscript
# 17 2024-06-23 17:48:47.000000  torchscript       pythia-410m          NaN
# 52 2024-06-23 17:48:47.921375          NaN               NaN  torchscript
# 53 2024-06-23 17:48:55.811190          NaN               NaN  torchscript
# 18 2024-06-23 17:50:37.000000  torchscript        error_phi2          NaN
# 19 2024-06-30 15:30:42.000000         onnx             START          NaN
# 54 2024-06-30 15:30:42.943662          NaN               NaN         onnx
# 55 2024-06-30 15:30:55.897983          NaN               NaN         onnx
# 20 2024-06-30 15:44:10.000000         onnx              phi2          NaN
# 21 2024-06-30 15:44:10.000000        torch             START          NaN
# 56 2024-06-30 15:44:11.503720          NaN               NaN        torch
# 57 2024-06-30 15:44:15.052154          NaN               NaN        torch
# 22 2024-06-30 15:48:27.000000        torch              phi2          NaN
# 23 2024-06-30 15:48:28.000000  torchscript             START          NaN
# 58 2024-06-30 15:48:28.578192          NaN               NaN  torchscript
# 59 2024-06-30 15:48:34.885348          NaN               NaN  torchscript
# 24 2024-06-30 15:50:16.000000  torchscript              phi2          NaN
# 25 2024-06-30 15:50:17.000000            -            FINISH          NaN
#
#           model_name  start_end        file                         label
# 0                NaN        NaN      runall                          idle
# 1                NaN        NaN      runall                   torch START
# 26        pythia1-4b        1.0  load_times                       nan nan
# 27        pythia1-4b        0.0  load_times                       nan nan
# 2                NaN        NaN      runall              torch pythia1-4b
# 28         tinyllama        1.0  load_times                       nan nan
# 29         tinyllama        0.0  load_times                       nan nan
# 3                NaN        NaN      runall               torch tinyllama
# 30  codeparrot-small        1.0  load_times                       nan nan
# 31  codeparrot-small        0.0  load_times                       nan nan
# 4                NaN        NaN      runall        torch codeparrot-small
# 32       pythia-410m        1.0  load_times                       nan nan
# 33       pythia-410m        0.0  load_times                       nan nan
# 5                NaN        NaN      runall             torch pythia-410m
# 34        error_phi2        1.0  load_times                       nan nan
# 35        error_phi2        0.0  load_times                       nan nan
# 6                NaN        NaN      runall              torch error_phi2
# 7                NaN        NaN      runall                    onnx START
# 36        pythia1-4b        1.0  load_times                       nan nan
# 37        pythia1-4b        0.0  load_times                       nan nan
# 8                NaN        NaN      runall               onnx pythia1-4b
# 38         tinyllama        1.0  load_times                       nan nan
# 39         tinyllama        0.0  load_times                       nan nan
# 9                NaN        NaN      runall                onnx tinyllama
# 40  codeparrot-small        1.0  load_times                       nan nan
# 41  codeparrot-small        0.0  load_times                       nan nan
# 10               NaN        NaN      runall         onnx codeparrot-small
# 42       pythia-410m        1.0  load_times                       nan nan
# 43       pythia-410m        0.0  load_times                       nan nan
# 11               NaN        NaN      runall              onnx pythia-410m
# 12               NaN        NaN      runall               onnx error_phi2
# 13               NaN        NaN      runall             torchscript START
# 44        pythia1-4b        1.0  load_times                       nan nan
# 45        pythia1-4b        0.0  load_times                       nan nan
# 14               NaN        NaN      runall        torchscript pythia1-4b
# 46         tinyllama        1.0  load_times                       nan nan
# 47         tinyllama        0.0  load_times                       nan nan
# 15               NaN        NaN      runall         torchscript tinyllama
# 48  codeparrot-small        1.0  load_times                       nan nan
# 49  codeparrot-small        0.0  load_times                       nan nan
# 16               NaN        NaN      runall  torchscript codeparrot-small
# 50       pythia-410m        1.0  load_times                       nan nan
# 51       pythia-410m        0.0  load_times                       nan nan
# 17               NaN        NaN      runall       torchscript pythia-410m
# 52        error_phi2        1.0  load_times                       nan nan
# 53        error_phi2        0.0  load_times                       nan nan
# 18               NaN        NaN      runall        torchscript error_phi2
# 19               NaN        NaN      runall                    onnx START
# 54              phi2        1.0  load_times                       nan nan
# 55              phi2        0.0  load_times                       nan nan
# 20               NaN        NaN      runall                     onnx phi2
# 21               NaN        NaN      runall                   torch START
# 56              phi2        1.0  load_times                       nan nan
# 57              phi2        0.0  load_times                       nan nan
# 22               NaN        NaN      runall                    torch phi2
# 23               NaN        NaN      runall             torchscript START
# 58              phi2        1.0  load_times                       nan nan
# 59              phi2        0.0  load_times                       nan nan
# 24               NaN        NaN      runall                         name3
# 25               NaN        NaN      runall                         name3

# %%
# Reset index
general_df.reset_index(drop=True, inplace=True)

general_df
# Out:
#                          time      runtime             model       engine  \
# 0  2024-06-23 16:46:53.000000            -              IDLE          NaN
# 1  2024-06-23 16:51:54.000000        torch             START          NaN
# 2  2024-06-23 16:51:54.862842          NaN               NaN        torch
# 3  2024-06-23 16:51:56.727207          NaN               NaN        torch
# 4  2024-06-23 16:55:08.000000        torch        pythia1-4b          NaN
# 5  2024-06-23 16:55:09.145398          NaN               NaN        torch
# 6  2024-06-23 16:55:10.507139          NaN               NaN        torch
# 7  2024-06-23 16:58:20.000000        torch         tinyllama          NaN
# 8  2024-06-23 16:58:21.094631          NaN               NaN        torch
# 9  2024-06-23 16:58:21.283208          NaN               NaN        torch
# 10 2024-06-23 16:59:56.000000        torch  codeparrot-small          NaN
# 11 2024-06-23 16:59:57.418073          NaN               NaN        torch
# 12 2024-06-23 16:59:58.011860          NaN               NaN        torch
# 13 2024-06-23 17:03:08.000000        torch       pythia-410m          NaN
# 14 2024-06-23 17:03:08.951462          NaN               NaN        torch
# 15 2024-06-23 17:03:12.407967          NaN               NaN        torch
# 16 2024-06-23 17:07:23.000000        torch        error_phi2          NaN
# 17 2024-06-23 17:07:24.000000         onnx             START          NaN
# 18 2024-06-23 17:07:25.293045          NaN               NaN         onnx
# 19 2024-06-23 17:07:32.508933          NaN               NaN         onnx
# 20 2024-06-23 17:16:29.000000         onnx        pythia1-4b          NaN
# 21 2024-06-23 17:16:30.896322          NaN               NaN         onnx
# 22 2024-06-23 17:16:36.242586          NaN               NaN         onnx
# 23 2024-06-23 17:23:25.000000         onnx         tinyllama          NaN
# 24 2024-06-23 17:23:26.315983          NaN               NaN         onnx
# 25 2024-06-23 17:23:27.724942          NaN               NaN         onnx
# 26 2024-06-23 17:26:40.000000         onnx  codeparrot-small          NaN
# 27 2024-06-23 17:26:40.725283          NaN               NaN         onnx
# 28 2024-06-23 17:26:44.458125          NaN               NaN         onnx
# 29 2024-06-23 17:34:13.000000         onnx       pythia-410m          NaN
# 30 2024-06-23 17:41:57.000000         onnx        error_phi2          NaN
# 31 2024-06-23 17:41:58.000000  torchscript             START          NaN
# 32 2024-06-23 17:41:59.307629          NaN               NaN  torchscript
# 33 2024-06-23 17:42:03.551629          NaN               NaN  torchscript
# 34 2024-06-23 17:43:41.000000  torchscript        pythia1-4b          NaN
# 35 2024-06-23 17:43:42.776044          NaN               NaN  torchscript
# 36 2024-06-23 17:43:46.073415          NaN               NaN  torchscript
# 37 2024-06-23 17:45:30.000000  torchscript         tinyllama          NaN
# 38 2024-06-23 17:45:31.582783          NaN               NaN  torchscript
# 39 2024-06-23 17:45:32.008281          NaN               NaN  torchscript
# 40 2024-06-23 17:47:07.000000  torchscript  codeparrot-small          NaN
# 41 2024-06-23 17:47:08.203822          NaN               NaN  torchscript
# 42 2024-06-23 17:47:09.276123          NaN               NaN  torchscript
# 43 2024-06-23 17:48:47.000000  torchscript       pythia-410m          NaN
# 44 2024-06-23 17:48:47.921375          NaN               NaN  torchscript
# 45 2024-06-23 17:48:55.811190          NaN               NaN  torchscript
# 46 2024-06-23 17:50:37.000000  torchscript        error_phi2          NaN
# 47 2024-06-30 15:30:42.000000         onnx             START          NaN
# 48 2024-06-30 15:30:42.943662          NaN               NaN         onnx
# 49 2024-06-30 15:30:55.897983          NaN               NaN         onnx
# 50 2024-06-30 15:44:10.000000         onnx              phi2          NaN
# 51 2024-06-30 15:44:10.000000        torch             START          NaN
# 52 2024-06-30 15:44:11.503720          NaN               NaN        torch
# 53 2024-06-30 15:44:15.052154          NaN               NaN        torch
# 54 2024-06-30 15:48:27.000000        torch              phi2          NaN
# 55 2024-06-30 15:48:28.000000  torchscript             START          NaN
# 56 2024-06-30 15:48:28.578192          NaN               NaN  torchscript
# 57 2024-06-30 15:48:34.885348          NaN               NaN  torchscript
# 58 2024-06-30 15:50:16.000000  torchscript              phi2          NaN
# 59 2024-06-30 15:50:17.000000            -            FINISH          NaN
#
#           model_name  start_end        file
# 0                NaN        NaN      runall
# 1                NaN        NaN      runall
# 2         pythia1-4b        1.0  load_times
# 3         pythia1-4b        0.0  load_times
# 4                NaN        NaN      runall
# 5          tinyllama        1.0  load_times
# 6          tinyllama        0.0  load_times
# 7                NaN        NaN      runall
# 8   codeparrot-small        1.0  load_times
# 9   codeparrot-small        0.0  load_times
# 10               NaN        NaN      runall
# 11       pythia-410m        1.0  load_times
# 12       pythia-410m        0.0  load_times
# 13               NaN        NaN      runall
# 14        error_phi2        1.0  load_times
# 15        error_phi2        0.0  load_times
# 16               NaN        NaN      runall
# 17               NaN        NaN      runall
# 18        pythia1-4b        1.0  load_times
# 19        pythia1-4b        0.0  load_times
# 20               NaN        NaN      runall
# 21         tinyllama        1.0  load_times
# 22         tinyllama        0.0  load_times
# 23               NaN        NaN      runall
# 24  codeparrot-small        1.0  load_times
# 25  codeparrot-small        0.0  load_times
# 26               NaN        NaN      runall
# 27       pythia-410m        1.0  load_times
# 28       pythia-410m        0.0  load_times
# 29               NaN        NaN      runall
# 30               NaN        NaN      runall
# 31               NaN        NaN      runall
# 32        pythia1-4b        1.0  load_times
# 33        pythia1-4b        0.0  load_times
# 34               NaN        NaN      runall
# 35         tinyllama        1.0  load_times
# 36         tinyllama        0.0  load_times
# 37               NaN        NaN      runall
# 38  codeparrot-small        1.0  load_times
# 39  codeparrot-small        0.0  load_times
# 40               NaN        NaN      runall
# 41       pythia-410m        1.0  load_times
# 42       pythia-410m        0.0  load_times
# 43               NaN        NaN      runall
# 44        error_phi2        1.0  load_times
# 45        error_phi2        0.0  load_times
# 46               NaN        NaN      runall
# 47               NaN        NaN      runall
# 48              phi2        1.0  load_times
# 49              phi2        0.0  load_times
# 50               NaN        NaN      runall
# 51               NaN        NaN      runall
# 52              phi2        1.0  load_times
# 53              phi2        0.0  load_times
# 54               NaN        NaN      runall
# 55               NaN        NaN      runall
# 56              phi2        1.0  load_times
# 57              phi2        0.0  load_times
# 58               NaN        NaN      runall
# 59               NaN        NaN      runall

# %%
# Add label column

# Create DataFrame
df = general_df.copy()

# Iterate through each row
for idx, row in df.iterrows():
    # If it's the first row, set "idle" as the label
    if idx == 0:
        df.at[idx, 'label'] = 'idle'
    # If it's the last two rows, set "name3" as the label
    elif idx >= len(df) - 1:
        print(idx)
        df.at[idx, 'label'] = 'finish'
    # For other rows, set the label as the concatenation of runtime and model
    else:
        if not isinstance(row['runtime'],str):
            df.at[idx, 'label'] = f"{row['engine']}_{row['model_name']}"
        else:
            df.at[idx, 'label'] = f"{row['runtime']}_{row['model']}"
        #df['label'] = np.where(df['runtime'].isna() | df['model'].isna(), 'nan_value', '')
        #df.at[idx, 'label'] = f"{row['runtime']} {row['model']}"

df
# Out:
# 59
#                          time      runtime             model       engine  \
# 0  2024-06-23 16:46:53.000000            -              IDLE          NaN
# 1  2024-06-23 16:51:54.000000        torch             START          NaN
# 2  2024-06-23 16:51:54.862842          NaN               NaN        torch
# 3  2024-06-23 16:51:56.727207          NaN               NaN        torch
# 4  2024-06-23 16:55:08.000000        torch        pythia1-4b          NaN
# 5  2024-06-23 16:55:09.145398          NaN               NaN        torch
# 6  2024-06-23 16:55:10.507139          NaN               NaN        torch
# 7  2024-06-23 16:58:20.000000        torch         tinyllama          NaN
# 8  2024-06-23 16:58:21.094631          NaN               NaN        torch
# 9  2024-06-23 16:58:21.283208          NaN               NaN        torch
# 10 2024-06-23 16:59:56.000000        torch  codeparrot-small          NaN
# 11 2024-06-23 16:59:57.418073          NaN               NaN        torch
# 12 2024-06-23 16:59:58.011860          NaN               NaN        torch
# 13 2024-06-23 17:03:08.000000        torch       pythia-410m          NaN
# 14 2024-06-23 17:03:08.951462          NaN               NaN        torch
# 15 2024-06-23 17:03:12.407967          NaN               NaN        torch
# 16 2024-06-23 17:07:23.000000        torch        error_phi2          NaN
# 17 2024-06-23 17:07:24.000000         onnx             START          NaN
# 18 2024-06-23 17:07:25.293045          NaN               NaN         onnx
# 19 2024-06-23 17:07:32.508933          NaN               NaN         onnx
# 20 2024-06-23 17:16:29.000000         onnx        pythia1-4b          NaN
# 21 2024-06-23 17:16:30.896322          NaN               NaN         onnx
# 22 2024-06-23 17:16:36.242586          NaN               NaN         onnx
# 23 2024-06-23 17:23:25.000000         onnx         tinyllama          NaN
# 24 2024-06-23 17:23:26.315983          NaN               NaN         onnx
# 25 2024-06-23 17:23:27.724942          NaN               NaN         onnx
# 26 2024-06-23 17:26:40.000000         onnx  codeparrot-small          NaN
# 27 2024-06-23 17:26:40.725283          NaN               NaN         onnx
# 28 2024-06-23 17:26:44.458125          NaN               NaN         onnx
# 29 2024-06-23 17:34:13.000000         onnx       pythia-410m          NaN
# 30 2024-06-23 17:41:57.000000         onnx        error_phi2          NaN
# 31 2024-06-23 17:41:58.000000  torchscript             START          NaN
# 32 2024-06-23 17:41:59.307629          NaN               NaN  torchscript
# 33 2024-06-23 17:42:03.551629          NaN               NaN  torchscript
# 34 2024-06-23 17:43:41.000000  torchscript        pythia1-4b          NaN
# 35 2024-06-23 17:43:42.776044          NaN               NaN  torchscript
# 36 2024-06-23 17:43:46.073415          NaN               NaN  torchscript
# 37 2024-06-23 17:45:30.000000  torchscript         tinyllama          NaN
# 38 2024-06-23 17:45:31.582783          NaN               NaN  torchscript
# 39 2024-06-23 17:45:32.008281          NaN               NaN  torchscript
# 40 2024-06-23 17:47:07.000000  torchscript  codeparrot-small          NaN
# 41 2024-06-23 17:47:08.203822          NaN               NaN  torchscript
# 42 2024-06-23 17:47:09.276123          NaN               NaN  torchscript
# 43 2024-06-23 17:48:47.000000  torchscript       pythia-410m          NaN
# 44 2024-06-23 17:48:47.921375          NaN               NaN  torchscript
# 45 2024-06-23 17:48:55.811190          NaN               NaN  torchscript
# 46 2024-06-23 17:50:37.000000  torchscript        error_phi2          NaN
# 47 2024-06-30 15:30:42.000000         onnx             START          NaN
# 48 2024-06-30 15:30:42.943662          NaN               NaN         onnx
# 49 2024-06-30 15:30:55.897983          NaN               NaN         onnx
# 50 2024-06-30 15:44:10.000000         onnx              phi2          NaN
# 51 2024-06-30 15:44:10.000000        torch             START          NaN
# 52 2024-06-30 15:44:11.503720          NaN               NaN        torch
# 53 2024-06-30 15:44:15.052154          NaN               NaN        torch
# 54 2024-06-30 15:48:27.000000        torch              phi2          NaN
# 55 2024-06-30 15:48:28.000000  torchscript             START          NaN
# 56 2024-06-30 15:48:28.578192          NaN               NaN  torchscript
# 57 2024-06-30 15:48:34.885348          NaN               NaN  torchscript
# 58 2024-06-30 15:50:16.000000  torchscript              phi2          NaN
# 59 2024-06-30 15:50:17.000000            -            FINISH          NaN
#
#           model_name  start_end        file                         label
# 0                NaN        NaN      runall                          idle
# 1                NaN        NaN      runall                   torch_START
# 2         pythia1-4b        1.0  load_times              torch_pythia1-4b
# 3         pythia1-4b        0.0  load_times              torch_pythia1-4b
# 4                NaN        NaN      runall              torch_pythia1-4b
# 5          tinyllama        1.0  load_times               torch_tinyllama
# 6          tinyllama        0.0  load_times               torch_tinyllama
# 7                NaN        NaN      runall               torch_tinyllama
# 8   codeparrot-small        1.0  load_times        torch_codeparrot-small
# 9   codeparrot-small        0.0  load_times        torch_codeparrot-small
# 10               NaN        NaN      runall        torch_codeparrot-small
# 11       pythia-410m        1.0  load_times             torch_pythia-410m
# 12       pythia-410m        0.0  load_times             torch_pythia-410m
# 13               NaN        NaN      runall             torch_pythia-410m
# 14        error_phi2        1.0  load_times              torch_error_phi2
# 15        error_phi2        0.0  load_times              torch_error_phi2
# 16               NaN        NaN      runall              torch_error_phi2
# 17               NaN        NaN      runall                    onnx_START
# 18        pythia1-4b        1.0  load_times               onnx_pythia1-4b
# 19        pythia1-4b        0.0  load_times               onnx_pythia1-4b
# 20               NaN        NaN      runall               onnx_pythia1-4b
# 21         tinyllama        1.0  load_times                onnx_tinyllama
# 22         tinyllama        0.0  load_times                onnx_tinyllama
# 23               NaN        NaN      runall                onnx_tinyllama
# 24  codeparrot-small        1.0  load_times         onnx_codeparrot-small
# 25  codeparrot-small        0.0  load_times         onnx_codeparrot-small
# 26               NaN        NaN      runall         onnx_codeparrot-small
# 27       pythia-410m        1.0  load_times              onnx_pythia-410m
# 28       pythia-410m        0.0  load_times              onnx_pythia-410m
# 29               NaN        NaN      runall              onnx_pythia-410m
# 30               NaN        NaN      runall               onnx_error_phi2
# 31               NaN        NaN      runall             torchscript_START
# 32        pythia1-4b        1.0  load_times        torchscript_pythia1-4b
# 33        pythia1-4b        0.0  load_times        torchscript_pythia1-4b
# 34               NaN        NaN      runall        torchscript_pythia1-4b
# 35         tinyllama        1.0  load_times         torchscript_tinyllama
# 36         tinyllama        0.0  load_times         torchscript_tinyllama
# 37               NaN        NaN      runall         torchscript_tinyllama
# 38  codeparrot-small        1.0  load_times  torchscript_codeparrot-small
# 39  codeparrot-small        0.0  load_times  torchscript_codeparrot-small
# 40               NaN        NaN      runall  torchscript_codeparrot-small
# 41       pythia-410m        1.0  load_times       torchscript_pythia-410m
# 42       pythia-410m        0.0  load_times       torchscript_pythia-410m
# 43               NaN        NaN      runall       torchscript_pythia-410m
# 44        error_phi2        1.0  load_times        torchscript_error_phi2
# 45        error_phi2        0.0  load_times        torchscript_error_phi2
# 46               NaN        NaN      runall        torchscript_error_phi2
# 47               NaN        NaN      runall                    onnx_START
# 48              phi2        1.0  load_times                     onnx_phi2
# 49              phi2        0.0  load_times                     onnx_phi2
# 50               NaN        NaN      runall                     onnx_phi2
# 51               NaN        NaN      runall                   torch_START
# 52              phi2        1.0  load_times                    torch_phi2
# 53              phi2        0.0  load_times                    torch_phi2
# 54               NaN        NaN      runall                    torch_phi2
# 55               NaN        NaN      runall             torchscript_START
# 56              phi2        1.0  load_times              torchscript_phi2
# 57              phi2        0.0  load_times              torchscript_phi2
# 58               NaN        NaN      runall              torchscript_phi2
# 59               NaN        NaN      runall                        finish

# %%
# Ensure the 'time' column is a datetime type
df['time'] = pd.to_datetime(df['time'])

# Calculate the difference in seconds between the current and previous row
df['duration'] = df['time'].diff().dt.total_seconds()

# %%
df
# Out:
#                          time      runtime             model       engine  \
# 0  2024-06-23 16:46:53.000000            -              IDLE          NaN
# 1  2024-06-23 16:51:54.000000        torch             START          NaN
# 2  2024-06-23 16:51:54.862842          NaN               NaN        torch
# 3  2024-06-23 16:51:56.727207          NaN               NaN        torch
# 4  2024-06-23 16:55:08.000000        torch        pythia1-4b          NaN
# 5  2024-06-23 16:55:09.145398          NaN               NaN        torch
# 6  2024-06-23 16:55:10.507139          NaN               NaN        torch
# 7  2024-06-23 16:58:20.000000        torch         tinyllama          NaN
# 8  2024-06-23 16:58:21.094631          NaN               NaN        torch
# 9  2024-06-23 16:58:21.283208          NaN               NaN        torch
# 10 2024-06-23 16:59:56.000000        torch  codeparrot-small          NaN
# 11 2024-06-23 16:59:57.418073          NaN               NaN        torch
# 12 2024-06-23 16:59:58.011860          NaN               NaN        torch
# 13 2024-06-23 17:03:08.000000        torch       pythia-410m          NaN
# 14 2024-06-23 17:03:08.951462          NaN               NaN        torch
# 15 2024-06-23 17:03:12.407967          NaN               NaN        torch
# 16 2024-06-23 17:07:23.000000        torch        error_phi2          NaN
# 17 2024-06-23 17:07:24.000000         onnx             START          NaN
# 18 2024-06-23 17:07:25.293045          NaN               NaN         onnx
# 19 2024-06-23 17:07:32.508933          NaN               NaN         onnx
# 20 2024-06-23 17:16:29.000000         onnx        pythia1-4b          NaN
# 21 2024-06-23 17:16:30.896322          NaN               NaN         onnx
# 22 2024-06-23 17:16:36.242586          NaN               NaN         onnx
# 23 2024-06-23 17:23:25.000000         onnx         tinyllama          NaN
# 24 2024-06-23 17:23:26.315983          NaN               NaN         onnx
# 25 2024-06-23 17:23:27.724942          NaN               NaN         onnx
# 26 2024-06-23 17:26:40.000000         onnx  codeparrot-small          NaN
# 27 2024-06-23 17:26:40.725283          NaN               NaN         onnx
# 28 2024-06-23 17:26:44.458125          NaN               NaN         onnx
# 29 2024-06-23 17:34:13.000000         onnx       pythia-410m          NaN
# 30 2024-06-23 17:41:57.000000         onnx        error_phi2          NaN
# 31 2024-06-23 17:41:58.000000  torchscript             START          NaN
# 32 2024-06-23 17:41:59.307629          NaN               NaN  torchscript
# 33 2024-06-23 17:42:03.551629          NaN               NaN  torchscript
# 34 2024-06-23 17:43:41.000000  torchscript        pythia1-4b          NaN
# 35 2024-06-23 17:43:42.776044          NaN               NaN  torchscript
# 36 2024-06-23 17:43:46.073415          NaN               NaN  torchscript
# 37 2024-06-23 17:45:30.000000  torchscript         tinyllama          NaN
# 38 2024-06-23 17:45:31.582783          NaN               NaN  torchscript
# 39 2024-06-23 17:45:32.008281          NaN               NaN  torchscript
# 40 2024-06-23 17:47:07.000000  torchscript  codeparrot-small          NaN
# 41 2024-06-23 17:47:08.203822          NaN               NaN  torchscript
# 42 2024-06-23 17:47:09.276123          NaN               NaN  torchscript
# 43 2024-06-23 17:48:47.000000  torchscript       pythia-410m          NaN
# 44 2024-06-23 17:48:47.921375          NaN               NaN  torchscript
# 45 2024-06-23 17:48:55.811190          NaN               NaN  torchscript
# 46 2024-06-23 17:50:37.000000  torchscript        error_phi2          NaN
# 47 2024-06-30 15:30:42.000000         onnx             START          NaN
# 48 2024-06-30 15:30:42.943662          NaN               NaN         onnx
# 49 2024-06-30 15:30:55.897983          NaN               NaN         onnx
# 50 2024-06-30 15:44:10.000000         onnx              phi2          NaN
# 51 2024-06-30 15:44:10.000000        torch             START          NaN
# 52 2024-06-30 15:44:11.503720          NaN               NaN        torch
# 53 2024-06-30 15:44:15.052154          NaN               NaN        torch
# 54 2024-06-30 15:48:27.000000        torch              phi2          NaN
# 55 2024-06-30 15:48:28.000000  torchscript             START          NaN
# 56 2024-06-30 15:48:28.578192          NaN               NaN  torchscript
# 57 2024-06-30 15:48:34.885348          NaN               NaN  torchscript
# 58 2024-06-30 15:50:16.000000  torchscript              phi2          NaN
# 59 2024-06-30 15:50:17.000000            -            FINISH          NaN
#
#           model_name  start_end        file                         label  \
# 0                NaN        NaN      runall                          idle
# 1                NaN        NaN      runall                   torch_START
# 2         pythia1-4b        1.0  load_times              torch_pythia1-4b
# 3         pythia1-4b        0.0  load_times              torch_pythia1-4b
# 4                NaN        NaN      runall              torch_pythia1-4b
# 5          tinyllama        1.0  load_times               torch_tinyllama
# 6          tinyllama        0.0  load_times               torch_tinyllama
# 7                NaN        NaN      runall               torch_tinyllama
# 8   codeparrot-small        1.0  load_times        torch_codeparrot-small
# 9   codeparrot-small        0.0  load_times        torch_codeparrot-small
# 10               NaN        NaN      runall        torch_codeparrot-small
# 11       pythia-410m        1.0  load_times             torch_pythia-410m
# 12       pythia-410m        0.0  load_times             torch_pythia-410m
# 13               NaN        NaN      runall             torch_pythia-410m
# 14        error_phi2        1.0  load_times              torch_error_phi2
# 15        error_phi2        0.0  load_times              torch_error_phi2
# 16               NaN        NaN      runall              torch_error_phi2
# 17               NaN        NaN      runall                    onnx_START
# 18        pythia1-4b        1.0  load_times               onnx_pythia1-4b
# 19        pythia1-4b        0.0  load_times               onnx_pythia1-4b
# 20               NaN        NaN      runall               onnx_pythia1-4b
# 21         tinyllama        1.0  load_times                onnx_tinyllama
# 22         tinyllama        0.0  load_times                onnx_tinyllama
# 23               NaN        NaN      runall                onnx_tinyllama
# 24  codeparrot-small        1.0  load_times         onnx_codeparrot-small
# 25  codeparrot-small        0.0  load_times         onnx_codeparrot-small
# 26               NaN        NaN      runall         onnx_codeparrot-small
# 27       pythia-410m        1.0  load_times              onnx_pythia-410m
# 28       pythia-410m        0.0  load_times              onnx_pythia-410m
# 29               NaN        NaN      runall              onnx_pythia-410m
# 30               NaN        NaN      runall               onnx_error_phi2
# 31               NaN        NaN      runall             torchscript_START
# 32        pythia1-4b        1.0  load_times        torchscript_pythia1-4b
# 33        pythia1-4b        0.0  load_times        torchscript_pythia1-4b
# 34               NaN        NaN      runall        torchscript_pythia1-4b
# 35         tinyllama        1.0  load_times         torchscript_tinyllama
# 36         tinyllama        0.0  load_times         torchscript_tinyllama
# 37               NaN        NaN      runall         torchscript_tinyllama
# 38  codeparrot-small        1.0  load_times  torchscript_codeparrot-small
# 39  codeparrot-small        0.0  load_times  torchscript_codeparrot-small
# 40               NaN        NaN      runall  torchscript_codeparrot-small
# 41       pythia-410m        1.0  load_times       torchscript_pythia-410m
# 42       pythia-410m        0.0  load_times       torchscript_pythia-410m
# 43               NaN        NaN      runall       torchscript_pythia-410m
# 44        error_phi2        1.0  load_times        torchscript_error_phi2
# 45        error_phi2        0.0  load_times        torchscript_error_phi2
# 46               NaN        NaN      runall        torchscript_error_phi2
# 47               NaN        NaN      runall                    onnx_START
# 48              phi2        1.0  load_times                     onnx_phi2
# 49              phi2        0.0  load_times                     onnx_phi2
# 50               NaN        NaN      runall                     onnx_phi2
# 51               NaN        NaN      runall                   torch_START
# 52              phi2        1.0  load_times                    torch_phi2
# 53              phi2        0.0  load_times                    torch_phi2
# 54               NaN        NaN      runall                    torch_phi2
# 55               NaN        NaN      runall             torchscript_START
# 56              phi2        1.0  load_times              torchscript_phi2
# 57              phi2        0.0  load_times              torchscript_phi2
# 58               NaN        NaN      runall              torchscript_phi2
# 59               NaN        NaN      runall                        finish
#
#          duration
# 0             NaN
# 1      301.000000
# 2        0.862842
# 3        1.864365
# 4      191.272793
# 5        1.145398
# 6        1.361741
# 7      189.492861
# 8        1.094631
# 9        0.188577
# 10      94.716792
# 11       1.418073
# 12       0.593787
# 13     189.988140
# 14       0.951462
# 15       3.456505
# 16     250.592033
# 17       1.000000
# 18       1.293045
# 19       7.215888
# 20     536.491067
# 21       1.896322
# 22       5.346264
# 23     408.757414
# 24       1.315983
# 25       1.408959
# 26     192.275058
# 27       0.725283
# 28       3.732842
# 29     448.541875
# 30     464.000000
# 31       1.000000
# 32       1.307629
# 33       4.244000
# 34      97.448371
# 35       1.776044
# 36       3.297371
# 37     103.926585
# 38       1.582783
# 39       0.425498
# 40      94.991719
# 41       1.203822
# 42       1.072301
# 43      97.723877
# 44       0.921375
# 45       7.889815
# 46     101.188810
# 47  596405.000000
# 48       0.943662
# 49      12.954321
# 50     794.102017
# 51       0.000000
# 52       1.503720
# 53       3.548434
# 54     251.947846
# 55       1.000000
# 56       0.578192
# 57       6.307156
# 58     101.114652
# 59       1.000000

# %%
def isNaN(num):
    return num != num

# Add new column 'label2' based on conditions
def determine_label(row):
    if row['start_end'] == 0:
        return row['engine'] + "_" + row['model_name']+ "_load"
    if row['file'] == 'runall' and  not isNaN(row['runtime']):
        return row['runtime'] + "_" + row['model']+ "_inference"
    else:
        return None



# Apply the function to each row
df['label_time'] = df.apply(determine_label, axis=1)

df
# Out:
#                          time      runtime             model       engine  \
# 0  2024-06-23 16:46:53.000000            -              IDLE          NaN
# 1  2024-06-23 16:51:54.000000        torch             START          NaN
# 2  2024-06-23 16:51:54.862842          NaN               NaN        torch
# 3  2024-06-23 16:51:56.727207          NaN               NaN        torch
# 4  2024-06-23 16:55:08.000000        torch        pythia1-4b          NaN
# 5  2024-06-23 16:55:09.145398          NaN               NaN        torch
# 6  2024-06-23 16:55:10.507139          NaN               NaN        torch
# 7  2024-06-23 16:58:20.000000        torch         tinyllama          NaN
# 8  2024-06-23 16:58:21.094631          NaN               NaN        torch
# 9  2024-06-23 16:58:21.283208          NaN               NaN        torch
# 10 2024-06-23 16:59:56.000000        torch  codeparrot-small          NaN
# 11 2024-06-23 16:59:57.418073          NaN               NaN        torch
# 12 2024-06-23 16:59:58.011860          NaN               NaN        torch
# 13 2024-06-23 17:03:08.000000        torch       pythia-410m          NaN
# 14 2024-06-23 17:03:08.951462          NaN               NaN        torch
# 15 2024-06-23 17:03:12.407967          NaN               NaN        torch
# 16 2024-06-23 17:07:23.000000        torch        error_phi2          NaN
# 17 2024-06-23 17:07:24.000000         onnx             START          NaN
# 18 2024-06-23 17:07:25.293045          NaN               NaN         onnx
# 19 2024-06-23 17:07:32.508933          NaN               NaN         onnx
# 20 2024-06-23 17:16:29.000000         onnx        pythia1-4b          NaN
# 21 2024-06-23 17:16:30.896322          NaN               NaN         onnx
# 22 2024-06-23 17:16:36.242586          NaN               NaN         onnx
# 23 2024-06-23 17:23:25.000000         onnx         tinyllama          NaN
# 24 2024-06-23 17:23:26.315983          NaN               NaN         onnx
# 25 2024-06-23 17:23:27.724942          NaN               NaN         onnx
# 26 2024-06-23 17:26:40.000000         onnx  codeparrot-small          NaN
# 27 2024-06-23 17:26:40.725283          NaN               NaN         onnx
# 28 2024-06-23 17:26:44.458125          NaN               NaN         onnx
# 29 2024-06-23 17:34:13.000000         onnx       pythia-410m          NaN
# 30 2024-06-23 17:41:57.000000         onnx        error_phi2          NaN
# 31 2024-06-23 17:41:58.000000  torchscript             START          NaN
# 32 2024-06-23 17:41:59.307629          NaN               NaN  torchscript
# 33 2024-06-23 17:42:03.551629          NaN               NaN  torchscript
# 34 2024-06-23 17:43:41.000000  torchscript        pythia1-4b          NaN
# 35 2024-06-23 17:43:42.776044          NaN               NaN  torchscript
# 36 2024-06-23 17:43:46.073415          NaN               NaN  torchscript
# 37 2024-06-23 17:45:30.000000  torchscript         tinyllama          NaN
# 38 2024-06-23 17:45:31.582783          NaN               NaN  torchscript
# 39 2024-06-23 17:45:32.008281          NaN               NaN  torchscript
# 40 2024-06-23 17:47:07.000000  torchscript  codeparrot-small          NaN
# 41 2024-06-23 17:47:08.203822          NaN               NaN  torchscript
# 42 2024-06-23 17:47:09.276123          NaN               NaN  torchscript
# 43 2024-06-23 17:48:47.000000  torchscript       pythia-410m          NaN
# 44 2024-06-23 17:48:47.921375          NaN               NaN  torchscript
# 45 2024-06-23 17:48:55.811190          NaN               NaN  torchscript
# 46 2024-06-23 17:50:37.000000  torchscript        error_phi2          NaN
# 47 2024-06-30 15:30:42.000000         onnx             START          NaN
# 48 2024-06-30 15:30:42.943662          NaN               NaN         onnx
# 49 2024-06-30 15:30:55.897983          NaN               NaN         onnx
# 50 2024-06-30 15:44:10.000000         onnx              phi2          NaN
# 51 2024-06-30 15:44:10.000000        torch             START          NaN
# 52 2024-06-30 15:44:11.503720          NaN               NaN        torch
# 53 2024-06-30 15:44:15.052154          NaN               NaN        torch
# 54 2024-06-30 15:48:27.000000        torch              phi2          NaN
# 55 2024-06-30 15:48:28.000000  torchscript             START          NaN
# 56 2024-06-30 15:48:28.578192          NaN               NaN  torchscript
# 57 2024-06-30 15:48:34.885348          NaN               NaN  torchscript
# 58 2024-06-30 15:50:16.000000  torchscript              phi2          NaN
# 59 2024-06-30 15:50:17.000000            -            FINISH          NaN
#
#           model_name  start_end        file                         label  \
# 0                NaN        NaN      runall                          idle
# 1                NaN        NaN      runall                   torch_START
# 2         pythia1-4b        1.0  load_times              torch_pythia1-4b
# 3         pythia1-4b        0.0  load_times              torch_pythia1-4b
# 4                NaN        NaN      runall              torch_pythia1-4b
# 5          tinyllama        1.0  load_times               torch_tinyllama
# 6          tinyllama        0.0  load_times               torch_tinyllama
# 7                NaN        NaN      runall               torch_tinyllama
# 8   codeparrot-small        1.0  load_times        torch_codeparrot-small
# 9   codeparrot-small        0.0  load_times        torch_codeparrot-small
# 10               NaN        NaN      runall        torch_codeparrot-small
# 11       pythia-410m        1.0  load_times             torch_pythia-410m
# 12       pythia-410m        0.0  load_times             torch_pythia-410m
# 13               NaN        NaN      runall             torch_pythia-410m
# 14        error_phi2        1.0  load_times              torch_error_phi2
# 15        error_phi2        0.0  load_times              torch_error_phi2
# 16               NaN        NaN      runall              torch_error_phi2
# 17               NaN        NaN      runall                    onnx_START
# 18        pythia1-4b        1.0  load_times               onnx_pythia1-4b
# 19        pythia1-4b        0.0  load_times               onnx_pythia1-4b
# 20               NaN        NaN      runall               onnx_pythia1-4b
# 21         tinyllama        1.0  load_times                onnx_tinyllama
# 22         tinyllama        0.0  load_times                onnx_tinyllama
# 23               NaN        NaN      runall                onnx_tinyllama
# 24  codeparrot-small        1.0  load_times         onnx_codeparrot-small
# 25  codeparrot-small        0.0  load_times         onnx_codeparrot-small
# 26               NaN        NaN      runall         onnx_codeparrot-small
# 27       pythia-410m        1.0  load_times              onnx_pythia-410m
# 28       pythia-410m        0.0  load_times              onnx_pythia-410m
# 29               NaN        NaN      runall              onnx_pythia-410m
# 30               NaN        NaN      runall               onnx_error_phi2
# 31               NaN        NaN      runall             torchscript_START
# 32        pythia1-4b        1.0  load_times        torchscript_pythia1-4b
# 33        pythia1-4b        0.0  load_times        torchscript_pythia1-4b
# 34               NaN        NaN      runall        torchscript_pythia1-4b
# 35         tinyllama        1.0  load_times         torchscript_tinyllama
# 36         tinyllama        0.0  load_times         torchscript_tinyllama
# 37               NaN        NaN      runall         torchscript_tinyllama
# 38  codeparrot-small        1.0  load_times  torchscript_codeparrot-small
# 39  codeparrot-small        0.0  load_times  torchscript_codeparrot-small
# 40               NaN        NaN      runall  torchscript_codeparrot-small
# 41       pythia-410m        1.0  load_times       torchscript_pythia-410m
# 42       pythia-410m        0.0  load_times       torchscript_pythia-410m
# 43               NaN        NaN      runall       torchscript_pythia-410m
# 44        error_phi2        1.0  load_times        torchscript_error_phi2
# 45        error_phi2        0.0  load_times        torchscript_error_phi2
# 46               NaN        NaN      runall        torchscript_error_phi2
# 47               NaN        NaN      runall                    onnx_START
# 48              phi2        1.0  load_times                     onnx_phi2
# 49              phi2        0.0  load_times                     onnx_phi2
# 50               NaN        NaN      runall                     onnx_phi2
# 51               NaN        NaN      runall                   torch_START
# 52              phi2        1.0  load_times                    torch_phi2
# 53              phi2        0.0  load_times                    torch_phi2
# 54               NaN        NaN      runall                    torch_phi2
# 55               NaN        NaN      runall             torchscript_START
# 56              phi2        1.0  load_times              torchscript_phi2
# 57              phi2        0.0  load_times              torchscript_phi2
# 58               NaN        NaN      runall              torchscript_phi2
# 59               NaN        NaN      runall                        finish
#
#          duration                              label_time
# 0             NaN                        -_IDLE_inference
# 1      301.000000                   torch_START_inference
# 2        0.862842                                    None
# 3        1.864365                   torch_pythia1-4b_load
# 4      191.272793              torch_pythia1-4b_inference
# 5        1.145398                                    None
# 6        1.361741                    torch_tinyllama_load
# 7      189.492861               torch_tinyllama_inference
# 8        1.094631                                    None
# 9        0.188577             torch_codeparrot-small_load
# 10      94.716792        torch_codeparrot-small_inference
# 11       1.418073                                    None
# 12       0.593787                  torch_pythia-410m_load
# 13     189.988140             torch_pythia-410m_inference
# 14       0.951462                                    None
# 15       3.456505                   torch_error_phi2_load
# 16     250.592033              torch_error_phi2_inference
# 17       1.000000                    onnx_START_inference
# 18       1.293045                                    None
# 19       7.215888                    onnx_pythia1-4b_load
# 20     536.491067               onnx_pythia1-4b_inference
# 21       1.896322                                    None
# 22       5.346264                     onnx_tinyllama_load
# 23     408.757414                onnx_tinyllama_inference
# 24       1.315983                                    None
# 25       1.408959              onnx_codeparrot-small_load
# 26     192.275058         onnx_codeparrot-small_inference
# 27       0.725283                                    None
# 28       3.732842                   onnx_pythia-410m_load
# 29     448.541875              onnx_pythia-410m_inference
# 30     464.000000               onnx_error_phi2_inference
# 31       1.000000             torchscript_START_inference
# 32       1.307629                                    None
# 33       4.244000             torchscript_pythia1-4b_load
# 34      97.448371        torchscript_pythia1-4b_inference
# 35       1.776044                                    None
# 36       3.297371              torchscript_tinyllama_load
# 37     103.926585         torchscript_tinyllama_inference
# 38       1.582783                                    None
# 39       0.425498       torchscript_codeparrot-small_load
# 40      94.991719  torchscript_codeparrot-small_inference
# 41       1.203822                                    None
# 42       1.072301            torchscript_pythia-410m_load
# 43      97.723877       torchscript_pythia-410m_inference
# 44       0.921375                                    None
# 45       7.889815             torchscript_error_phi2_load
# 46     101.188810        torchscript_error_phi2_inference
# 47  596405.000000                    onnx_START_inference
# 48       0.943662                                    None
# 49      12.954321                          onnx_phi2_load
# 50     794.102017                     onnx_phi2_inference
# 51       0.000000                   torch_START_inference
# 52       1.503720                                    None
# 53       3.548434                         torch_phi2_load
# 54     251.947846                    torch_phi2_inference
# 55       1.000000             torchscript_START_inference
# 56       0.578192                                    None
# 57       6.307156                   torchscript_phi2_load
# 58     101.114652              torchscript_phi2_inference
# 59       1.000000                      -_FINISH_inference

# %%
df.to_csv(processed_dir + 'time_marks.csv', )

# %%
print(general_df['time'].iloc[0])
print(general_df['time'].iloc[-1])
# Out:
# 2024-06-23 16:46:53
# 2024-06-30 15:50:17
