# %% [markdown]
# # Create one dataset for each profiler
#
# - get profiler data organized by each serving configuration
# - run {script}.py to go trough all experiment runs
#
# - Input:
#   - results_*/{profiler data}.csv
# - Output
#   - results_*/processed/{profiler}_processed.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
device = 'gpu'
#all_dir = f"D:/GAISSA/energy-repo/last_repo/june_{device}/"
all_dir = f"D:/GAISSA/energy-repo/last_repo/june_{device}_test/" # change
new_results = f"D:/GAISSA/energy-repo/last_repo/{device}_june_phi2_01/" # change
results_dir = 'results_10/'

# %%
os.chdir(all_dir)

# %%
processed_dir = all_dir + results_dir +"processed/"
try:
    os.mkdir(processed_dir)
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'D:/GAISSA/energy-repo/last_repo/june_gpu_test/results_10/processed/'

# %%
#os.listdir(results_dir)

# %%
ENERGIBRIDGE_SAVE_CSV = 'energibridge_dataset.csv'
NVIDIA_SAVE_CSV = 'nvidia-smi_dataset.csv'
WATTMETER_SAVE_CSV = 'wattmeter_dataset.csv'

# %% [markdown]
# ## nvidia-smi files

# %%
csv_dir = results_dir
os.listdir(csv_dir)
# Out:
# ['energy_codeparrot-small_onnx.csv',
#  'energy_codeparrot-small_torch.csv',
#  'energy_codeparrot-small_torchscript.csv',
#  'energy_idle.csv',
#  'energy_phi2_onnx.csv',
#  'energy_phi2_torch.csv',
#  'energy_phi2_torchscript.csv',
#  'energy_pythia-410m_onnx.csv',
#  'energy_pythia-410m_torch.csv',
#  'energy_pythia-410m_torchscript.csv',
#  'energy_pythia1-4b_onnx.csv',
#  'energy_pythia1-4b_torch.csv',
#  'energy_pythia1-4b_torchscript.csv',
#  'energy_tinyllama_onnx.csv',
#  'energy_tinyllama_torch.csv',
#  'energy_tinyllama_torchscript.csv',
#  'load_times.csv',
#  'nvidia_codeparrot-small_onnx.csv',
#  'nvidia_codeparrot-small_torch.csv',
#  'nvidia_codeparrot-small_torchscript.csv',
#  'nvidia_phi2_onnx.csv',
#  'nvidia_phi2_torch.csv',
#  'nvidia_phi2_torchscript.csv',
#  'nvidia_pythia-410m_onnx.csv',
#  'nvidia_pythia-410m_torch.csv',
#  'nvidia_pythia-410m_torchscript.csv',
#  'nvidia_pythia1-4b_onnx.csv',
#  'nvidia_pythia1-4b_torch.csv',
#  'nvidia_pythia1-4b_torchscript.csv',
#  'nvidia_tinyllama_onnx.csv',
#  'nvidia_tinyllama_torch.csv',
#  'nvidia_tinyllama_torchscript.csv',
#  'out_codeparrot-small_onnx.log',
#  'out_codeparrot-small_torch.log',
#  'out_codeparrot-small_torchscript.log',
#  'out_phi2_onnx.log',
#  'out_phi2_torch.log',
#  'out_phi2_torchscript.log',
#  'out_pythia-410m_onnx.log',
#  'out_pythia-410m_torch.log',
#  'out_pythia-410m_torchscript.log',
#  'out_pythia1-4b_onnx.log',
#  'out_pythia1-4b_torch.log',
#  'out_pythia1-4b_torchscript.log',
#  'out_tinyllama_onnx.log',
#  'out_tinyllama_torch.log',
#  'out_tinyllama_torchscript.log',
#  'processed',
#  'processes.log',
#  'runall_2.out',
#  'runall_timestamps.csv',
#  'server_2306.log',
#  'wattmeter_codeparrot-small_onnx.csv',
#  'wattmeter_codeparrot-small_torch.csv',
#  'wattmeter_codeparrot-small_torchscript.csv',
#  'wattmeter_phi2_onnx.csv',
#  'wattmeter_phi2_torch.csv',
#  'wattmeter_phi2_torchscript.csv',
#  'wattmeter_pythia-410m_onnx.csv',
#  'wattmeter_pythia-410m_torch.csv',
#  'wattmeter_pythia-410m_torchscript.csv',
#  'wattmeter_pythia1-4b_onnx.csv',
#  'wattmeter_pythia1-4b_torch.csv',
#  'wattmeter_pythia1-4b_torchscript.csv',
#  'wattmeter_tinyllama_onnx.csv',
#  'wattmeter_tinyllama_torch.csv',
#  'wattmeter_tinyllama_torchscript.csv']

# %%
## add runtime and model columns

# Initialize an empty list to hold dataframes
dfs = []

for file in os.listdir(csv_dir):
    if file.endswith('.csv') and file.startswith('nvidia'):
        print(f"file: {file}")
        
        # Parse the filename to get runtime and model
        #filename_parts = file.split('_')
        #runtime = filename_parts[1]
        #model = filename_parts[2].split('.')[0]

        filename_parts = file.split('_')
        print(filename_parts)
        model = filename_parts[1].split('_')[0]
        print(model)
        #print(filename_parts[1].split('_')[1])
        #model = models[0]
        #runtime_model = filename_parts[1].split('_')
        runtime = filename_parts[-1].split('.')[0]
        print(runtime)
        #model = runtime_model[1].split('.')[0]  # Split again to remove '.csv'
        
        # Load the CSV file into a dataframe
        df = pd.read_csv(os.path.join(csv_dir, file))

        # Add 'runtime' and 'model' columns
        df['runtime'] = runtime
        df['model'] = model

        # Append the dataframe to the list
        dfs.append(df)
        #print(df.columns)

# Concatenate all dataframes in the list
nvidia_df = pd.concat(dfs, ignore_index=True)

# Display the combined dataframe
nvidia_df
# Out:
# file: nvidia_codeparrot-small_onnx.csv
# ['nvidia', 'codeparrot-small', 'onnx.csv']
# codeparrot-small
# onnx
# file: nvidia_codeparrot-small_torch.csv
# ['nvidia', 'codeparrot-small', 'torch.csv']
# codeparrot-small
# torch
# file: nvidia_codeparrot-small_torchscript.csv
# ['nvidia', 'codeparrot-small', 'torchscript.csv']
# codeparrot-small
# torchscript
# file: nvidia_phi2_onnx.csv
# ['nvidia', 'phi2', 'onnx.csv']
# phi2
# onnx
# file: nvidia_phi2_torch.csv
# ['nvidia', 'phi2', 'torch.csv']
# phi2
# torch
# file: nvidia_phi2_torchscript.csv
# ['nvidia', 'phi2', 'torchscript.csv']
# phi2
# torchscript
# file: nvidia_pythia-410m_onnx.csv
# ['nvidia', 'pythia-410m', 'onnx.csv']
# pythia-410m
# onnx
# file: nvidia_pythia-410m_torch.csv
# ['nvidia', 'pythia-410m', 'torch.csv']
# pythia-410m
# torch
# file: nvidia_pythia-410m_torchscript.csv
# ['nvidia', 'pythia-410m', 'torchscript.csv']
# pythia-410m
# torchscript
# file: nvidia_pythia1-4b_onnx.csv
# ['nvidia', 'pythia1-4b', 'onnx.csv']
# pythia1-4b
# onnx
# file: nvidia_pythia1-4b_torch.csv
# ['nvidia', 'pythia1-4b', 'torch.csv']
# pythia1-4b
# torch
# file: nvidia_pythia1-4b_torchscript.csv
# ['nvidia', 'pythia1-4b', 'torchscript.csv']
# pythia1-4b
# torchscript
# file: nvidia_tinyllama_onnx.csv
# ['nvidia', 'tinyllama', 'onnx.csv']
# tinyllama
# onnx
# file: nvidia_tinyllama_torch.csv
# ['nvidia', 'tinyllama', 'torch.csv']
# tinyllama
# torch
# file: nvidia_tinyllama_torchscript.csv
# ['nvidia', 'tinyllama', 'torchscript.csv']
# tinyllama
# torchscript
#                      timestamp                      name  utilization.gpu [%]  \
# 0      2024/06/23 17:23:25.840   NVIDIA GeForce RTX 4090                  0 %
# 1      2024/06/23 17:23:25.942   NVIDIA GeForce RTX 4090                  0 %
# 2      2024/06/23 17:23:26.043   NVIDIA GeForce RTX 4090                  0 %
# 3      2024/06/23 17:23:26.144   NVIDIA GeForce RTX 4090                  0 %
# 4      2024/06/23 17:23:26.244   NVIDIA GeForce RTX 4090                  0 %
# ...                        ...                       ...                  ...
# 34913  2024/06/23 17:45:30.198   NVIDIA GeForce RTX 4090                  5 %
# 34914  2024/06/23 17:45:30.299   NVIDIA GeForce RTX 4090                  0 %
# 34915  2024/06/23 17:45:30.400   NVIDIA GeForce RTX 4090                  0 %
# 34916  2024/06/23 17:45:30.501   NVIDIA GeForce RTX 4090                  0 %
# 34917  2024/06/23 17:45:30.601   NVIDIA GeForce RTX 4090                  0 %
#
#        utilization.memory [%]  memory.total [MiB]  memory.used [MiB]  \
# 0                         0 %           24564 MiB          18618 MiB
# 1                         0 %           24564 MiB          18618 MiB
# 2                         0 %           24564 MiB          18618 MiB
# 3                         0 %           24564 MiB          18618 MiB
# 4                         0 %           24564 MiB          18618 MiB
# ...                       ...                 ...                ...
# 34913                     3 %           24564 MiB          13470 MiB
# 34914                     0 %           24564 MiB          13470 MiB
# 34915                     0 %           24564 MiB          13470 MiB
# 34916                     0 %           24564 MiB          13470 MiB
# 34917                     0 %           24564 MiB          13470 MiB
#
#        power.draw [W]  power.max_limit [W]   temperature.gpu      runtime  \
# 0            112.52 W             500.00 W                43         onnx
# 1            101.11 W             500.00 W                42         onnx
# 2             89.70 W             500.00 W                42         onnx
# 3             78.28 W             500.00 W                42         onnx
# 4             78.28 W             500.00 W                42         onnx
# ...               ...                  ...               ...          ...
# 34913         61.21 W             500.00 W                37  torchscript
# 34914         61.22 W             500.00 W                37  torchscript
# 34915         61.24 W             500.00 W                37  torchscript
# 34916         61.22 W             500.00 W                37  torchscript
# 34917         57.83 W             500.00 W                37  torchscript
#
#                   model
# 0      codeparrot-small
# 1      codeparrot-small
# 2      codeparrot-small
# 3      codeparrot-small
# 4      codeparrot-small
# ...                 ...
# 34913         tinyllama
# 34914         tinyllama
# 34915         tinyllama
# 34916         tinyllama
# 34917         tinyllama
#
# [34918 rows x 11 columns]

# %%
os.chdir(new_results)

# %%
## add runtime and model columns

# Initialize an empty list to hold dataframes
dfs = []

for file in os.listdir(csv_dir):
    if file.endswith('.csv') and file.startswith('nvidia'):
        print(f"file: {file}")
        
        # Parse the filename to get runtime and model
        #filename_parts = file.split('_')
        #runtime = filename_parts[1]
        #model = filename_parts[2].split('.')[0]

        filename_parts = file.split('_')
        print(filename_parts)
        model = filename_parts[1].split('_')[0]
        print(model)
        #print(filename_parts[1].split('_')[1])
        #model = models[0]
        #runtime_model = filename_parts[1].split('_')
        runtime = filename_parts[-1].split('.')[0]
        print(runtime)
        #model = runtime_model[1].split('.')[0]  # Split again to remove '.csv'
        
        # Load the CSV file into a dataframe
        df = pd.read_csv(os.path.join(csv_dir, file))

        # Add 'runtime' and 'model' columns
        df['runtime'] = runtime
        df['model'] = model

        # Append the dataframe to the list
        dfs.append(df)
        #print(df.columns)

# Concatenate all dataframes in the list
new_df = pd.concat(dfs, ignore_index=True)

# Display the combined dataframe
new_df
# Out:
# file: nvidia_phi2_onnx.csv
# ['nvidia', 'phi2', 'onnx.csv']
# phi2
# onnx
# file: nvidia_phi2_torch.csv
# ['nvidia', 'phi2', 'torch.csv']
# phi2
# torch
# file: nvidia_phi2_torchscript.csv
# ['nvidia', 'phi2', 'torchscript.csv']
# phi2
# torchscript
#                      timestamp                      name  utilization.gpu [%]  \
# 0      2024/06/30 15:30:42.501   NVIDIA GeForce RTX 4090                  0 %
# 1      2024/06/30 15:30:42.603   NVIDIA GeForce RTX 4090                  0 %
# 2      2024/06/30 15:30:42.704   NVIDIA GeForce RTX 4090                  0 %
# 3      2024/06/30 15:30:42.805   NVIDIA GeForce RTX 4090                  0 %
# 4      2024/06/30 15:30:42.906   NVIDIA GeForce RTX 4090                  0 %
# ...                        ...                       ...                  ...
# 11625  2024/06/30 15:50:15.565   NVIDIA GeForce RTX 4090                  0 %
# 11626  2024/06/30 15:50:15.666   NVIDIA GeForce RTX 4090                  0 %
# 11627  2024/06/30 15:50:15.767   NVIDIA GeForce RTX 4090                  0 %
# 11628  2024/06/30 15:50:15.868   NVIDIA GeForce RTX 4090                  0 %
# 11629  2024/06/30 15:50:15.969   NVIDIA GeForce RTX 4090                  0 %
#
#        utilization.memory [%]  memory.total [MiB]  memory.used [MiB]  \
# 0                         0 %           24564 MiB             83 MiB
# 1                         0 %           24564 MiB             83 MiB
# 2                         0 %           24564 MiB             83 MiB
# 3                         0 %           24564 MiB             83 MiB
# 4                         0 %           24564 MiB             83 MiB
# ...                       ...                 ...                ...
# 11625                     0 %           24564 MiB          22742 MiB
# 11626                     0 %           24564 MiB          22742 MiB
# 11627                     0 %           24564 MiB          22742 MiB
# 11628                     0 %           24564 MiB          22742 MiB
# 11629                     0 %           24564 MiB          22742 MiB
#
#        power.draw [W]  power.max_limit [W]   temperature.gpu      runtime  \
# 0             18.86 W             500.00 W                44         onnx
# 1             18.86 W             500.00 W                44         onnx
# 2             18.86 W             500.00 W                44         onnx
# 3             18.86 W             500.00 W                44         onnx
# 4             18.86 W             500.00 W                44         onnx
# ...               ...                  ...               ...          ...
# 11625         75.69 W             500.00 W                44  torchscript
# 11626         75.61 W             500.00 W                44  torchscript
# 11627         75.64 W             500.00 W                44  torchscript
# 11628         68.14 W             500.00 W                44  torchscript
# 11629         66.55 W             500.00 W                44  torchscript
#
#       model
# 0      phi2
# 1      phi2
# 2      phi2
# 3      phi2
# 4      phi2
# ...     ...
# 11625  phi2
# 11626  phi2
# 11627  phi2
# 11628  phi2
# 11629  phi2
#
# [11630 rows x 11 columns]

# %%
new_df['runtime'].unique()
# Out:
# array(['onnx', 'torch', 'torchscript'], dtype=object)

# %%
nvidia_df.columns
# Out:
# Index(['timestamp', ' name', ' utilization.gpu [%]', ' utilization.memory [%]',
#        ' memory.total [MiB]', ' memory.used [MiB]', ' power.draw [W]',
#        ' power.max_limit [W]', ' temperature.gpu', 'runtime', 'model'],
#       dtype='object')

# %%
def change_model(old,new, model):
    try:
        new = new[new['runtime'] != 'idle']
    
        old = old[old['model'] != model]
    except:
        print("check dfs")
    
    return pd.concat([old, new], )#ignore_index=True

# %%
nvidia_df = change_model(nvidia_df, new_df, "phi2")
nvidia_df
# Out:
#                      timestamp                      name  utilization.gpu [%]  \
# 0      2024/06/23 17:23:25.840   NVIDIA GeForce RTX 4090                  0 %
# 1      2024/06/23 17:23:25.942   NVIDIA GeForce RTX 4090                  0 %
# 2      2024/06/23 17:23:26.043   NVIDIA GeForce RTX 4090                  0 %
# 3      2024/06/23 17:23:26.144   NVIDIA GeForce RTX 4090                  0 %
# 4      2024/06/23 17:23:26.244   NVIDIA GeForce RTX 4090                  0 %
# ...                        ...                       ...                  ...
# 11625  2024/06/30 15:50:15.565   NVIDIA GeForce RTX 4090                  0 %
# 11626  2024/06/30 15:50:15.666   NVIDIA GeForce RTX 4090                  0 %
# 11627  2024/06/30 15:50:15.767   NVIDIA GeForce RTX 4090                  0 %
# 11628  2024/06/30 15:50:15.868   NVIDIA GeForce RTX 4090                  0 %
# 11629  2024/06/30 15:50:15.969   NVIDIA GeForce RTX 4090                  0 %
#
#        utilization.memory [%]  memory.total [MiB]  memory.used [MiB]  \
# 0                         0 %           24564 MiB          18618 MiB
# 1                         0 %           24564 MiB          18618 MiB
# 2                         0 %           24564 MiB          18618 MiB
# 3                         0 %           24564 MiB          18618 MiB
# 4                         0 %           24564 MiB          18618 MiB
# ...                       ...                 ...                ...
# 11625                     0 %           24564 MiB          22742 MiB
# 11626                     0 %           24564 MiB          22742 MiB
# 11627                     0 %           24564 MiB          22742 MiB
# 11628                     0 %           24564 MiB          22742 MiB
# 11629                     0 %           24564 MiB          22742 MiB
#
#        power.draw [W]  power.max_limit [W]   temperature.gpu      runtime  \
# 0            112.52 W             500.00 W                43         onnx
# 1            101.11 W             500.00 W                42         onnx
# 2             89.70 W             500.00 W                42         onnx
# 3             78.28 W             500.00 W                42         onnx
# 4             78.28 W             500.00 W                42         onnx
# ...               ...                  ...               ...          ...
# 11625         75.69 W             500.00 W                44  torchscript
# 11626         75.61 W             500.00 W                44  torchscript
# 11627         75.64 W             500.00 W                44  torchscript
# 11628         68.14 W             500.00 W                44  torchscript
# 11629         66.55 W             500.00 W                44  torchscript
#
#                   model
# 0      codeparrot-small
# 1      codeparrot-small
# 2      codeparrot-small
# 3      codeparrot-small
# 4      codeparrot-small
# ...                 ...
# 11625              phi2
# 11626              phi2
# 11627              phi2
# 11628              phi2
# 11629              phi2
#
# [38312 rows x 11 columns]

# %%
nvidia_df['time'] = pd.to_datetime(nvidia_df['timestamp'],)
nvidia_df.head()
# Out:
#                  timestamp                      name  utilization.gpu [%]  \
# 0  2024/06/23 17:23:25.840   NVIDIA GeForce RTX 4090                  0 %
# 1  2024/06/23 17:23:25.942   NVIDIA GeForce RTX 4090                  0 %
# 2  2024/06/23 17:23:26.043   NVIDIA GeForce RTX 4090                  0 %
# 3  2024/06/23 17:23:26.144   NVIDIA GeForce RTX 4090                  0 %
# 4  2024/06/23 17:23:26.244   NVIDIA GeForce RTX 4090                  0 %
#
#    utilization.memory [%]  memory.total [MiB]  memory.used [MiB]  \
# 0                     0 %           24564 MiB          18618 MiB
# 1                     0 %           24564 MiB          18618 MiB
# 2                     0 %           24564 MiB          18618 MiB
# 3                     0 %           24564 MiB          18618 MiB
# 4                     0 %           24564 MiB          18618 MiB
#
#    power.draw [W]  power.max_limit [W]   temperature.gpu runtime  \
# 0        112.52 W             500.00 W                43    onnx
# 1        101.11 W             500.00 W                42    onnx
# 2         89.70 W             500.00 W                42    onnx
# 3         78.28 W             500.00 W                42    onnx
# 4         78.28 W             500.00 W                42    onnx
#
#               model                    time
# 0  codeparrot-small 2024-06-23 17:23:25.840
# 1  codeparrot-small 2024-06-23 17:23:25.942
# 2  codeparrot-small 2024-06-23 17:23:26.043
# 3  codeparrot-small 2024-06-23 17:23:26.144
# 4  codeparrot-small 2024-06-23 17:23:26.244

# %%
## organize columns
columns = list(nvidia_df.columns)
new_order = columns[:2] + ['time','runtime', 'model'] + columns[2:-3]
nvidia_df = nvidia_df[new_order]

# %%
nvidia_df.head()
# Out:
#                  timestamp                      name                    time  \
# 0  2024/06/23 17:23:25.840   NVIDIA GeForce RTX 4090 2024-06-23 17:23:25.840
# 1  2024/06/23 17:23:25.942   NVIDIA GeForce RTX 4090 2024-06-23 17:23:25.942
# 2  2024/06/23 17:23:26.043   NVIDIA GeForce RTX 4090 2024-06-23 17:23:26.043
# 3  2024/06/23 17:23:26.144   NVIDIA GeForce RTX 4090 2024-06-23 17:23:26.144
# 4  2024/06/23 17:23:26.244   NVIDIA GeForce RTX 4090 2024-06-23 17:23:26.244
#
#   runtime             model  utilization.gpu [%]  utilization.memory [%]  \
# 0    onnx  codeparrot-small                  0 %                     0 %
# 1    onnx  codeparrot-small                  0 %                     0 %
# 2    onnx  codeparrot-small                  0 %                     0 %
# 3    onnx  codeparrot-small                  0 %                     0 %
# 4    onnx  codeparrot-small                  0 %                     0 %
#
#    memory.total [MiB]  memory.used [MiB]  power.draw [W]  power.max_limit [W]  \
# 0           24564 MiB          18618 MiB        112.52 W             500.00 W
# 1           24564 MiB          18618 MiB        101.11 W             500.00 W
# 2           24564 MiB          18618 MiB         89.70 W             500.00 W
# 3           24564 MiB          18618 MiB         78.28 W             500.00 W
# 4           24564 MiB          18618 MiB         78.28 W             500.00 W
#
#     temperature.gpu
# 0                43
# 1                42
# 2                42
# 3                42
# 4                42

# %%
nvidia_df.columns
# Out:
# Index(['timestamp', ' name', 'time', 'runtime', 'model',
#        ' utilization.gpu [%]', ' utilization.memory [%]',
#        ' memory.total [MiB]', ' memory.used [MiB]', ' power.draw [W]',
#        ' power.max_limit [W]', ' temperature.gpu'],
#       dtype='object')

# %%
columns_to_int = [' utilization.gpu [%]', ' utilization.memory [%]',
       ' memory.total [MiB]', ' memory.used [MiB]', ]

for column in columns_to_int:
    nvidia_df[column] = nvidia_df[column].str.replace(r'\D', '', regex=True).astype(int)

# %%
columns_to_float = [' power.draw [W]', ' power.max_limit [W]']

for column in columns_to_float:
    #df[column] = df[column].str.replace(r'[^\d.]+', '', regex=True).astype(float)
    #df[column] = df[column].str.replace(r'\D', '', regex=True).astype(float)
    nvidia_df[column] = nvidia_df[column].str.replace(r'[^\d.]+', '', regex=True).astype(float)
#power.draw [W], power.max_limit [W]

# %%
# verify no % columns and dont have strings on it 
nvidia_df.head()
# Out:
#                  timestamp                      name                    time  \
# 0  2024/06/23 17:23:25.840   NVIDIA GeForce RTX 4090 2024-06-23 17:23:25.840
# 1  2024/06/23 17:23:25.942   NVIDIA GeForce RTX 4090 2024-06-23 17:23:25.942
# 2  2024/06/23 17:23:26.043   NVIDIA GeForce RTX 4090 2024-06-23 17:23:26.043
# 3  2024/06/23 17:23:26.144   NVIDIA GeForce RTX 4090 2024-06-23 17:23:26.144
# 4  2024/06/23 17:23:26.244   NVIDIA GeForce RTX 4090 2024-06-23 17:23:26.244
#
#   runtime             model   utilization.gpu [%]   utilization.memory [%]  \
# 0    onnx  codeparrot-small                     0                        0
# 1    onnx  codeparrot-small                     0                        0
# 2    onnx  codeparrot-small                     0                        0
# 3    onnx  codeparrot-small                     0                        0
# 4    onnx  codeparrot-small                     0                        0
#
#     memory.total [MiB]   memory.used [MiB]   power.draw [W]  \
# 0                24564               18618           112.52
# 1                24564               18618           101.11
# 2                24564               18618            89.70
# 3                24564               18618            78.28
# 4                24564               18618            78.28
#
#     power.max_limit [W]   temperature.gpu
# 0                 500.0                43
# 1                 500.0                42
# 2                 500.0                42
# 3                 500.0                42
# 4                 500.0                42

# %%
processed_dir
# Out:
# 'D:/GAISSA/energy-repo/last_repo/june_gpu_test/results_10/processed/'

# %%
nvidia_df = nvidia_df.sort_values(by='time', ascending=True)
nvidia_df.to_csv(processed_dir+NVIDIA_SAVE_CSV, index=False)
print(f"Results saved in {processed_dir+NVIDIA_SAVE_CSV}")
# Out:
# Results saved in D:/GAISSA/energy-repo/last_repo/june_gpu_test/results_10/processed/nvidia-smi_dataset.csv

# %%
nvidia_df.columns
# Out:
# Index(['timestamp', ' name', 'time', 'runtime', 'model',
#        ' utilization.gpu [%]', ' utilization.memory [%]',
#        ' memory.total [MiB]', ' memory.used [MiB]', ' power.draw [W]',
#        ' power.max_limit [W]', ' temperature.gpu'],
#       dtype='object')

# %%
#selected_columns = ['time','runtime','model','CPU_ENERGY (J)', 'TOTAL_MEMORY', 'TOTAL_SWAP', 'USED_MEMORY', 'USED_SWAP']
selected_columns = ['time','runtime','model',' utilization.gpu [%]',' utilization.memory [%]',' memory.total [MiB]',' memory.used [MiB]',' power.draw [W]',' power.max_limit [W]',' temperature.gpu']
energi_selected = nvidia_df[selected_columns].copy()

# %%
energi_selected.head()
# Out:
#                          time runtime       model   utilization.gpu [%]  \
# 24876 2024-06-23 16:51:54.356   torch  pythia1-4b                     0
# 24877 2024-06-23 16:51:54.458   torch  pythia1-4b                     0
# 24878 2024-06-23 16:51:54.559   torch  pythia1-4b                     0
# 24879 2024-06-23 16:51:54.661   torch  pythia1-4b                     0
# 24880 2024-06-23 16:51:54.762   torch  pythia1-4b                     0
#
#         utilization.memory [%]   memory.total [MiB]   memory.used [MiB]  \
# 24876                        0                24564                  83
# 24877                        0                24564                  83
# 24878                        0                24564                  83
# 24879                        0                24564                  83
# 24880                        0                24564                  83
#
#         power.draw [W]   power.max_limit [W]   temperature.gpu
# 24876            18.96                 500.0                40
# 24877            18.94                 500.0                40
# 24878            18.95                 500.0                40
# 24879            18.95                 500.0                40
# 24880            18.95                 500.0                40

# %%
energi_selected['label'] = energi_selected['runtime'] + '_'+energi_selected['model']

# %%
 energi_selected['label'].unique()
# Out:
# array(['torch_pythia1-4b', 'torch_tinyllama', 'torch_codeparrot-small',
#        'torch_pythia-410m', 'onnx_pythia1-4b', 'onnx_tinyllama',
#        'onnx_codeparrot-small', 'onnx_pythia-410m',
#        'torchscript_pythia1-4b', 'torchscript_tinyllama',
#        'torchscript_codeparrot-small', 'torchscript_pythia-410m',
#        'onnx_phi2', 'torch_phi2', 'torchscript_phi2'], dtype=object)

# %%
energi_selected.columns
# Out:
# Index(['time', 'runtime', 'model', ' utilization.gpu [%]',
#        ' utilization.memory [%]', ' memory.total [MiB]', ' memory.used [MiB]',
#        ' power.draw [W]', ' power.max_limit [W]', ' temperature.gpu', 'label'],
#       dtype='object')

# %%
energi_selected['used_memory_pct_mib'] = energi_selected[' memory.used [MiB]'] / energi_selected[' memory.total [MiB]'] *100
energi_selected
# Out:
#                          time      runtime       model   utilization.gpu [%]  \
# 24876 2024-06-23 16:51:54.356        torch  pythia1-4b                     0
# 24877 2024-06-23 16:51:54.458        torch  pythia1-4b                     0
# 24878 2024-06-23 16:51:54.559        torch  pythia1-4b                     0
# 24879 2024-06-23 16:51:54.661        torch  pythia1-4b                     0
# 24880 2024-06-23 16:51:54.762        torch  pythia1-4b                     0
# ...                       ...          ...         ...                   ...
# 11625 2024-06-30 15:50:15.565  torchscript        phi2                     0
# 11626 2024-06-30 15:50:15.666  torchscript        phi2                     0
# 11627 2024-06-30 15:50:15.767  torchscript        phi2                     0
# 11628 2024-06-30 15:50:15.868  torchscript        phi2                     0
# 11629 2024-06-30 15:50:15.969  torchscript        phi2                     0
#
#         utilization.memory [%]   memory.total [MiB]   memory.used [MiB]  \
# 24876                        0                24564                  83
# 24877                        0                24564                  83
# 24878                        0                24564                  83
# 24879                        0                24564                  83
# 24880                        0                24564                  83
# ...                        ...                  ...                 ...
# 11625                        0                24564               22742
# 11626                        0                24564               22742
# 11627                        0                24564               22742
# 11628                        0                24564               22742
# 11629                        0                24564               22742
#
#         power.draw [W]   power.max_limit [W]   temperature.gpu  \
# 24876            18.96                 500.0                40
# 24877            18.94                 500.0                40
# 24878            18.95                 500.0                40
# 24879            18.95                 500.0                40
# 24880            18.95                 500.0                40
# ...                ...                   ...               ...
# 11625            75.69                 500.0                44
# 11626            75.61                 500.0                44
# 11627            75.64                 500.0                44
# 11628            68.14                 500.0                44
# 11629            66.55                 500.0                44
#
#                   label  used_memory_pct_mib
# 24876  torch_pythia1-4b             0.337893
# 24877  torch_pythia1-4b             0.337893
# 24878  torch_pythia1-4b             0.337893
# 24879  torch_pythia1-4b             0.337893
# 24880  torch_pythia1-4b             0.337893
# ...                 ...                  ...
# 11625  torchscript_phi2            92.582641
# 11626  torchscript_phi2            92.582641
# 11627  torchscript_phi2            92.582641
# 11628  torchscript_phi2            92.582641
# 11629  torchscript_phi2            92.582641
#
# [38312 rows x 12 columns]

# %%
def calculate_statistics(df, columns, column_types, label_column):
    new_df = df.copy()
    
    # Iterate over the columns and their types
    for col, col_type in zip(columns, column_types):
        # Calculate the average based on the label_column
        if col_type == 'average':
            new_df['avg_' + col] = new_df.groupby(label_column)[col].transform('mean')
        # Calculate the difference, then average
        elif col_type == 'diff_then_average':
            new_df['diff_' + col] = new_df[col].diff()
            new_df['avg_diff_' + col] = new_df.groupby(label_column)['diff_' + col].transform('mean')
        # Calculate average minus last average
        elif col_type == 'average_minus_last_average':
            new_df['avg_' + col] = new_df.groupby(label_column)[col].transform('mean')
            #new_df['avg_minus_last_' + col] = new_df.groupby(label_column)['avg_' + col].diff()

            
            # Conditionally set the value for the first label
            #first_label_mask = new_df[label_column] != new_df[label_column].shift()
            #new_df.loc[first_label_mask, 'avg_minus_last_' + col] = new_df['avg_' + col]

            #pass
        
    return new_df

# %%
#numeric_columns = ['CPU_ENERGY (J)', 'TOTAL_MEMORY', 'TOTAL_SWAP', 'USED_MEMORY', 'USED_SWAP']
numeric_columns = [' utilization.gpu [%]',' utilization.memory [%]',' memory.used [MiB]',' power.draw [W]',' temperature.gpu','used_memory_pct_mib']

column_types = ['average', 'average', 'average', 'average','average', 'average']
#'average', 'diff_then_average', 'average_minus_last_average'
df_with_metrics = calculate_statistics(energi_selected,numeric_columns,column_types,'label')

# %%
df_with_metrics
# Out:
#                          time      runtime       model   utilization.gpu [%]  \
# 24876 2024-06-23 16:51:54.356        torch  pythia1-4b                     0
# 24877 2024-06-23 16:51:54.458        torch  pythia1-4b                     0
# 24878 2024-06-23 16:51:54.559        torch  pythia1-4b                     0
# 24879 2024-06-23 16:51:54.661        torch  pythia1-4b                     0
# 24880 2024-06-23 16:51:54.762        torch  pythia1-4b                     0
# ...                       ...          ...         ...                   ...
# 11625 2024-06-30 15:50:15.565  torchscript        phi2                     0
# 11626 2024-06-30 15:50:15.666  torchscript        phi2                     0
# 11627 2024-06-30 15:50:15.767  torchscript        phi2                     0
# 11628 2024-06-30 15:50:15.868  torchscript        phi2                     0
# 11629 2024-06-30 15:50:15.969  torchscript        phi2                     0
#
#         utilization.memory [%]   memory.total [MiB]   memory.used [MiB]  \
# 24876                        0                24564                  83
# 24877                        0                24564                  83
# 24878                        0                24564                  83
# 24879                        0                24564                  83
# 24880                        0                24564                  83
# ...                        ...                  ...                 ...
# 11625                        0                24564               22742
# 11626                        0                24564               22742
# 11627                        0                24564               22742
# 11628                        0                24564               22742
# 11629                        0                24564               22742
#
#         power.draw [W]   power.max_limit [W]   temperature.gpu  \
# 24876            18.96                 500.0                40
# 24877            18.94                 500.0                40
# 24878            18.95                 500.0                40
# 24879            18.95                 500.0                40
# 24880            18.95                 500.0                40
# ...                ...                   ...               ...
# 11625            75.69                 500.0                44
# 11626            75.61                 500.0                44
# 11627            75.64                 500.0                44
# 11628            68.14                 500.0                44
# 11629            66.55                 500.0                44
#
#                   label  used_memory_pct_mib  avg_ utilization.gpu [%]  \
# 24876  torch_pythia1-4b             0.337893                 74.532744
# 24877  torch_pythia1-4b             0.337893                 74.532744
# 24878  torch_pythia1-4b             0.337893                 74.532744
# 24879  torch_pythia1-4b             0.337893                 74.532744
# 24880  torch_pythia1-4b             0.337893                 74.532744
# ...                 ...                  ...                       ...
# 11625  torchscript_phi2            92.582641                  5.525725
# 11626  torchscript_phi2            92.582641                  5.525725
# 11627  torchscript_phi2            92.582641                  5.525725
# 11628  torchscript_phi2            92.582641                  5.525725
# 11629  torchscript_phi2            92.582641                  5.525725
#
#        avg_ utilization.memory [%]  avg_ memory.used [MiB]  \
# 24876                    66.995322             6070.442827
# 24877                    66.995322             6070.442827
# 24878                    66.995322             6070.442827
# 24879                    66.995322             6070.442827
# 24880                    66.995322             6070.442827
# ...                            ...                     ...
# 11625                     2.413471            22402.379794
# 11626                     2.413471            22402.379794
# 11627                     2.413471            22402.379794
# 11628                     2.413471            22402.379794
# 11629                     2.413471            22402.379794
#
#        avg_ power.draw [W]  avg_ temperature.gpu  avg_used_memory_pct_mib
# 24876           156.280691             48.241164                24.712762
# 24877           156.280691             48.241164                24.712762
# 24878           156.280691             48.241164                24.712762
# 24879           156.280691             48.241164                24.712762
# 24880           156.280691             48.241164                24.712762
# ...                    ...                   ...                      ...
# 11625            74.830271             47.824135                91.200048
# 11626            74.830271             47.824135                91.200048
# 11627            74.830271             47.824135                91.200048
# 11628            74.830271             47.824135                91.200048
# 11629            74.830271             47.824135                91.200048
#
# [38312 rows x 18 columns]

# %%
## get duration from first instance of label = runtime_model until first of other

def add_durations_groupby(df, time_col,groupby_col,):
    new_df = df.copy()
    new_df['config_duration' ] = new_df.groupby(groupby_col)[time_col].transform(lambda x: pd.to_datetime(x).max() - pd.to_datetime(x).min())
    #new_df['sum_time_config'] = pd.to_datetime(new['timestamp'],)
    #new_df['config_duration' ] = new_df['config_duration' ].total_seconds()
    new_df['config_duration' ] = new_df['config_duration'].dt.total_seconds()
    return new_df

# %%
df_with_duration = add_durations_groupby(df_with_metrics,'time','label')
#avg_ power.draw [W]

# %%
df_with_duration.iloc[0]['config_duration']
# Out:
# 193.638

# %%
df_with_duration
# Out:
#                          time      runtime       model   utilization.gpu [%]  \
# 24876 2024-06-23 16:51:54.356        torch  pythia1-4b                     0
# 24877 2024-06-23 16:51:54.458        torch  pythia1-4b                     0
# 24878 2024-06-23 16:51:54.559        torch  pythia1-4b                     0
# 24879 2024-06-23 16:51:54.661        torch  pythia1-4b                     0
# 24880 2024-06-23 16:51:54.762        torch  pythia1-4b                     0
# ...                       ...          ...         ...                   ...
# 11625 2024-06-30 15:50:15.565  torchscript        phi2                     0
# 11626 2024-06-30 15:50:15.666  torchscript        phi2                     0
# 11627 2024-06-30 15:50:15.767  torchscript        phi2                     0
# 11628 2024-06-30 15:50:15.868  torchscript        phi2                     0
# 11629 2024-06-30 15:50:15.969  torchscript        phi2                     0
#
#         utilization.memory [%]   memory.total [MiB]   memory.used [MiB]  \
# 24876                        0                24564                  83
# 24877                        0                24564                  83
# 24878                        0                24564                  83
# 24879                        0                24564                  83
# 24880                        0                24564                  83
# ...                        ...                  ...                 ...
# 11625                        0                24564               22742
# 11626                        0                24564               22742
# 11627                        0                24564               22742
# 11628                        0                24564               22742
# 11629                        0                24564               22742
#
#         power.draw [W]   power.max_limit [W]   temperature.gpu  \
# 24876            18.96                 500.0                40
# 24877            18.94                 500.0                40
# 24878            18.95                 500.0                40
# 24879            18.95                 500.0                40
# 24880            18.95                 500.0                40
# ...                ...                   ...               ...
# 11625            75.69                 500.0                44
# 11626            75.61                 500.0                44
# 11627            75.64                 500.0                44
# 11628            68.14                 500.0                44
# 11629            66.55                 500.0                44
#
#                   label  used_memory_pct_mib  avg_ utilization.gpu [%]  \
# 24876  torch_pythia1-4b             0.337893                 74.532744
# 24877  torch_pythia1-4b             0.337893                 74.532744
# 24878  torch_pythia1-4b             0.337893                 74.532744
# 24879  torch_pythia1-4b             0.337893                 74.532744
# 24880  torch_pythia1-4b             0.337893                 74.532744
# ...                 ...                  ...                       ...
# 11625  torchscript_phi2            92.582641                  5.525725
# 11626  torchscript_phi2            92.582641                  5.525725
# 11627  torchscript_phi2            92.582641                  5.525725
# 11628  torchscript_phi2            92.582641                  5.525725
# 11629  torchscript_phi2            92.582641                  5.525725
#
#        avg_ utilization.memory [%]  avg_ memory.used [MiB]  \
# 24876                    66.995322             6070.442827
# 24877                    66.995322             6070.442827
# 24878                    66.995322             6070.442827
# 24879                    66.995322             6070.442827
# 24880                    66.995322             6070.442827
# ...                            ...                     ...
# 11625                     2.413471            22402.379794
# 11626                     2.413471            22402.379794
# 11627                     2.413471            22402.379794
# 11628                     2.413471            22402.379794
# 11629                     2.413471            22402.379794
#
#        avg_ power.draw [W]  avg_ temperature.gpu  avg_used_memory_pct_mib  \
# 24876           156.280691             48.241164                24.712762
# 24877           156.280691             48.241164                24.712762
# 24878           156.280691             48.241164                24.712762
# 24879           156.280691             48.241164                24.712762
# 24880           156.280691             48.241164                24.712762
# ...                    ...                   ...                      ...
# 11625            74.830271             47.824135                91.200048
# 11626            74.830271             47.824135                91.200048
# 11627            74.830271             47.824135                91.200048
# 11628            74.830271             47.824135                91.200048
# 11629            74.830271             47.824135                91.200048
#
#        config_duration
# 24876          193.638
# 24877          193.638
# 24878          193.638
# 24879          193.638
# 24880          193.638
# ...                ...
# 11625          107.820
# 11626          107.820
# 11627          107.820
# 11628          107.820
# 11629          107.820
#
# [38312 rows x 19 columns]

# %%
## add energy from load and time-t
df_with_duration['energy'] =  df_with_duration['avg_ power.draw [W]']*df_with_duration['config_duration']

# %%
df_with_duration
# Out:
#                          time      runtime       model   utilization.gpu [%]  \
# 24876 2024-06-23 16:51:54.356        torch  pythia1-4b                     0
# 24877 2024-06-23 16:51:54.458        torch  pythia1-4b                     0
# 24878 2024-06-23 16:51:54.559        torch  pythia1-4b                     0
# 24879 2024-06-23 16:51:54.661        torch  pythia1-4b                     0
# 24880 2024-06-23 16:51:54.762        torch  pythia1-4b                     0
# ...                       ...          ...         ...                   ...
# 11625 2024-06-30 15:50:15.565  torchscript        phi2                     0
# 11626 2024-06-30 15:50:15.666  torchscript        phi2                     0
# 11627 2024-06-30 15:50:15.767  torchscript        phi2                     0
# 11628 2024-06-30 15:50:15.868  torchscript        phi2                     0
# 11629 2024-06-30 15:50:15.969  torchscript        phi2                     0
#
#         utilization.memory [%]   memory.total [MiB]   memory.used [MiB]  \
# 24876                        0                24564                  83
# 24877                        0                24564                  83
# 24878                        0                24564                  83
# 24879                        0                24564                  83
# 24880                        0                24564                  83
# ...                        ...                  ...                 ...
# 11625                        0                24564               22742
# 11626                        0                24564               22742
# 11627                        0                24564               22742
# 11628                        0                24564               22742
# 11629                        0                24564               22742
#
#         power.draw [W]   power.max_limit [W]   temperature.gpu  \
# 24876            18.96                 500.0                40
# 24877            18.94                 500.0                40
# 24878            18.95                 500.0                40
# 24879            18.95                 500.0                40
# 24880            18.95                 500.0                40
# ...                ...                   ...               ...
# 11625            75.69                 500.0                44
# 11626            75.61                 500.0                44
# 11627            75.64                 500.0                44
# 11628            68.14                 500.0                44
# 11629            66.55                 500.0                44
#
#                   label  used_memory_pct_mib  avg_ utilization.gpu [%]  \
# 24876  torch_pythia1-4b             0.337893                 74.532744
# 24877  torch_pythia1-4b             0.337893                 74.532744
# 24878  torch_pythia1-4b             0.337893                 74.532744
# 24879  torch_pythia1-4b             0.337893                 74.532744
# 24880  torch_pythia1-4b             0.337893                 74.532744
# ...                 ...                  ...                       ...
# 11625  torchscript_phi2            92.582641                  5.525725
# 11626  torchscript_phi2            92.582641                  5.525725
# 11627  torchscript_phi2            92.582641                  5.525725
# 11628  torchscript_phi2            92.582641                  5.525725
# 11629  torchscript_phi2            92.582641                  5.525725
#
#        avg_ utilization.memory [%]  avg_ memory.used [MiB]  \
# 24876                    66.995322             6070.442827
# 24877                    66.995322             6070.442827
# 24878                    66.995322             6070.442827
# 24879                    66.995322             6070.442827
# 24880                    66.995322             6070.442827
# ...                            ...                     ...
# 11625                     2.413471            22402.379794
# 11626                     2.413471            22402.379794
# 11627                     2.413471            22402.379794
# 11628                     2.413471            22402.379794
# 11629                     2.413471            22402.379794
#
#        avg_ power.draw [W]  avg_ temperature.gpu  avg_used_memory_pct_mib  \
# 24876           156.280691             48.241164                24.712762
# 24877           156.280691             48.241164                24.712762
# 24878           156.280691             48.241164                24.712762
# 24879           156.280691             48.241164                24.712762
# 24880           156.280691             48.241164                24.712762
# ...                    ...                   ...                      ...
# 11625            74.830271             47.824135                91.200048
# 11626            74.830271             47.824135                91.200048
# 11627            74.830271             47.824135                91.200048
# 11628            74.830271             47.824135                91.200048
# 11629            74.830271             47.824135                91.200048
#
#        config_duration        energy
# 24876          193.638  30261.880496
# 24877          193.638  30261.880496
# 24878          193.638  30261.880496
# 24879          193.638  30261.880496
# 24880          193.638  30261.880496
# ...                ...           ...
# 11625          107.820   8068.199850
# 11626          107.820   8068.199850
# 11627          107.820   8068.199850
# 11628          107.820   8068.199850
# 11629          107.820   8068.199850
#
# [38312 rows x 20 columns]

# %%
df_with_duration.columns
# Out:
# Index(['time', 'runtime', 'model', ' utilization.gpu [%]',
#        ' utilization.memory [%]', ' memory.total [MiB]', ' memory.used [MiB]',
#        ' power.draw [W]', ' power.max_limit [W]', ' temperature.gpu', 'label',
#        'used_memory_pct_mib', 'avg_ utilization.gpu [%]',
#        'avg_ utilization.memory [%]', 'avg_ memory.used [MiB]',
#        'avg_ power.draw [W]', 'avg_ temperature.gpu',
#        'avg_used_memory_pct_mib', 'config_duration', 'energy'],
#       dtype='object')

# %%
df_with_duration.rename(columns={'avg_ temperature.gpu': 'avg_temperature_gpu_config'}, inplace=True)
df_with_duration.rename(columns={'avg_ utilization.gpu [%]': 'avg_utilization_gpu_config'}, inplace=True)
df_with_duration.rename(columns={'avg_ utilization.memory [%]': 'avg_utilization_memory_config'}, inplace=True)
df_with_duration.rename(columns={'avg_ memory.used [MiB]': 'avg_memory_used_config'}, inplace=True)
df_with_duration.rename(columns={'avg_ power.draw [W]': 'avg_power_draw_config'}, inplace=True)


df_with_duration
# Out:
#                          time      runtime       model   utilization.gpu [%]  \
# 24876 2024-06-23 16:51:54.356        torch  pythia1-4b                     0
# 24877 2024-06-23 16:51:54.458        torch  pythia1-4b                     0
# 24878 2024-06-23 16:51:54.559        torch  pythia1-4b                     0
# 24879 2024-06-23 16:51:54.661        torch  pythia1-4b                     0
# 24880 2024-06-23 16:51:54.762        torch  pythia1-4b                     0
# ...                       ...          ...         ...                   ...
# 11625 2024-06-30 15:50:15.565  torchscript        phi2                     0
# 11626 2024-06-30 15:50:15.666  torchscript        phi2                     0
# 11627 2024-06-30 15:50:15.767  torchscript        phi2                     0
# 11628 2024-06-30 15:50:15.868  torchscript        phi2                     0
# 11629 2024-06-30 15:50:15.969  torchscript        phi2                     0
#
#         utilization.memory [%]   memory.total [MiB]   memory.used [MiB]  \
# 24876                        0                24564                  83
# 24877                        0                24564                  83
# 24878                        0                24564                  83
# 24879                        0                24564                  83
# 24880                        0                24564                  83
# ...                        ...                  ...                 ...
# 11625                        0                24564               22742
# 11626                        0                24564               22742
# 11627                        0                24564               22742
# 11628                        0                24564               22742
# 11629                        0                24564               22742
#
#         power.draw [W]   power.max_limit [W]   temperature.gpu  \
# 24876            18.96                 500.0                40
# 24877            18.94                 500.0                40
# 24878            18.95                 500.0                40
# 24879            18.95                 500.0                40
# 24880            18.95                 500.0                40
# ...                ...                   ...               ...
# 11625            75.69                 500.0                44
# 11626            75.61                 500.0                44
# 11627            75.64                 500.0                44
# 11628            68.14                 500.0                44
# 11629            66.55                 500.0                44
#
#                   label  used_memory_pct_mib  avg_utilization_gpu_config  \
# 24876  torch_pythia1-4b             0.337893                   74.532744
# 24877  torch_pythia1-4b             0.337893                   74.532744
# 24878  torch_pythia1-4b             0.337893                   74.532744
# 24879  torch_pythia1-4b             0.337893                   74.532744
# 24880  torch_pythia1-4b             0.337893                   74.532744
# ...                 ...                  ...                         ...
# 11625  torchscript_phi2            92.582641                    5.525725
# 11626  torchscript_phi2            92.582641                    5.525725
# 11627  torchscript_phi2            92.582641                    5.525725
# 11628  torchscript_phi2            92.582641                    5.525725
# 11629  torchscript_phi2            92.582641                    5.525725
#
#        avg_utilization_memory_config  avg_memory_used_config  \
# 24876                      66.995322             6070.442827
# 24877                      66.995322             6070.442827
# 24878                      66.995322             6070.442827
# 24879                      66.995322             6070.442827
# 24880                      66.995322             6070.442827
# ...                              ...                     ...
# 11625                       2.413471            22402.379794
# 11626                       2.413471            22402.379794
# 11627                       2.413471            22402.379794
# 11628                       2.413471            22402.379794
# 11629                       2.413471            22402.379794
#
#        avg_power_draw_config  avg_temperature_gpu_config  \
# 24876             156.280691                   48.241164
# 24877             156.280691                   48.241164
# 24878             156.280691                   48.241164
# 24879             156.280691                   48.241164
# 24880             156.280691                   48.241164
# ...                      ...                         ...
# 11625              74.830271                   47.824135
# 11626              74.830271                   47.824135
# 11627              74.830271                   47.824135
# 11628              74.830271                   47.824135
# 11629              74.830271                   47.824135
#
#        avg_used_memory_pct_mib  config_duration        energy
# 24876                24.712762          193.638  30261.880496
# 24877                24.712762          193.638  30261.880496
# 24878                24.712762          193.638  30261.880496
# 24879                24.712762          193.638  30261.880496
# 24880                24.712762          193.638  30261.880496
# ...                        ...              ...           ...
# 11625                91.200048          107.820   8068.199850
# 11626                91.200048          107.820   8068.199850
# 11627                91.200048          107.820   8068.199850
# 11628                91.200048          107.820   8068.199850
# 11629                91.200048          107.820   8068.199850
#
# [38312 rows x 20 columns]

# %%
# Sort the DataFrame by the 'timestamp' column
save_dir = 'nvidia_processed.csv'
df_with_duration.to_csv(processed_dir+save_dir, index=False)

# %% [markdown]
# ## Verify timestamps match

# %%
runall_df = pd.read_csv(results_dir + 'runall_timestamps.csv', )

# %%
runall_df
# Out:
#              timestamp      runtime   model
# 0  2024-06-30 15:25:42            -    IDLE
# 1  2024-06-30 15:30:42         onnx   START
# 2  2024-06-30 15:44:10         onnx    phi2
# 3  2024-06-30 15:44:10        torch   START
# 4  2024-06-30 15:48:27        torch    phi2
# 5  2024-06-30 15:48:28  torchscript   START
# 6  2024-06-30 15:50:16  torchscript    phi2
# 7  2024-06-30 15:50:17            -  FINISH

# %%
print("from runall:")
print(runall_df['timestamp'].iloc[0])
print(runall_df['timestamp'].iloc[len(runall_df)-1])

print("nvidia")
print(nvidia_df['time'].iloc[0])
print(nvidia_df['time'].iloc[len(nvidia_df)-1])
# Out:
# from runall:
# 2024-06-30 15:25:42
# 2024-06-30 15:50:17
# nvidia
# 2024-06-23 16:51:54.356000
# 2024-06-30 15:50:15.969000
