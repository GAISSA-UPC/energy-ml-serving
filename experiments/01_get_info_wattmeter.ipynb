# %% [markdown]
# # Create one dataset for each profiler
#
# - normalize datasets
#  -

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
device = 'gpu' #CHANGE
#all_dir = f"D:/GAISSA/energy-repo/last_repo/june_{device}/"
all_dir = f"D:/GAISSA/energy-repo/last_repo/june_{device}_test/" # change
new_results = f"D:/GAISSA/energy-repo/last_repo/{device}_june_phi2_01/" # change

results_dir = 'results_9/' #change

# %%
os.chdir(all_dir)

# %%
processed_dir = all_dir + results_dir +"processed/"
try:
    os.mkdir(processed_dir)
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'D:/GAISSA/energy-repo/last_repo/june_gpu_test/results_9/processed/'

# %%
ENERGIBRIDGE_SAVE_CSV = 'energibridge_dataset.csv'
NVIDIA_SAVE_CSV = 'nvidia-smi_dataset.csv'
WATTMETER_SAVE_CSV = 'wattmeter_dataset.csv'

# %%
def change_model(old,new, model):
    try:
        new = new[new['runtime'] != 'idle']
    
        old = old[old['model'] != model]
    except:
        print("check dfs")
    
    return pd.concat([old, new], )#ignore_index=True

# %% [markdown]
# ## wattmeter files

# %%
csv_dir = results_dir
os.listdir(csv_dir)
# Out:
# ['energy_codeparrot-small_onnx.csv',
#  'energy_codeparrot-small_torch.csv',
#  'energy_codeparrot-small_torchscript.csv',
#  'energy_idle.csv',
#  'energy_phi2_onnx.csv',
#  'energy_phi2_torch.csv',
#  'energy_phi2_torchscript.csv',
#  'energy_pythia-410m_onnx.csv',
#  'energy_pythia-410m_torch.csv',
#  'energy_pythia-410m_torchscript.csv',
#  'energy_pythia1-4b_onnx.csv',
#  'energy_pythia1-4b_torch.csv',
#  'energy_pythia1-4b_torchscript.csv',
#  'energy_tinyllama_onnx.csv',
#  'energy_tinyllama_torch.csv',
#  'energy_tinyllama_torchscript.csv',
#  'load_times.csv',
#  'nvidia_codeparrot-small_onnx.csv',
#  'nvidia_codeparrot-small_torch.csv',
#  'nvidia_codeparrot-small_torchscript.csv',
#  'nvidia_phi2_onnx.csv',
#  'nvidia_phi2_torch.csv',
#  'nvidia_phi2_torchscript.csv',
#  'nvidia_pythia-410m_onnx.csv',
#  'nvidia_pythia-410m_torch.csv',
#  'nvidia_pythia-410m_torchscript.csv',
#  'nvidia_pythia1-4b_onnx.csv',
#  'nvidia_pythia1-4b_torch.csv',
#  'nvidia_pythia1-4b_torchscript.csv',
#  'nvidia_tinyllama_onnx.csv',
#  'nvidia_tinyllama_torch.csv',
#  'nvidia_tinyllama_torchscript.csv',
#  'out_codeparrot-small_onnx.log',
#  'out_codeparrot-small_torch.log',
#  'out_codeparrot-small_torchscript.log',
#  'out_phi2_onnx.log',
#  'out_phi2_torch.log',
#  'out_phi2_torchscript.log',
#  'out_pythia-410m_onnx.log',
#  'out_pythia-410m_torch.log',
#  'out_pythia-410m_torchscript.log',
#  'out_pythia1-4b_onnx.log',
#  'out_pythia1-4b_torch.log',
#  'out_pythia1-4b_torchscript.log',
#  'out_tinyllama_onnx.log',
#  'out_tinyllama_torch.log',
#  'out_tinyllama_torchscript.log',
#  'processed',
#  'processes.log',
#  'runall_2.out',
#  'runall_timestamps.csv',
#  'server_1106.log',
#  'wattmeter_codeparrot-small_onnx.csv',
#  'wattmeter_codeparrot-small_torch.csv',
#  'wattmeter_codeparrot-small_torchscript.csv',
#  'wattmeter_phi2_onnx.csv',
#  'wattmeter_phi2_torch.csv',
#  'wattmeter_phi2_torchscript.csv',
#  'wattmeter_pythia-410m_onnx.csv',
#  'wattmeter_pythia-410m_torch.csv',
#  'wattmeter_pythia-410m_torchscript.csv',
#  'wattmeter_pythia1-4b_onnx.csv',
#  'wattmeter_pythia1-4b_torch.csv',
#  'wattmeter_pythia1-4b_torchscript.csv',
#  'wattmeter_tinyllama_onnx.csv',
#  'wattmeter_tinyllama_torch.csv',
#  'wattmeter_tinyllama_torchscript.csv']

# %%
# Initialize an empty list to hold dataframes
dfs = []

for file in os.listdir(csv_dir):
    if file.endswith('.csv') and file.startswith('wattmeter'):
        print(f"file: {file}")
        
        # Parse the filename to get runtime and model
        #filename_parts = file.split('_')
        #runtime = filename_parts[1]
        #model = filename_parts[2].split('.')[0]

        filename_parts = file.split('_')
        print(filename_parts)
        model = filename_parts[1].split('_')[0]
        print(model)
        #print(filename_parts[1].split('_')[1])
        #model = models[0]
        #runtime_model = filename_parts[1].split('_')
        runtime = filename_parts[-1].split('.')[0]
        print(runtime)
        #model = runtime_model[1].split('.')[0]  # Split again to remove '.csv'
        
        # Load the CSV file into a dataframe
        df = pd.read_csv(os.path.join(csv_dir, file))

        # Add 'runtime' and 'model' columns
        df['runtime'] = runtime
        df['model'] = model

        # Append the dataframe to the list
        dfs.append(df)
        #print(df.columns)

# Concatenate all dataframes in the list
wattmeter_df = pd.concat(dfs, ignore_index=True)

# Display the combined dataframe
wattmeter_df
# Out:
# file: wattmeter_codeparrot-small_onnx.csv
# ['wattmeter', 'codeparrot-small', 'onnx.csv']
# codeparrot-small
# onnx
# file: wattmeter_codeparrot-small_torch.csv
# ['wattmeter', 'codeparrot-small', 'torch.csv']
# codeparrot-small
# torch
# file: wattmeter_codeparrot-small_torchscript.csv
# ['wattmeter', 'codeparrot-small', 'torchscript.csv']
# codeparrot-small
# torchscript
# file: wattmeter_phi2_onnx.csv
# ['wattmeter', 'phi2', 'onnx.csv']
# phi2
# onnx
# file: wattmeter_phi2_torch.csv
# ['wattmeter', 'phi2', 'torch.csv']
# phi2
# torch
# file: wattmeter_phi2_torchscript.csv
# ['wattmeter', 'phi2', 'torchscript.csv']
# phi2
# torchscript
# file: wattmeter_pythia-410m_onnx.csv
# ['wattmeter', 'pythia-410m', 'onnx.csv']
# pythia-410m
# onnx
# file: wattmeter_pythia-410m_torch.csv
# ['wattmeter', 'pythia-410m', 'torch.csv']
# pythia-410m
# torch
# file: wattmeter_pythia-410m_torchscript.csv
# ['wattmeter', 'pythia-410m', 'torchscript.csv']
# pythia-410m
# torchscript
# file: wattmeter_pythia1-4b_onnx.csv
# ['wattmeter', 'pythia1-4b', 'onnx.csv']
# pythia1-4b
# onnx
# file: wattmeter_pythia1-4b_torch.csv
# ['wattmeter', 'pythia1-4b', 'torch.csv']
# pythia1-4b
# torch
# file: wattmeter_pythia1-4b_torchscript.csv
# ['wattmeter', 'pythia1-4b', 'torchscript.csv']
# pythia1-4b
# torchscript
# file: wattmeter_tinyllama_onnx.csv
# ['wattmeter', 'tinyllama', 'onnx.csv']
# tinyllama
# onnx
# file: wattmeter_tinyllama_torch.csv
# ['wattmeter', 'tinyllama', 'torch.csv']
# tinyllama
# torch
# file: wattmeter_tinyllama_torchscript.csv
# ['wattmeter', 'tinyllama', 'torchscript.csv']
# tinyllama
# torchscript
#           Wattmetter Timestamp              True timestamp  ID  \
# 0     2024-06-11T18:58:31+0100  2024-06-11 18:58:32.312579   1
# 1     2024-06-11T18:58:32+0100  2024-06-11 18:58:33.457552   1
# 2     2024-06-11T18:58:33+0100  2024-06-11 18:58:34.603030   1
# 3     2024-06-11T18:58:35+0100  2024-06-11 18:58:35.748496   1
# 4     2024-06-11T18:58:36+0100  2024-06-11 18:58:36.899888   1
# ...                        ...                         ...  ..
# 4106  2024-06-11T19:22:24+0100  2024-06-11 19:22:24.952666   1
# 4107  2024-06-11T19:22:25+0100  2024-06-11 19:22:25.529630   1
# 4108  2024-06-11T19:22:26+0100  2024-06-11 19:22:26.109695   1
# 4109  2024-06-11T19:22:26+0100  2024-06-11 19:22:26.697614   1
# 4110  2024-06-11T19:22:27+0100  2024-06-11 19:22:27.277679   1
#
#                 Name  State  Action  Delay  Current  PowerFactor   Phase  \
# 0     Power output 1      1       6   5000      836         0.93  336.99
# 1     Power output 1      1       6   5000      825         0.90  336.41
# 2     Power output 1      1       6   5000      810         0.90  335.39
# 3     Power output 1      1       6   5000      951         1.00  342.74
# 4     Power output 1      1       6   5000     1049         0.96  341.59
# ...              ...    ...     ...    ...      ...          ...     ...
# 4106  Power output 1      1       6   5000      649         0.86  329.36
# 4107  Power output 1      1       6   5000      649         0.86  329.36
# 4108  Power output 1      1       6   5000      649         0.87  327.20
# 4109  Power output 1      1       6   5000      649         0.87  327.20
# 4110  Power output 1      1       6   5000      649         0.87  327.20
#
#       Energy  ReverseEnergy  EnergyNR  ReverseEnergyNR  Load      runtime  \
# 0     128621              0    128621                0   186         onnx
# 1     128621              0    128621                0   178         onnx
# 2     128621              0    128621                0   175         onnx
# 3     128621              0    128621                0   243         onnx
# 4     128621              0    128621                0   239         onnx
# ...      ...            ...       ...              ...   ...          ...
# 4106  128692              0    128692                0   133  torchscript
# 4107  128692              0    128692                0   133  torchscript
# 4108  128692              0    128692                0   135  torchscript
# 4109  128692              0    128692                0   135  torchscript
# 4110  128692              0    128692                0   135  torchscript
#
#                  model
# 0     codeparrot-small
# 1     codeparrot-small
# 2     codeparrot-small
# 3     codeparrot-small
# 4     codeparrot-small
# ...                ...
# 4106         tinyllama
# 4107         tinyllama
# 4108         tinyllama
# 4109         tinyllama
# 4110         tinyllama
#
# [4111 rows x 17 columns]

# %%
os.chdir(new_results)

# %%
# Initialize an empty list to hold dataframes
dfs = []

for file in os.listdir(csv_dir):
    if file.endswith('.csv') and file.startswith('wattmeter'):
        print(f"file: {file}")
        
        # Parse the filename to get runtime and model
        #filename_parts = file.split('_')
        #runtime = filename_parts[1]
        #model = filename_parts[2].split('.')[0]

        filename_parts = file.split('_')
        print(filename_parts)
        model = filename_parts[1].split('_')[0]
        print(model)
        #print(filename_parts[1].split('_')[1])
        #model = models[0]
        #runtime_model = filename_parts[1].split('_')
        runtime = filename_parts[-1].split('.')[0]
        print(runtime)
        #model = runtime_model[1].split('.')[0]  # Split again to remove '.csv'
        
        # Load the CSV file into a dataframe
        df = pd.read_csv(os.path.join(csv_dir, file))

        # Add 'runtime' and 'model' columns
        df['runtime'] = runtime
        df['model'] = model

        # Append the dataframe to the list
        dfs.append(df)
        #print(df.columns)

# Concatenate all dataframes in the list
new_df = pd.concat(dfs, ignore_index=True)

# Display the combined dataframe
new_df
# Out:
# file: wattmeter_phi2_onnx.csv
# ['wattmeter', 'phi2', 'onnx.csv']
# phi2
# onnx
# file: wattmeter_phi2_torch.csv
# ['wattmeter', 'phi2', 'torch.csv']
# phi2
# torch
# file: wattmeter_phi2_torchscript.csv
# ['wattmeter', 'phi2', 'torchscript.csv']
# phi2
# torchscript
#           Wattmetter Timestamp              True timestamp  ID  \
# 0     2024-06-30T15:04:15+0100  2024-06-30 15:04:15.217028   1
# 1     2024-06-30T15:04:17+0100  2024-06-30 15:04:18.018022   1
# 2     2024-06-30T15:04:18+0100  2024-06-30 15:04:18.593624   1
# 3     2024-06-30T15:04:19+0100  2024-06-30 15:04:19.171427   1
# 4     2024-06-30T15:04:19+0100  2024-06-30 15:04:19.746467   1
# ...                        ...                         ...  ..
# 1194  2024-06-30T15:25:37+0100  2024-06-30 15:25:37.998872   1
# 1195  2024-06-30T15:25:38+0100  2024-06-30 15:25:38.575078   1
# 1196  2024-06-30T15:25:39+0100  2024-06-30 15:25:39.155122   1
# 1197  2024-06-30T15:25:39+0100  2024-06-30 15:25:39.743225   1
# 1198  2024-06-30T15:25:40+0100  2024-06-30 15:25:40.322107   1
#
#                 Name  State  Action  Delay  Current  PowerFactor   Phase  \
# 0     Power output 1      1       6   5000      787         0.90  334.80
# 1     Power output 1      1       6   5000      795         0.89  332.78
# 2     Power output 1      1       6   5000     1289         1.00  344.31
# 3     Power output 1      1       6   5000     1289         1.00  344.31
# 4     Power output 1      1       6   5000     1289         1.00  344.31
# ...              ...    ...     ...    ...      ...          ...     ...
# 1194  Power output 1      1       6   5000      831         0.66  324.59
# 1195  Power output 1      1       6   5000      831         0.66  324.59
# 1196  Power output 1      1       6   5000      687         0.82  328.48
# 1197  Power output 1      1       6   5000      687         0.82  328.48
# 1198  Power output 1      1       6   5000      687         0.82  328.48
#
#       Energy  ReverseEnergy  EnergyNR  ReverseEnergyNR  Load      runtime  \
# 0     178351              0    178351                0   169         onnx
# 1     178351              0    178351                0   169         onnx
# 2     178351              0    178351                0   312         onnx
# 3     178351              0    178351                0   312         onnx
# 4     178351              0    178351                0   312         onnx
# ...      ...            ...       ...              ...   ...          ...
# 1194  178428              0    178428                0   131  torchscript
# 1195  178428              0    178428                0   131  torchscript
# 1196  178428              0    178428                0   133  torchscript
# 1197  178428              0    178428                0   133  torchscript
# 1198  178428              0    178428                0   133  torchscript
#
#      model
# 0     phi2
# 1     phi2
# 2     phi2
# 3     phi2
# 4     phi2
# ...    ...
# 1194  phi2
# 1195  phi2
# 1196  phi2
# 1197  phi2
# 1198  phi2
#
# [1199 rows x 17 columns]

# %%
wattmeter_df = change_model(wattmeter_df, new_df, "phi2")
wattmeter_df
# Out:
#           Wattmetter Timestamp              True timestamp  ID  \
# 0     2024-06-11T18:58:31+0100  2024-06-11 18:58:32.312579   1
# 1     2024-06-11T18:58:32+0100  2024-06-11 18:58:33.457552   1
# 2     2024-06-11T18:58:33+0100  2024-06-11 18:58:34.603030   1
# 3     2024-06-11T18:58:35+0100  2024-06-11 18:58:35.748496   1
# 4     2024-06-11T18:58:36+0100  2024-06-11 18:58:36.899888   1
# ...                        ...                         ...  ..
# 1194  2024-06-30T15:25:37+0100  2024-06-30 15:25:37.998872   1
# 1195  2024-06-30T15:25:38+0100  2024-06-30 15:25:38.575078   1
# 1196  2024-06-30T15:25:39+0100  2024-06-30 15:25:39.155122   1
# 1197  2024-06-30T15:25:39+0100  2024-06-30 15:25:39.743225   1
# 1198  2024-06-30T15:25:40+0100  2024-06-30 15:25:40.322107   1
#
#                 Name  State  Action  Delay  Current  PowerFactor   Phase  \
# 0     Power output 1      1       6   5000      836         0.93  336.99
# 1     Power output 1      1       6   5000      825         0.90  336.41
# 2     Power output 1      1       6   5000      810         0.90  335.39
# 3     Power output 1      1       6   5000      951         1.00  342.74
# 4     Power output 1      1       6   5000     1049         0.96  341.59
# ...              ...    ...     ...    ...      ...          ...     ...
# 1194  Power output 1      1       6   5000      831         0.66  324.59
# 1195  Power output 1      1       6   5000      831         0.66  324.59
# 1196  Power output 1      1       6   5000      687         0.82  328.48
# 1197  Power output 1      1       6   5000      687         0.82  328.48
# 1198  Power output 1      1       6   5000      687         0.82  328.48
#
#       Energy  ReverseEnergy  EnergyNR  ReverseEnergyNR  Load      runtime  \
# 0     128621              0    128621                0   186         onnx
# 1     128621              0    128621                0   178         onnx
# 2     128621              0    128621                0   175         onnx
# 3     128621              0    128621                0   243         onnx
# 4     128621              0    128621                0   239         onnx
# ...      ...            ...       ...              ...   ...          ...
# 1194  178428              0    178428                0   131  torchscript
# 1195  178428              0    178428                0   131  torchscript
# 1196  178428              0    178428                0   133  torchscript
# 1197  178428              0    178428                0   133  torchscript
# 1198  178428              0    178428                0   133  torchscript
#
#                  model
# 0     codeparrot-small
# 1     codeparrot-small
# 2     codeparrot-small
# 3     codeparrot-small
# 4     codeparrot-small
# ...                ...
# 1194              phi2
# 1195              phi2
# 1196              phi2
# 1197              phi2
# 1198              phi2
#
# [4383 rows x 17 columns]

# %%
wattmeter_df['time'] = pd.to_datetime(wattmeter_df['True timestamp'],)
wattmeter_df.head()
# Out:
#        Wattmetter Timestamp              True timestamp  ID            Name  \
# 0  2024-06-11T18:58:31+0100  2024-06-11 18:58:32.312579   1  Power output 1
# 1  2024-06-11T18:58:32+0100  2024-06-11 18:58:33.457552   1  Power output 1
# 2  2024-06-11T18:58:33+0100  2024-06-11 18:58:34.603030   1  Power output 1
# 3  2024-06-11T18:58:35+0100  2024-06-11 18:58:35.748496   1  Power output 1
# 4  2024-06-11T18:58:36+0100  2024-06-11 18:58:36.899888   1  Power output 1
#
#    State  Action  Delay  Current  PowerFactor   Phase  Energy  ReverseEnergy  \
# 0      1       6   5000      836         0.93  336.99  128621              0
# 1      1       6   5000      825         0.90  336.41  128621              0
# 2      1       6   5000      810         0.90  335.39  128621              0
# 3      1       6   5000      951         1.00  342.74  128621              0
# 4      1       6   5000     1049         0.96  341.59  128621              0
#
#    EnergyNR  ReverseEnergyNR  Load runtime             model  \
# 0    128621                0   186    onnx  codeparrot-small
# 1    128621                0   178    onnx  codeparrot-small
# 2    128621                0   175    onnx  codeparrot-small
# 3    128621                0   243    onnx  codeparrot-small
# 4    128621                0   239    onnx  codeparrot-small
#
#                         time
# 0 2024-06-11 18:58:32.312579
# 1 2024-06-11 18:58:33.457552
# 2 2024-06-11 18:58:34.603030
# 3 2024-06-11 18:58:35.748496
# 4 2024-06-11 18:58:36.899888

# %%
columns = list(wattmeter_df.columns)
new_order = columns[:2] + ['time','runtime', 'model'] + columns[2:-3]
wattmeter_df = wattmeter_df[new_order]
wattmeter_df.head()
# Out:
#        Wattmetter Timestamp              True timestamp  \
# 0  2024-06-11T18:58:31+0100  2024-06-11 18:58:32.312579
# 1  2024-06-11T18:58:32+0100  2024-06-11 18:58:33.457552
# 2  2024-06-11T18:58:33+0100  2024-06-11 18:58:34.603030
# 3  2024-06-11T18:58:35+0100  2024-06-11 18:58:35.748496
# 4  2024-06-11T18:58:36+0100  2024-06-11 18:58:36.899888
#
#                         time runtime             model  ID            Name  \
# 0 2024-06-11 18:58:32.312579    onnx  codeparrot-small   1  Power output 1
# 1 2024-06-11 18:58:33.457552    onnx  codeparrot-small   1  Power output 1
# 2 2024-06-11 18:58:34.603030    onnx  codeparrot-small   1  Power output 1
# 3 2024-06-11 18:58:35.748496    onnx  codeparrot-small   1  Power output 1
# 4 2024-06-11 18:58:36.899888    onnx  codeparrot-small   1  Power output 1
#
#    State  Action  Delay  Current  PowerFactor   Phase  Energy  ReverseEnergy  \
# 0      1       6   5000      836         0.93  336.99  128621              0
# 1      1       6   5000      825         0.90  336.41  128621              0
# 2      1       6   5000      810         0.90  335.39  128621              0
# 3      1       6   5000      951         1.00  342.74  128621              0
# 4      1       6   5000     1049         0.96  341.59  128621              0
#
#    EnergyNR  ReverseEnergyNR  Load
# 0    128621                0   186
# 1    128621                0   178
# 2    128621                0   175
# 3    128621                0   243
# 4    128621                0   239

# %%
wattmeter_df = wattmeter_df.sort_values(by='time', ascending=True)
wattmeter_df.to_csv(processed_dir+WATTMETER_SAVE_CSV, index=False)
print(f"Results saved in {processed_dir+WATTMETER_SAVE_CSV}")
# Out:
# Results saved in D:/GAISSA/energy-repo/last_repo/june_gpu_test/results_9/processed/wattmeter_dataset.csv

# %% [markdown]
# ## Verify timestamps match

# %%
runall_df = pd.read_csv(results_dir + 'runall_timestamps.csv', )

# %%
runall_df
# Out:
#              timestamp      runtime   model
# 0  2024-06-30 14:59:01            -    IDLE
# 1  2024-06-30 15:04:01         onnx   START
# 2  2024-06-30 15:19:33         onnx    phi2
# 3  2024-06-30 15:19:34        torch   START
# 4  2024-06-30 15:23:50        torch    phi2
# 5  2024-06-30 15:23:51  torchscript   START
# 6  2024-06-30 15:25:40  torchscript    phi2
# 7  2024-06-30 15:25:41            -  FINISH

# %%
print("from runall:")
print(runall_df['timestamp'].iloc[0])
print(runall_df['timestamp'].iloc[len(runall_df)-1])

print("wattmeter")
print(wattmeter_df['time'].iloc[0])
print(wattmeter_df['time'].iloc[len(wattmeter_df)-1])
# Out:
# from runall:
# 2024-06-30 14:59:01
# 2024-06-30 15:25:41
# wattmeter
# 2024-06-11 18:27:08.430839
# 2024-06-30 15:25:40.322107

# %%
wattmeter_df.head()
# Out:
#           Wattmetter Timestamp              True timestamp  \
# 2760  2024-06-11T18:27:08+0100  2024-06-11 18:27:08.430839
# 2761  2024-06-11T18:27:08+0100  2024-06-11 18:27:09.004525
# 2762  2024-06-11T18:27:09+0100  2024-06-11 18:27:09.576245
# 2763  2024-06-11T18:27:10+0100  2024-06-11 18:27:10.151533
# 2764  2024-06-11T18:27:10+0100  2024-06-11 18:27:10.722532
#
#                            time runtime       model  ID            Name  \
# 2760 2024-06-11 18:27:08.430839   torch  pythia1-4b   1  Power output 1
# 2761 2024-06-11 18:27:09.004525   torch  pythia1-4b   1  Power output 1
# 2762 2024-06-11 18:27:09.576245   torch  pythia1-4b   1  Power output 1
# 2763 2024-06-11 18:27:10.151533   torch  pythia1-4b   1  Power output 1
# 2764 2024-06-11 18:27:10.722532   torch  pythia1-4b   1  Power output 1
#
#       State  Action  Delay  Current  PowerFactor   Phase  Energy  \
# 2760      1       6   5000      847         0.93  335.27  128497
# 2761      1       6   5000      847         0.93  335.27  128497
# 2762      1       6   5000      827         0.91  335.12  128497
# 2763      1       6   5000      827         0.91  335.12  128497
# 2764      1       6   5000     1307         0.95  345.34  128497
#
#       ReverseEnergy  EnergyNR  ReverseEnergyNR  Load
# 2760              0    128497                0   189
# 2761              0    128497                0   189
# 2762              0    128497                0   179
# 2763              0    128497                0   179
# 2764              0    128497                0   297

# %%
#selected_columns = ['time','runtime','model','CPU_ENERGY (J)', 'TOTAL_MEMORY', 'TOTAL_SWAP', 'USED_MEMORY', 'USED_SWAP']
selected_columns = ['time','runtime','model','Current', 'PowerFactor', 'Phase',
       'Energy',  'EnergyNR',  'Load']
energi_selected = wattmeter_df[selected_columns].copy()

# %%
energi_selected.head()
# Out:
#                            time runtime       model  Current  PowerFactor  \
# 2760 2024-06-11 18:27:08.430839   torch  pythia1-4b      847         0.93
# 2761 2024-06-11 18:27:09.004525   torch  pythia1-4b      847         0.93
# 2762 2024-06-11 18:27:09.576245   torch  pythia1-4b      827         0.91
# 2763 2024-06-11 18:27:10.151533   torch  pythia1-4b      827         0.91
# 2764 2024-06-11 18:27:10.722532   torch  pythia1-4b     1307         0.95
#
#        Phase  Energy  EnergyNR  Load
# 2760  335.27  128497    128497   189
# 2761  335.27  128497    128497   189
# 2762  335.12  128497    128497   179
# 2763  335.12  128497    128497   179
# 2764  345.34  128497    128497   297

# %%
energi_selected['label'] = energi_selected['runtime'] + '_'+energi_selected['model']

# %%
 energi_selected['label'].unique()
# Out:
# array(['torch_pythia1-4b', 'torch_tinyllama', 'torch_codeparrot-small',
#        'torch_pythia-410m', 'onnx_pythia1-4b', 'onnx_tinyllama',
#        'onnx_codeparrot-small', 'onnx_pythia-410m',
#        'torchscript_pythia1-4b', 'torchscript_tinyllama',
#        'torchscript_codeparrot-small', 'torchscript_pythia-410m',
#        'onnx_phi2', 'torch_phi2', 'torchscript_phi2'], dtype=object)

# %%
energi_selected['energy_joules'] = energi_selected['Energy']*3600
energi_selected['energyNR_joules'] = energi_selected['EnergyNR']*3600
energi_selected
# Out:
#                            time      runtime       model  Current  \
# 2760 2024-06-11 18:27:08.430839        torch  pythia1-4b      847
# 2761 2024-06-11 18:27:09.004525        torch  pythia1-4b      847
# 2762 2024-06-11 18:27:09.576245        torch  pythia1-4b      827
# 2763 2024-06-11 18:27:10.151533        torch  pythia1-4b      827
# 2764 2024-06-11 18:27:10.722532        torch  pythia1-4b     1307
# ...                         ...          ...         ...      ...
# 1194 2024-06-30 15:25:37.998872  torchscript        phi2      831
# 1195 2024-06-30 15:25:38.575078  torchscript        phi2      831
# 1196 2024-06-30 15:25:39.155122  torchscript        phi2      687
# 1197 2024-06-30 15:25:39.743225  torchscript        phi2      687
# 1198 2024-06-30 15:25:40.322107  torchscript        phi2      687
#
#       PowerFactor   Phase  Energy  EnergyNR  Load             label  \
# 2760         0.93  335.27  128497    128497   189  torch_pythia1-4b
# 2761         0.93  335.27  128497    128497   189  torch_pythia1-4b
# 2762         0.91  335.12  128497    128497   179  torch_pythia1-4b
# 2763         0.91  335.12  128497    128497   179  torch_pythia1-4b
# 2764         0.95  345.34  128497    128497   297  torch_pythia1-4b
# ...           ...     ...     ...       ...   ...               ...
# 1194         0.66  324.59  178428    178428   131  torchscript_phi2
# 1195         0.66  324.59  178428    178428   131  torchscript_phi2
# 1196         0.82  328.48  178428    178428   133  torchscript_phi2
# 1197         0.82  328.48  178428    178428   133  torchscript_phi2
# 1198         0.82  328.48  178428    178428   133  torchscript_phi2
#
#       energy_joules  energyNR_joules
# 2760      462589200        462589200
# 2761      462589200        462589200
# 2762      462589200        462589200
# 2763      462589200        462589200
# 2764      462589200        462589200
# ...             ...              ...
# 1194      642340800        642340800
# 1195      642340800        642340800
# 1196      642340800        642340800
# 1197      642340800        642340800
# 1198      642340800        642340800
#
# [4383 rows x 12 columns]

# %%
def add_energy_groupby(df, energy_col,groupby_col,new_col_name):
    new_df = df.copy()
    new_df[new_col_name] = new_df.groupby(groupby_col)[energy_col].transform(lambda x: x.max() - x.min())

    #new_df['energy' ] = new_df['e'].dt.total_seconds()
    return new_df

# %%
df_last = add_energy_groupby(energi_selected,'energy_joules','label','energy_joules_config')
df_last = add_energy_groupby(df_last,'energyNR_joules','label','energyNR_joules_config')
df_last
# Out:
#                            time      runtime       model  Current  \
# 2760 2024-06-11 18:27:08.430839        torch  pythia1-4b      847
# 2761 2024-06-11 18:27:09.004525        torch  pythia1-4b      847
# 2762 2024-06-11 18:27:09.576245        torch  pythia1-4b      827
# 2763 2024-06-11 18:27:10.151533        torch  pythia1-4b      827
# 2764 2024-06-11 18:27:10.722532        torch  pythia1-4b     1307
# ...                         ...          ...         ...      ...
# 1194 2024-06-30 15:25:37.998872  torchscript        phi2      831
# 1195 2024-06-30 15:25:38.575078  torchscript        phi2      831
# 1196 2024-06-30 15:25:39.155122  torchscript        phi2      687
# 1197 2024-06-30 15:25:39.743225  torchscript        phi2      687
# 1198 2024-06-30 15:25:40.322107  torchscript        phi2      687
#
#       PowerFactor   Phase  Energy  EnergyNR  Load             label  \
# 2760         0.93  335.27  128497    128497   189  torch_pythia1-4b
# 2761         0.93  335.27  128497    128497   189  torch_pythia1-4b
# 2762         0.91  335.12  128497    128497   179  torch_pythia1-4b
# 2763         0.91  335.12  128497    128497   179  torch_pythia1-4b
# 2764         0.95  345.34  128497    128497   297  torch_pythia1-4b
# ...           ...     ...     ...       ...   ...               ...
# 1194         0.66  324.59  178428    178428   131  torchscript_phi2
# 1195         0.66  324.59  178428    178428   131  torchscript_phi2
# 1196         0.82  328.48  178428    178428   133  torchscript_phi2
# 1197         0.82  328.48  178428    178428   133  torchscript_phi2
# 1198         0.82  328.48  178428    178428   133  torchscript_phi2
#
#       energy_joules  energyNR_joules  energy_joules_config  \
# 2760      462589200        462589200                 50400
# 2761      462589200        462589200                 50400
# 2762      462589200        462589200                 50400
# 2763      462589200        462589200                 50400
# 2764      462589200        462589200                 50400
# ...             ...              ...                   ...
# 1194      642340800        642340800                 14400
# 1195      642340800        642340800                 14400
# 1196      642340800        642340800                 14400
# 1197      642340800        642340800                 14400
# 1198      642340800        642340800                 14400
#
#       energyNR_joules_config
# 2760                   50400
# 2761                   50400
# 2762                   50400
# 2763                   50400
# 2764                   50400
# ...                      ...
# 1194                   14400
# 1195                   14400
# 1196                   14400
# 1197                   14400
# 1198                   14400
#
# [4383 rows x 14 columns]

# %%
def calculate_statistics(df, columns, column_types, label_column):
    new_df = df.copy()
    
    # Iterate over the columns and their types
    for col, col_type in zip(columns, column_types):
        # Calculate the average based on the label_column
        if col_type == 'average':
            new_df['avg_' + col] = new_df.groupby(label_column)[col].transform('mean')
        # Calculate the difference, then average
        elif col_type == 'diff_then_average':
            new_df['diff_' + col] = new_df[col].diff()
            new_df['avg_diff_' + col] = new_df.groupby(label_column)['diff_' + col].transform('mean')
        # Calculate average minus last average
        elif col_type == 'average_minus_last_average':
            new_df['avg_' + col] = new_df.groupby(label_column)[col].transform('mean')
            #new_df['avg_minus_last_' + col] = new_df.groupby(label_column)['avg_' + col].diff()

            
            # Conditionally set the value for the first label
            #first_label_mask = new_df[label_column] != new_df[label_column].shift()
            #new_df.loc[first_label_mask, 'avg_minus_last_' + col] = new_df['avg_' + col]

            #pass
        
    return new_df

# %%
#numeric_columns = ['CPU_ENERGY (J)', 'TOTAL_MEMORY', 'TOTAL_SWAP', 'USED_MEMORY', 'USED_SWAP']
numeric_columns = ['Current', 'PowerFactor', 'Phase', 'Load']

column_types = ['average', 'average', 'average', 'average',]
#'average', 'diff_then_average', 'average_minus_last_average'
df_with_metrics = calculate_statistics(df_last,numeric_columns,column_types,'label')
df_with_metrics
# Out:
#                            time      runtime       model  Current  \
# 2760 2024-06-11 18:27:08.430839        torch  pythia1-4b      847
# 2761 2024-06-11 18:27:09.004525        torch  pythia1-4b      847
# 2762 2024-06-11 18:27:09.576245        torch  pythia1-4b      827
# 2763 2024-06-11 18:27:10.151533        torch  pythia1-4b      827
# 2764 2024-06-11 18:27:10.722532        torch  pythia1-4b     1307
# ...                         ...          ...         ...      ...
# 1194 2024-06-30 15:25:37.998872  torchscript        phi2      831
# 1195 2024-06-30 15:25:38.575078  torchscript        phi2      831
# 1196 2024-06-30 15:25:39.155122  torchscript        phi2      687
# 1197 2024-06-30 15:25:39.743225  torchscript        phi2      687
# 1198 2024-06-30 15:25:40.322107  torchscript        phi2      687
#
#       PowerFactor   Phase  Energy  EnergyNR  Load             label  \
# 2760         0.93  335.27  128497    128497   189  torch_pythia1-4b
# 2761         0.93  335.27  128497    128497   189  torch_pythia1-4b
# 2762         0.91  335.12  128497    128497   179  torch_pythia1-4b
# 2763         0.91  335.12  128497    128497   179  torch_pythia1-4b
# 2764         0.95  345.34  128497    128497   297  torch_pythia1-4b
# ...           ...     ...     ...       ...   ...               ...
# 1194         0.66  324.59  178428    178428   131  torchscript_phi2
# 1195         0.66  324.59  178428    178428   131  torchscript_phi2
# 1196         0.82  328.48  178428    178428   133  torchscript_phi2
# 1197         0.82  328.48  178428    178428   133  torchscript_phi2
# 1198         0.82  328.48  178428    178428   133  torchscript_phi2
#
#       energy_joules  energyNR_joules  energy_joules_config  \
# 2760      462589200        462589200                 50400
# 2761      462589200        462589200                 50400
# 2762      462589200        462589200                 50400
# 2763      462589200        462589200                 50400
# 2764      462589200        462589200                 50400
# ...             ...              ...                   ...
# 1194      642340800        642340800                 14400
# 1195      642340800        642340800                 14400
# 1196      642340800        642340800                 14400
# 1197      642340800        642340800                 14400
# 1198      642340800        642340800                 14400
#
#       energyNR_joules_config  avg_Current  avg_PowerFactor   avg_Phase  \
# 2760                   50400  1201.486405         0.918822  342.273384
# 2761                   50400  1201.486405         0.918822  342.273384
# 2762                   50400  1201.486405         0.918822  342.273384
# 2763                   50400  1201.486405         0.918822  342.273384
# 2764                   50400  1201.486405         0.918822  342.273384
# ...                      ...          ...              ...         ...
# 1194                   14400   764.350575         0.778851  326.560287
# 1195                   14400   764.350575         0.778851  326.560287
# 1196                   14400   764.350575         0.778851  326.560287
# 1197                   14400   764.350575         0.778851  326.560287
# 1198                   14400   764.350575         0.778851  326.560287
#
#         avg_Load
# 2760  265.601208
# 2761  265.601208
# 2762  265.601208
# 2763  265.601208
# 2764  265.601208
# ...          ...
# 1194  149.465517
# 1195  149.465517
# 1196  149.465517
# 1197  149.465517
# 1198  149.465517
#
# [4383 rows x 18 columns]

# %%
save_dir = 'wattmeter_processed.csv'
df_with_metrics.to_csv(processed_dir+save_dir, index=False)

# %%
runall_df = pd.read_csv(results_dir + 'runall_timestamps.csv', )
print("from runall:")
print(runall_df['timestamp'].iloc[0])
print(runall_df['timestamp'].iloc[len(runall_df)-1])

print("wattmeter")
print(wattmeter_df['time'].iloc[0])
print(wattmeter_df['time'].iloc[len(wattmeter_df)-1])
# Out:
# from runall:
# 2024-06-30 14:59:01
# 2024-06-30 15:25:41
# wattmeter
# 2024-06-11 18:27:08.430839
# 2024-06-30 15:25:40.322107
