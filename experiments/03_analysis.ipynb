# %% [markdown]
# - input
#   - results_*/processed/
# - output
#   - tables/* median tables
#   - tables/* final data table
#   - figures/* box plots

# %%
import matplotlib.pyplot as plt
import pandas as pd
import glob

# %% [markdown]
# ## Energibridge

# %%
# Path where the CSV files are stored
path = "D:/GAISSA/energy-repo/last_repo/june_gpu/"  # Adjust this path to your CSV files location
all_files = glob.glob(path + "/results_*/processed/energi_processed.csv")
all_files
# Out:
# ['D:/GAISSA/energy-repo/last_repo/june_gpu\\results_1\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_10\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_2\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_3\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_4\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_5\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_6\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_7\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_8\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_9\\processed\\energi_processed.csv']

# %%
## add "experiment" column 1,2...10

# List to hold data from each file
li = []

# Read each file and append to list
n=1
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df['experiment'] = n
    li.append(df)
    n+=1
    

# Combine all data into one DataFrame
combined_df = pd.concat(li, axis=0, ignore_index=True)
combined_df
# Out:
#                            time      runtime model  CPU_ENERGY (J)  \
# 0       2024-06-08 21:42:00.400         idle  idle   516616.142639
# 1       2024-06-08 21:42:00.400         idle  idle   516616.207123
# 2       2024-06-08 21:42:00.600         idle  idle   516627.494354
# 3       2024-06-08 21:42:00.800         idle  idle   516639.257111
# 4       2024-06-08 21:42:01.000         idle  idle   516651.727112
# ...                         ...          ...   ...             ...
# 195752  2024-06-11 18:22:03.338  torchscript  phi2   284087.755600
# 195753  2024-06-11 18:22:03.538  torchscript  phi2   284093.116379
# 195754  2024-06-11 18:22:03.738  torchscript  phi2   284096.458450
# 195755  2024-06-11 18:22:03.939  torchscript  phi2   284100.854996
# 195756  2024-06-11 18:22:04.139  torchscript  phi2   284104.789276
#
#         TOTAL_MEMORY  TOTAL_SWAP  USED_MEMORY  USED_SWAP  AVG_CPU_USAGE  \
# 0        66575933440  2147479552   2241388544          0       5.237742
# 1        66575933440  2147479552   2246549504          0       5.237742
# 2        66575933440  2147479552   2353451008          0       4.872685
# 3        66575933440  2147479552   2402861056          0       4.872685
# 4        66575933440  2147479552   2452594688          0       6.209758
# ...              ...         ...          ...        ...            ...
# 195752   66575949824  2147479552  12816416768          0       0.000000
# 195753   66575949824  2147479552  12816416768          0       0.617560
# 195754   66575949824  2147479552  12816416768          0       0.000000
# 195755   66575949824  2147479552  12816416768          0       0.305060
# 195756   66575949824  2147479552  12799025152          0       0.297619
#
#                    label  avg_TOTAL_MEMORY  avg_TOTAL_SWAP  avg_USED_MEMORY  \
# 0              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 1              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 2              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 3              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 4              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# ...                  ...               ...             ...              ...
# 195752  torchscript_phi2      6.657595e+10    2.147480e+09     1.268366e+10
# 195753  torchscript_phi2      6.657595e+10    2.147480e+09     1.268366e+10
# 195754  torchscript_phi2      6.657595e+10    2.147480e+09     1.268366e+10
# 195755  torchscript_phi2      6.657595e+10    2.147480e+09     1.268366e+10
# 195756  torchscript_phi2      6.657595e+10    2.147480e+09     1.268366e+10
#
#         avg_USED_SWAP       energy  experiment
# 0                 0.0  5356.125122           1
# 1                 0.0  5356.125122           1
# 2                 0.0  5356.125122           1
# 3                 0.0  5356.125122           1
# 4                 0.0  5356.125122           1
# ...               ...          ...         ...
# 195752            0.0  2862.805466          10
# 195753            0.0  2862.805466          10
# 195754            0.0  2862.805466          10
# 195755            0.0  2862.805466          10
# 195756            0.0  2862.805466          10
#
# [195757 rows x 16 columns]

# %%
combined_df.columns
# Out:
# Index(['time', 'runtime', 'model', 'CPU_ENERGY (J)', 'TOTAL_MEMORY',
#        'TOTAL_SWAP', 'USED_MEMORY', 'USED_SWAP', 'AVG_CPU_USAGE', 'label',
#        'avg_TOTAL_MEMORY', 'avg_TOTAL_SWAP', 'avg_USED_MEMORY',
#        'avg_USED_SWAP', 'energy', 'experiment'],
#       dtype='object')

# %%
#'minus_avg_USED_SWAP', 
variables_to_plot = [ 'CPU_ENERGY (J)','energy',  'USED_MEMORY', 'USED_SWAP', 'AVG_CPU_USAGE',  'avg_USED_MEMORY',
       'avg_USED_SWAP',  ]

for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    combined_df.boxplot(column=variable, by='label', grid=False)
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel('Label')
    plt.ylabel(variable)
    plt.xticks(rotation=45)
    plt.tight_layout()  # Adjust layout to make room for the rotated x-axis labels

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming combined_df is already created and contains the data

#variables_to_plot = ['diff_CPU_ENERGY (J)','avg_diff_CPU_ENERGY (J)', 'avg_TOTAL_MEMORY',  'minus_avg_USED_MEMORY', 'avg_TOTAL_SWAP',]


# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    # Setting vert=False makes the box plots horizontal
    combined_df.boxplot(column=variable, by='label', grid=False, vert=False)
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.ylabel('Label')
    plt.yticks(rotation=0)  # Rotate label ticks if necessary
    plt.tight_layout()  # Adjust layout to make room for labels

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools  # for cycling through colors if necessary

# Assuming combined_df is already created and contains the data
#variables_to_plot = ['diff_CPU_ENERGY (J)', 'avg_diff_CPU_ENERGY (J)', 'avg_TOTAL_MEMORY', 'minus_avg_USED_MEMORY', 'avg_TOTAL_SWAP']

# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    grouped = combined_df.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.tight_layout()  # Adjust layout to make room for labels

plt.show()

# %% [markdown]
# ## Nvidia

# %%
# Path where the CSV files are stored
path = "D:/GAISSA/energy-repo/last_repo/june_gpu/"  # Adjust this path to your CSV files location
all_files = glob.glob(path + "/results_*/processed/nvidia*_processed.csv")
all_files
# Out:
# ['D:/GAISSA/energy-repo/last_repo/june_gpu\\results_1\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_10\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_2\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_3\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_4\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_5\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_6\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_7\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_8\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_9\\processed\\nvidia_processed.csv']

# %%
## add number of experiment

# List to hold data from each file
li = []

# Read each file and append to list
n=1
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df['experiment'] = n
    li.append(df)
    n+=1
    

# Combine all data into one DataFrame
combined_df = pd.concat(li, axis=0, ignore_index=True)
combined_df
# Out:
#                            time      runtime       model  \
# 0       2024-06-08 21:47:00.468        torch  pythia1-4b
# 1       2024-06-08 21:47:00.571        torch  pythia1-4b
# 2       2024-06-08 21:47:00.672        torch  pythia1-4b
# 3       2024-06-08 21:47:00.773        torch  pythia1-4b
# 4       2024-06-08 21:47:00.874        torch  pythia1-4b
# ...                         ...          ...         ...
# 359162  2024-06-11 18:22:03.717  torchscript        phi2
# 359163  2024-06-11 18:22:03.818  torchscript        phi2
# 359164  2024-06-11 18:22:03.919  torchscript        phi2
# 359165  2024-06-11 18:22:04.020  torchscript        phi2
# 359166  2024-06-11 18:22:04.120  torchscript        phi2
#
#          utilization.gpu [%]   utilization.memory [%]   memory.total [MiB]  \
# 0                          0                        2                24564
# 1                          0                        2                24564
# 2                          0                        2                24564
# 3                          0                        2                24564
# 4                          0                        2                24564
# ...                      ...                      ...                  ...
# 359162                     0                        0                24564
# 359163                     0                        0                24564
# 359164                     0                        0                24564
# 359165                     0                        0                24564
# 359166                     0                        0                24564
#
#          memory.used [MiB]   power.draw [W]   power.max_limit [W]  \
# 0                       65            11.65                 500.0
# 1                       65            11.66                 500.0
# 2                       65            11.67                 500.0
# 3                       65            11.68                 500.0
# 4                       65            11.70                 500.0
# ...                    ...              ...                   ...
# 359162               14472            75.72                 500.0
# 359163               14472            75.72                 500.0
# 359164               14472            75.66                 500.0
# 359165               14472            66.74                 500.0
# 359166               14472            66.66                 500.0
#
#          temperature.gpu             label  avg_ utilization.gpu [%]  \
# 0                     37  torch_pythia1-4b                 73.584680
# 1                     37  torch_pythia1-4b                 73.584680
# 2                     37  torch_pythia1-4b                 73.584680
# 3                     37  torch_pythia1-4b                 73.584680
# 4                     37  torch_pythia1-4b                 73.584680
# ...                  ...               ...                       ...
# 359162                39  torchscript_phi2                  5.463956
# 359163                39  torchscript_phi2                  5.463956
# 359164                39  torchscript_phi2                  5.463956
# 359165                39  torchscript_phi2                  5.463956
# 359166                39  torchscript_phi2                  5.463956
#
#         avg_ utilization.memory [%]  avg_ memory.used [MiB]  \
# 0                         67.165711             6061.018760
# 1                         67.165711             6061.018760
# 2                         67.165711             6061.018760
# 3                         67.165711             6061.018760
# 4                         67.165711             6061.018760
# ...                             ...                     ...
# 359162                     2.404806            14400.011091
# 359163                     2.404806            14400.011091
# 359164                     2.404806            14400.011091
# 359165                     2.404806            14400.011091
# 359166                     2.404806            14400.011091
#
#         avg_ power.draw [W]  avg_ temperature.gpu  config_duration  \
# 0                178.655961             49.400730          193.242
# 1                178.655961             49.400730          193.242
# 2                178.655961             49.400730          193.242
# 3                178.655961             49.400730          193.242
# 4                178.655961             49.400730          193.242
# ...                     ...                   ...              ...
# 359162            72.250166             38.703327          109.097
# 359163            72.250166             38.703327          109.097
# 359164            72.250166             38.703327          109.097
# 359165            72.250166             38.703327          109.097
# 359166            72.250166             38.703327          109.097
#
#               energy  experiment
# 0       34523.835300           1
# 1       34523.835300           1
# 2       34523.835300           1
# 3       34523.835300           1
# 4       34523.835300           1
# ...              ...         ...
# 359162   7882.276399          10
# 359163   7882.276399          10
# 359164   7882.276399          10
# 359165   7882.276399          10
# 359166   7882.276399          10
#
# [359167 rows x 19 columns]

# %%
combined_df.columns
# Out:
# Index(['time', 'runtime', 'model', ' utilization.gpu [%]',
#        ' utilization.memory [%]', ' memory.total [MiB]', ' memory.used [MiB]',
#        ' power.draw [W]', ' power.max_limit [W]', ' temperature.gpu', 'label',
#        'avg_ utilization.gpu [%]', 'avg_ utilization.memory [%]',
#        'avg_ memory.used [MiB]', 'avg_ power.draw [W]', 'avg_ temperature.gpu',
#        'config_duration', 'energy', 'experiment'],
#       dtype='object')

# %%
variables_to_plot = ['diff_CPU_ENERGY (J)','avg_diff_CPU_ENERGY (J)', 'avg_TOTAL_MEMORY', 'avg_TOTAL_SWAP', 'minus_avg_USED_MEMORY', 'minus_avg_USED_SWAP',]
# nvidia variables to plot
variables_to_plot = ['energy','config_duration','avg_ utilization.gpu [%]','avg_ utilization.memory [%]','avg_ memory.used [MiB]','avg_ power.draw [W]' ,'avg_ temperature.gpu']

#column_types = ['average', 'average', 'average', 'average', 'average','average','average']
#variables_to_plot = ['avg_'+c for c in numeric_columns]
variables_to_plot
# Out:
# ['energy',
#  'config_duration',
#  'avg_ utilization.gpu [%]',
#  'avg_ utilization.memory [%]',
#  'avg_ memory.used [MiB]',
#  'avg_ power.draw [W]',
#  'avg_ temperature.gpu']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming combined_df is already created and contains the data



# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    # Setting vert=False makes the box plots horizontal
    combined_df.boxplot(column=variable, by='label', grid=False, vert=False)
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.ylabel('Label')
    plt.yticks(rotation=0)  # Rotate label ticks if necessary
    plt.tight_layout()  # Adjust layout to make room for labels

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools  # for cycling through colors if necessary


# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    grouped = combined_df.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.tight_layout()  # Adjust layout to make room for labels

plt.show()

# %% [markdown]
# ## Wattmeter

# %%
# Path where the CSV files are stored
path = "D:/GAISSA/energy-repo/last_repo/june_gpu/"  # Adjust this path to your CSV files location
all_files = glob.glob(path + "/results_*/processed/wattmeter*_processed.csv")
all_files
# Out:
# ['D:/GAISSA/energy-repo/last_repo/june_gpu\\results_1\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_10\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_2\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_3\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_4\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_5\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_6\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_7\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_8\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_9\\processed\\wattmeter_processed.csv']

# %%
## add experiments number
# List to hold data from each file
li = []

# Read each file and append to list
n=1
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df['experiment'] = n
    li.append(df)
    n+=1
    

# Combine all data into one DataFrame
combined_df = pd.concat(li, axis=0, ignore_index=True)
combined_df
# Out:
#                              time      runtime       model  Current  \
# 0      2024-06-08 21:47:02.854518        torch  pythia1-4b      717
# 1      2024-06-08 21:47:03.429127        torch  pythia1-4b      717
# 2      2024-06-08 21:47:04.017249        torch  pythia1-4b      812
# 3      2024-06-08 21:47:04.591239        torch  pythia1-4b      812
# 4      2024-06-08 21:47:05.163254        torch  pythia1-4b      812
# ...                           ...          ...         ...      ...
# 41725  2024-06-11 18:22:01.114161  torchscript        phi2      642
# 41726  2024-06-11 18:22:01.689984  torchscript        phi2      905
# 41727  2024-06-11 18:22:02.270933  torchscript        phi2      905
# 41728  2024-06-11 18:22:02.853918  torchscript        phi2      700
# 41729  2024-06-11 18:22:03.433187  torchscript        phi2      700
#
#        PowerFactor   Phase  Energy  EnergyNR  Load             label  \
# 0             1.00  336.26  120086    120086   174  torch_pythia1-4b
# 1             1.00  336.26  120086    120086   174  torch_pythia1-4b
# 2             0.91  335.38  120086    120086   176  torch_pythia1-4b
# 3             0.91  335.38  120086    120086   176  torch_pythia1-4b
# 4             0.91  335.38  120086    120086   176  torch_pythia1-4b
# ...            ...     ...     ...       ...   ...               ...
# 41725         0.84  325.20  128489    128489   130  torchscript_phi2
# 41726         0.64  328.22  128489    128489   139  torchscript_phi2
# 41727         0.64  328.22  128489    128489   139  torchscript_phi2
# 41728         0.74  325.77  128489    128489   125  torchscript_phi2
# 41729         0.74  325.77  128489    128489   125  torchscript_phi2
#
#        energy_joules  energyNR_joules  energy_joules_config  \
# 0          432309600        432309600                 54000
# 1          432309600        432309600                 54000
# 2          432309600        432309600                 54000
# 3          432309600        432309600                 54000
# 4          432309600        432309600                 54000
# ...              ...              ...                   ...
# 41725      462560400        462560400                 14400
# 41726      462560400        462560400                 14400
# 41727      462560400        462560400                 14400
# 41728      462560400        462560400                 14400
# 41729      462560400        462560400                 14400
#
#        energyNR_joules_config  avg_Current  avg_PowerFactor   avg_Phase  \
# 0                       54000  1278.477341         0.931662  343.706465
# 1                       54000  1278.477341         0.931662  343.706465
# 2                       54000  1278.477341         0.931662  343.706465
# 3                       54000  1278.477341         0.931662  343.706465
# 4                       54000  1278.477341         0.931662  343.706465
# ...                       ...          ...              ...         ...
# 41725                   14400   747.810345         0.778103  325.112011
# 41726                   14400   747.810345         0.778103  325.112011
# 41727                   14400   747.810345         0.778103  325.112011
# 41728                   14400   747.810345         0.778103  325.112011
# 41729                   14400   747.810345         0.778103  325.112011
#
#          avg_Load  experiment
# 0      284.371601           1
# 1      284.371601           1
# 2      284.371601           1
# 3      284.371601           1
# 4      284.371601           1
# ...           ...         ...
# 41725  147.275862          10
# 41726  147.275862          10
# 41727  147.275862          10
# 41728  147.275862          10
# 41729  147.275862          10
#
# [41730 rows x 19 columns]

# %%
combined_df.columns
# Out:
# Index(['time', 'runtime', 'model', 'Current', 'PowerFactor', 'Phase', 'Energy',
#        'EnergyNR', 'Load', 'label', 'energy_joules', 'energyNR_joules',
#        'energy_joules_config', 'energyNR_joules_config', 'avg_Current',
#        'avg_PowerFactor', 'avg_Phase', 'avg_Load', 'experiment'],
#       dtype='object')

# %%
#numeric_columns = ['Current', 'PowerFactor', 'Phase',       'Energy', 'EnergyNR', 'Load']

#column_types = ['average', 'average', 'average', 'diff_then_average', 'diff_then_average','average',]
variables_to_plot = ['energy_joules_config', 'energyNR_joules_config','avg_Current', 'avg_PowerFactor', 'avg_Phase', 'avg_Load',]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming combined_df is already created and contains the data



# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    # Setting vert=False makes the box plots horizontal
    combined_df.boxplot(column=variable, by='label', grid=False, vert=False)
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.ylabel('Label')
    plt.yticks(rotation=0)  # Rotate label ticks if necessary
    plt.tight_layout()  # Adjust layout to make room for labels

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools  # for cycling through colors if necessary


# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    grouped = combined_df.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.tight_layout()  # Adjust layout to make room for labels

plt.show()

# %% [markdown]
# ## Duration

# %%
# Path where the CSV files are stored
path = "D:/GAISSA/energy-repo/last_repo/june_gpu/"  # Adjust this path to your CSV files location
all_files = glob.glob(path + "/results_*/processed/time_marks.csv")
#all_files=all_files[:4]
all_files
# Out:
# ['D:/GAISSA/energy-repo/last_repo/june_gpu\\results_1\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_10\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_2\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_3\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_4\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_5\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_6\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_7\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_8\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_9\\processed\\time_marks.csv']

# %%
## add number of experiment

# List to hold data from each file
li = []

# Read each file and append to list
n=1
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df['experiment'] = n
    li.append(df)
    n+=1
    

# Combine all data into one DataFrame
combined_df = pd.concat(li, axis=0, ignore_index=True)
combined_df
# Out:
#                            time      runtime        model       engine  \
# 0    2024-06-08 21:41:59.000000            -         IDLE          NaN
# 1    2024-06-08 21:47:00.000000        torch        START          NaN
# 2    2024-06-08 21:47:00.919120          NaN          NaN        torch
# 3    2024-06-08 21:47:02.775654          NaN          NaN        torch
# 4    2024-06-08 21:50:13.000000        torch   pythia1-4b          NaN
# ..                          ...          ...          ...          ...
# 473  2024-06-11 18:20:14.000000  torchscript  pythia-410m          NaN
# 474  2024-06-11 18:20:15.469099          NaN          NaN  torchscript
# 475  2024-06-11 18:20:23.217733          NaN          NaN  torchscript
# 476  2024-06-11 18:22:04.000000  torchscript         phi2          NaN
# 477  2024-06-11 18:22:05.000000            -       FINISH          NaN
#
#      model_name  start_end        file                    label    duration  \
# 0           NaN        NaN      runall                     idle         NaN
# 1           NaN        NaN      runall              torch_START  301.000000
# 2    pythia1-4b        1.0  load_times         torch_pythia1-4b    0.919120
# 3    pythia1-4b        0.0  load_times         torch_pythia1-4b    1.856534
# 4           NaN        NaN      runall         torch_pythia1-4b  190.224346
# ..          ...        ...         ...                      ...         ...
# 473         NaN        NaN      runall  torchscript_pythia-410m   96.750691
# 474        phi2        1.0  load_times         torchscript_phi2    1.469099
# 475        phi2        0.0  load_times         torchscript_phi2    7.748634
# 476         NaN        NaN      runall         torchscript_phi2  100.782267
# 477         NaN        NaN      runall                   finish    1.000000
#
#                             label_time  experiment
# 0                     -_IDLE_inference           1
# 1                torch_START_inference           1
# 2                                  NaN           1
# 3                torch_pythia1-4b_load           1
# 4           torch_pythia1-4b_inference           1
# ..                                 ...         ...
# 473  torchscript_pythia-410m_inference          10
# 474                                NaN          10
# 475              torchscript_phi2_load          10
# 476         torchscript_phi2_inference          10
# 477                 -_FINISH_inference          10
#
# [478 rows x 11 columns]

# %%
combined_df.columns
# Out:
# Index(['time', 'runtime', 'model', 'engine', 'model_name', 'start_end', 'file',
#        'label', 'duration', 'label_time', 'experiment'],
#       dtype='object')

# %%
variables_to_plot = ['duration', ]

# %%
combined_df[combined_df['label_time'].str.startswith('torch_', na=False) & combined_df['label_time'].str.endswith('inference', na=False) ]
# Out:
#                            time runtime             model engine model_name  \
# 1    2024-06-08 21:47:00.000000   torch             START    NaN        NaN
# 4    2024-06-08 21:50:13.000000   torch        pythia1-4b    NaN        NaN
# 7    2024-06-08 21:53:25.000000   torch         tinyllama    NaN        NaN
# 10   2024-06-08 21:57:41.000000   torch              phi2    NaN        NaN
# 13   2024-06-08 21:59:17.000000   torch  codeparrot-small    NaN        NaN
# 16   2024-06-08 22:02:28.000000   torch       pythia-410m    NaN        NaN
# 49   2024-06-11 18:27:06.000000   torch             START    NaN        NaN
# 52   2024-06-11 18:30:18.000000   torch        pythia1-4b    NaN        NaN
# 55   2024-06-11 18:33:30.000000   torch         tinyllama    NaN        NaN
# 58   2024-06-11 18:35:06.000000   torch  codeparrot-small    NaN        NaN
# 61   2024-06-11 18:38:16.000000   torch       pythia-410m    NaN        NaN
# 64   2024-06-11 18:42:32.000000   torch              phi2    NaN        NaN
# 97   2024-06-08 22:51:42.000000   torch             START    NaN        NaN
# 100  2024-06-08 22:54:55.000000   torch        pythia1-4b    NaN        NaN
# 103  2024-06-08 22:58:07.000000   torch         tinyllama    NaN        NaN
# 106  2024-06-08 23:02:23.000000   torch              phi2    NaN        NaN
# 109  2024-06-08 23:04:00.000000   torch  codeparrot-small    NaN        NaN
# 112  2024-06-08 23:07:11.000000   torch       pythia-410m    NaN        NaN
# 143  2024-06-09 00:03:23.000000   torch             START    NaN        NaN
# 146  2024-06-09 00:06:36.000000   torch        pythia1-4b    NaN        NaN
# 149  2024-06-09 00:09:48.000000   torch         tinyllama    NaN        NaN
# 152  2024-06-09 00:14:06.000000   torch              phi2    NaN        NaN
# 155  2024-06-09 00:15:43.000000   torch  codeparrot-small    NaN        NaN
# 158  2024-06-09 00:18:54.000000   torch       pythia-410m    NaN        NaN
# 191  2024-06-09 01:09:11.000000   torch             START    NaN        NaN
# 194  2024-06-09 01:12:24.000000   torch        pythia1-4b    NaN        NaN
# 197  2024-06-09 01:15:36.000000   torch         tinyllama    NaN        NaN
# 200  2024-06-09 01:19:53.000000   torch              phi2    NaN        NaN
# 203  2024-06-09 01:21:30.000000   torch  codeparrot-small    NaN        NaN
# 206  2024-06-09 01:24:41.000000   torch       pythia-410m    NaN        NaN
# 239  2024-06-09 02:14:44.000000   torch             START    NaN        NaN
# 242  2024-06-09 02:17:57.000000   torch        pythia1-4b    NaN        NaN
# 245  2024-06-09 02:21:09.000000   torch         tinyllama    NaN        NaN
# 248  2024-06-09 02:25:26.000000   torch              phi2    NaN        NaN
# 251  2024-06-09 02:27:02.000000   torch  codeparrot-small    NaN        NaN
# 254  2024-06-09 02:30:13.000000   torch       pythia-410m    NaN        NaN
# 287  2024-06-09 03:17:05.000000   torch             START    NaN        NaN
# 290  2024-06-09 03:20:18.000000   torch        pythia1-4b    NaN        NaN
# 293  2024-06-09 03:23:29.000000   torch         tinyllama    NaN        NaN
# 296  2024-06-09 03:27:46.000000   torch              phi2    NaN        NaN
# 299  2024-06-09 03:29:22.000000   torch  codeparrot-small    NaN        NaN
# 302  2024-06-09 03:32:33.000000   torch       pythia-410m    NaN        NaN
# 335  2024-06-09 04:20:14.000000   torch             START    NaN        NaN
# 338  2024-06-09 04:23:27.000000   torch        pythia1-4b    NaN        NaN
# 341  2024-06-09 04:26:39.000000   torch         tinyllama    NaN        NaN
# 344  2024-06-09 04:30:55.000000   torch              phi2    NaN        NaN
# 347  2024-06-09 04:32:32.000000   torch  codeparrot-small    NaN        NaN
# 350  2024-06-09 04:35:43.000000   torch       pythia-410m    NaN        NaN
# 383  2024-06-09 05:23:26.000000   torch             START    NaN        NaN
# 386  2024-06-09 05:26:40.000000   torch        pythia1-4b    NaN        NaN
# 389  2024-06-09 05:29:51.000000   torch         tinyllama    NaN        NaN
# 392  2024-06-09 05:34:07.000000   torch              phi2    NaN        NaN
# 395  2024-06-09 05:35:43.000000   torch  codeparrot-small    NaN        NaN
# 398  2024-06-09 05:38:54.000000   torch       pythia-410m    NaN        NaN
# 431  2024-06-11 17:23:49.000000   torch             START    NaN        NaN
# 434  2024-06-11 17:27:02.000000   torch        pythia1-4b    NaN        NaN
# 437  2024-06-11 17:30:14.000000   torch         tinyllama    NaN        NaN
# 440  2024-06-11 17:31:51.000000   torch  codeparrot-small    NaN        NaN
# 443  2024-06-11 17:35:02.000000   torch       pythia-410m    NaN        NaN
# 446  2024-06-11 17:39:19.000000   torch              phi2    NaN        NaN
#
#      start_end    file                   label    duration  \
# 1          NaN  runall             torch_START  301.000000
# 4          NaN  runall        torch_pythia1-4b  190.224346
# 7          NaN  runall         torch_tinyllama  188.823235
# 10         NaN  runall              torch_phi2  251.210585
# 13         NaN  runall  torch_codeparrot-small   94.157740
# 16         NaN  runall       torch_pythia-410m  189.240295
# 49         NaN  runall             torch_START  301.000000
# 52         NaN  runall        torch_pythia1-4b  189.646066
# 55         NaN  runall         torch_tinyllama  188.644582
# 58         NaN  runall  torch_codeparrot-small   94.652308
# 61         NaN  runall       torch_pythia-410m  188.724857
# 64         NaN  runall              torch_phi2  251.136543
# 97         NaN  runall             torch_START  301.000000
# 100        NaN  runall        torch_pythia1-4b  190.197751
# 103        NaN  runall         torch_tinyllama  188.801976
# 106        NaN  runall              torch_phi2  251.131986
# 109        NaN  runall  torch_codeparrot-small   95.155577
# 112        NaN  runall       torch_pythia-410m  189.635212
# 143        NaN  runall             torch_START  301.000000
# 146        NaN  runall        torch_pythia1-4b  190.333565
# 149        NaN  runall         torch_tinyllama  188.973348
# 152        NaN  runall              torch_phi2  253.328242
# 155        NaN  runall  torch_codeparrot-small   95.105898
# 158        NaN  runall       torch_pythia-410m  189.375270
# 191        NaN  runall             torch_START  301.000000
# 194        NaN  runall        torch_pythia1-4b  190.221426
# 197        NaN  runall         torch_tinyllama  188.812102
# 200        NaN  runall              torch_phi2  252.473396
# 203        NaN  runall  torch_codeparrot-small   94.733058
# 206        NaN  runall       torch_pythia-410m  189.217078
# 239        NaN  runall             torch_START  300.000000
# 242        NaN  runall        torch_pythia1-4b  189.708705
# 245        NaN  runall         torch_tinyllama  188.824329
# 248        NaN  runall              torch_phi2  252.255236
# 251        NaN  runall  torch_codeparrot-small   94.128561
# 254        NaN  runall       torch_pythia-410m  189.274824
# 287        NaN  runall             torch_START  301.000000
# 290        NaN  runall        torch_pythia1-4b  190.340252
# 293        NaN  runall         torch_tinyllama  188.411359
# 296        NaN  runall              torch_phi2  252.464138
# 299        NaN  runall  torch_codeparrot-small   93.886774
# 302        NaN  runall       torch_pythia-410m  189.167949
# 335        NaN  runall             torch_START  301.000000
# 338        NaN  runall        torch_pythia1-4b  190.263022
# 341        NaN  runall         torch_tinyllama  188.965821
# 344        NaN  runall              torch_phi2  251.449030
# 347        NaN  runall  torch_codeparrot-small   94.893645
# 350        NaN  runall       torch_pythia-410m  189.196356
# 383        NaN  runall             torch_START  300.000000
# 386        NaN  runall        torch_pythia1-4b  190.872293
# 389        NaN  runall         torch_tinyllama  188.553905
# 392        NaN  runall              torch_phi2  250.919591
# 395        NaN  runall  torch_codeparrot-small   93.907202
# 398        NaN  runall       torch_pythia-410m  189.067788
# 431        NaN  runall             torch_START  301.000000
# 434        NaN  runall        torch_pythia1-4b  190.029049
# 437        NaN  runall         torch_tinyllama  188.697151
# 440        NaN  runall  torch_codeparrot-small   95.327082
# 443        NaN  runall       torch_pythia-410m  189.564502
# 446        NaN  runall              torch_phi2  252.635954
#
#                            label_time  experiment
# 1               torch_START_inference           1
# 4          torch_pythia1-4b_inference           1
# 7           torch_tinyllama_inference           1
# 10               torch_phi2_inference           1
# 13   torch_codeparrot-small_inference           1
# 16        torch_pythia-410m_inference           1
# 49              torch_START_inference           2
# 52         torch_pythia1-4b_inference           2
# 55          torch_tinyllama_inference           2
# 58   torch_codeparrot-small_inference           2
# 61        torch_pythia-410m_inference           2
# 64               torch_phi2_inference           2
# 97              torch_START_inference           3
# 100        torch_pythia1-4b_inference           3
# 103         torch_tinyllama_inference           3
# 106              torch_phi2_inference           3
# 109  torch_codeparrot-small_inference           3
# 112       torch_pythia-410m_inference           3
# 143             torch_START_inference           4
# 146        torch_pythia1-4b_inference           4
# 149         torch_tinyllama_inference           4
# 152              torch_phi2_inference           4
# 155  torch_codeparrot-small_inference           4
# 158       torch_pythia-410m_inference           4
# 191             torch_START_inference           5
# 194        torch_pythia1-4b_inference           5
# 197         torch_tinyllama_inference           5
# 200              torch_phi2_inference           5
# 203  torch_codeparrot-small_inference           5
# 206       torch_pythia-410m_inference           5
# 239             torch_START_inference           6
# 242        torch_pythia1-4b_inference           6
# 245         torch_tinyllama_inference           6
# 248              torch_phi2_inference           6
# 251  torch_codeparrot-small_inference           6
# 254       torch_pythia-410m_inference           6
# 287             torch_START_inference           7
# 290        torch_pythia1-4b_inference           7
# 293         torch_tinyllama_inference           7
# 296              torch_phi2_inference           7
# 299  torch_codeparrot-small_inference           7
# 302       torch_pythia-410m_inference           7
# 335             torch_START_inference           8
# 338        torch_pythia1-4b_inference           8
# 341         torch_tinyllama_inference           8
# 344              torch_phi2_inference           8
# 347  torch_codeparrot-small_inference           8
# 350       torch_pythia-410m_inference           8
# 383             torch_START_inference           9
# 386        torch_pythia1-4b_inference           9
# 389         torch_tinyllama_inference           9
# 392              torch_phi2_inference           9
# 395  torch_codeparrot-small_inference           9
# 398       torch_pythia-410m_inference           9
# 431             torch_START_inference          10
# 434        torch_pythia1-4b_inference          10
# 437         torch_tinyllama_inference          10
# 440  torch_codeparrot-small_inference          10
# 443       torch_pythia-410m_inference          10
# 446              torch_phi2_inference          10

# %%
models = ['pythia1-4b','tinyllama', 'codeparrot-small', 'pythia-410m' ]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming combined_df is already created and contains the data

# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(20, 6))
    # Setting vert=False makes the box plots horizontal
    plot_df = combined_df[combined_df['label_time'].str.startswith('torch_', na=False)]
    plot_df = combined_df[combined_df['label_time'].str.startswith('torch_', na=False) & combined_df['label_time'].str.endswith('inference', na=False) ]
    plot_df = combined_df[ combined_df['label_time'].str.endswith('_inference', na=False) ]
    
    plot_df.boxplot(column=variable, by='label_time', grid=False, vert=False) #df[df['A'].notna()]
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.ylabel('Label')
    plt.yticks(rotation=0)  # Rotate label ticks if necessary
    plt.tight_layout()  # Adjust layout to make room for labels
    #plt.xlim([0,20])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools  # for cycling through colors if necessary


# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    plot_df = combined_df[ combined_df['label_time'].str.endswith('inference', na=False) ] #all
    plot_df = combined_df[ combined_df['label_time'].str.endswith(models[3]+'_inference', na=False) ] # per runtime
    
    
    
    grouped = plot_df.groupby('label_time')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.tight_layout()  # Adjust layout to make room for labels

plt.show()
