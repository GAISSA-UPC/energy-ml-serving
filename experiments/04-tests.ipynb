# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools  # for cycling through colors if necessary
import glob
import re
import os
from scipy.stats import shapiro

# %%
num_models = 4 #CHANGE
path = "D:/GAISSA/energy-repo/last_repo/june_gpu/"  # Adjust this path to your CSV files location #CHANGE

# %%
configs =['torch_pythia1-4b', 'torch_tinyllama',
       'torch_codeparrot-small', 'torch_pythia-410m', 'onnx_pythia1-4b',
       'onnx_tinyllama', 'onnx_codeparrot-small', 'onnx_pythia-410m',
       'torchscript_pythia1-4b', 'torchscript_tinyllama',
       'torchscript_codeparrot-small', 'torchscript_pythia-410m']

# %%
save_dir = path+"figures/"
tables_dir = path+"tables/"

try:
    os.mkdir(save_dir)
except Exception as e:
    print("could not create directory "+ save_dir )
    print(e)

try:
    os.mkdir(tables_dir)
except Exception as e:
    print("could not create directory "+ tables_dir )
    print(e)
# Out:
# could not create directory D:/GAISSA/energy-repo/last_repo/june_gpu/figures/
# [WinError 183] Cannot create a file when that file already exists: 'D:/GAISSA/energy-repo/last_repo/june_gpu/figures/'
# could not create directory D:/GAISSA/energy-repo/last_repo/june_gpu/tables/
# [WinError 183] Cannot create a file when that file already exists: 'D:/GAISSA/energy-repo/last_repo/june_gpu/tables/'

# %%
def remove_condition_rows(condition_to_remove,df):
    # example: condition = merged_df['label']  == 'idle_idle'
    df1 = df.copy()
    return df1[~condition_to_remove]

# %%
def save_latex_table(df,save_dir):
    df = df.copy()
    df.columns = [col.replace('_', ' ') for col in df.columns]
    
    latex_table = df.to_latex(index=False)

    # Define the filename
    filename = save_dir
    
    # Open the file in write mode
    with open(filename, 'w') as file:
        file.write(latex_table)
        
    # Print LaTeX table
    print(latex_table)

# %% [markdown]
# # RQ1.1: Energy

# %% [markdown]
# ## Energibridge

# %%
# Path where the CSV files are stored
all_files_energi = glob.glob(path + "/results_*/processed/energi_processed.csv")
all_files_energi
# Out:
# ['D:/GAISSA/energy-repo/last_repo/june_gpu\\results_1\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_10\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_2\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_3\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_4\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_5\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_6\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_7\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_8\\processed\\energi_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_9\\processed\\energi_processed.csv']

# %%
result_numbers = []

li = []
for my_file in all_files_energi:
    # The regex pattern to find "results_" followed by one or more digits
    df = pd.read_csv(my_file, index_col=None, header=0)
    
    match = re.search(r'results_(\d+)', my_file)
    if match:
        # Append the found number to the list
        result_numbers.append(int(match.group(1)))

    df['experiment'] = result_numbers[-1]
    li.append(df)

print(result_numbers)
# Combine all data into one DataFrame
energi_df = pd.concat(li, axis=0, ignore_index=True)
energi_df
# Out:
# [1, 10, 2, 3, 4, 5, 6, 7, 8, 9]
#                            time      runtime model  CPU_ENERGY (J)  \
# 0       2024-06-08 21:42:00.400         idle  idle   516616.142639
# 1       2024-06-08 21:42:00.400         idle  idle   516616.207123
# 2       2024-06-08 21:42:00.600         idle  idle   516627.494354
# 3       2024-06-08 21:42:00.800         idle  idle   516639.257111
# 4       2024-06-08 21:42:01.000         idle  idle   516651.727112
# ...                         ...          ...   ...             ...
# 193376  2024-06-11 19:27:32.772  torchscript  phi2   458083.008850
# 193377  2024-06-11 19:27:32.972  torchscript  phi2   458088.296036
# 193378  2024-06-11 19:27:33.172  torchscript  phi2   458092.385895
# 193379  2024-06-11 19:27:33.373  torchscript  phi2   458096.612167
# 193380  2024-06-11 19:27:33.573  torchscript  phi2   458101.048172
#
#         TOTAL_MEMORY  TOTAL_SWAP  USED_MEMORY  USED_SWAP  AVG_CPU_USAGE_SAMP  \
# 0        66575933440  2147479552   2241388544          0            5.237742
# 1        66575933440  2147479552   2246549504          0            5.237742
# 2        66575933440  2147479552   2353451008          0            4.872685
# 3        66575933440  2147479552   2402861056          0            4.872685
# 4        66575933440  2147479552   2452594688          0            6.209758
# ...              ...         ...          ...        ...                 ...
# 193376   66575949824  2147479552  12355092480          0            0.000000
# 193377   66575949824  2147479552  12354756608          0            0.617560
# 193378   66575949824  2147479552  12354756608          0            0.000000
# 193379   66575949824  2147479552  12354756608          0            0.305060
# 193380   66575949824  2147479552  12339982336          0            0.297619
#
#                    label  avg_TOTAL_MEMORY  avg_TOTAL_SWAP  avg_USED_MEMORY  \
# 0              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 1              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 2              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 3              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 4              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# ...                  ...               ...             ...              ...
# 193376  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
# 193377  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
# 193378  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
# 193379  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
# 193380  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
#
#         avg_USED_SWAP  avg_cpu_usage_config       energy  \
# 0                 0.0              0.143838  5356.125122
# 1                 0.0              0.143838  5356.125122
# 2                 0.0              0.143838  5356.125122
# 3                 0.0              0.143838  5356.125122
# 4                 0.0              0.143838  5356.125122
# ...               ...                   ...          ...
# 193376            0.0              0.658319  2812.548523
# 193377            0.0              0.658319  2812.548523
# 193378            0.0              0.658319  2812.548523
# 193379            0.0              0.658319  2812.548523
# 193380            0.0              0.658319  2812.548523
#
#         avg_used_memory_pct_config  experiment
# 0                         4.197672           1
# 1                         4.197672           1
# 2                         4.197672           1
# 3                         4.197672           1
# 4                         4.197672           1
# ...                            ...         ...
# 193376                   18.358024           9
# 193377                   18.358024           9
# 193378                   18.358024           9
# 193379                   18.358024           9
# 193380                   18.358024           9
#
# [193381 rows x 18 columns]

# %%
# ## add "experiment" column 1,2...10

# # List to hold data from each file
# li = []

# # Read each file and append to list
# n=1
# for filename in all_files_energi:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     df['experiment'] = n
#     li.append(df)
#     n+=1
    

# # Combine all data into one DataFrame
# energi_df = pd.concat(li, axis=0, ignore_index=True)
# energi_df

# %%
energi_df.columns
# Out:
# Index(['time', 'runtime', 'model', 'CPU_ENERGY (J)', 'TOTAL_MEMORY',
#        'TOTAL_SWAP', 'USED_MEMORY', 'USED_SWAP', 'AVG_CPU_USAGE_SAMP', 'label',
#        'avg_TOTAL_MEMORY', 'avg_TOTAL_SWAP', 'avg_USED_MEMORY',
#        'avg_USED_SWAP', 'avg_cpu_usage_config', 'energy',
#        'avg_used_memory_pct_config', 'experiment'],
#       dtype='object')

# %%
energi_df
# Out:
#                            time      runtime model  CPU_ENERGY (J)  \
# 0       2024-06-08 21:42:00.400         idle  idle   516616.142639
# 1       2024-06-08 21:42:00.400         idle  idle   516616.207123
# 2       2024-06-08 21:42:00.600         idle  idle   516627.494354
# 3       2024-06-08 21:42:00.800         idle  idle   516639.257111
# 4       2024-06-08 21:42:01.000         idle  idle   516651.727112
# ...                         ...          ...   ...             ...
# 193376  2024-06-11 19:27:32.772  torchscript  phi2   458083.008850
# 193377  2024-06-11 19:27:32.972  torchscript  phi2   458088.296036
# 193378  2024-06-11 19:27:33.172  torchscript  phi2   458092.385895
# 193379  2024-06-11 19:27:33.373  torchscript  phi2   458096.612167
# 193380  2024-06-11 19:27:33.573  torchscript  phi2   458101.048172
#
#         TOTAL_MEMORY  TOTAL_SWAP  USED_MEMORY  USED_SWAP  AVG_CPU_USAGE_SAMP  \
# 0        66575933440  2147479552   2241388544          0            5.237742
# 1        66575933440  2147479552   2246549504          0            5.237742
# 2        66575933440  2147479552   2353451008          0            4.872685
# 3        66575933440  2147479552   2402861056          0            4.872685
# 4        66575933440  2147479552   2452594688          0            6.209758
# ...              ...         ...          ...        ...                 ...
# 193376   66575949824  2147479552  12355092480          0            0.000000
# 193377   66575949824  2147479552  12354756608          0            0.617560
# 193378   66575949824  2147479552  12354756608          0            0.000000
# 193379   66575949824  2147479552  12354756608          0            0.305060
# 193380   66575949824  2147479552  12339982336          0            0.297619
#
#                    label  avg_TOTAL_MEMORY  avg_TOTAL_SWAP  avg_USED_MEMORY  \
# 0              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 1              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 2              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 3              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# 4              idle_idle      6.657593e+10    2.147480e+09     2.794639e+09
# ...                  ...               ...             ...              ...
# 193376  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
# 193377  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
# 193378  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
# 193379  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
# 193380  torchscript_phi2      6.657595e+10    2.147480e+09     1.222203e+10
#
#         avg_USED_SWAP  avg_cpu_usage_config       energy  \
# 0                 0.0              0.143838  5356.125122
# 1                 0.0              0.143838  5356.125122
# 2                 0.0              0.143838  5356.125122
# 3                 0.0              0.143838  5356.125122
# 4                 0.0              0.143838  5356.125122
# ...               ...                   ...          ...
# 193376            0.0              0.658319  2812.548523
# 193377            0.0              0.658319  2812.548523
# 193378            0.0              0.658319  2812.548523
# 193379            0.0              0.658319  2812.548523
# 193380            0.0              0.658319  2812.548523
#
#         avg_used_memory_pct_config  experiment
# 0                         4.197672           1
# 1                         4.197672           1
# 2                         4.197672           1
# 3                         4.197672           1
# 4                         4.197672           1
# ...                            ...         ...
# 193376                   18.358024           9
# 193377                   18.358024           9
# 193378                   18.358024           9
# 193379                   18.358024           9
# 193380                   18.358024           9
#
# [193381 rows x 18 columns]

# %%
# phi2 model had errors

condition = energi_df['label'].str.endswith('phi2')
#remove_condition_rows( condition, energi_df)
#energi_df = energi_df[~condition]
energi_plot = remove_condition_rows( condition, energi_df)
energi_plot
# Out:
#                            time      runtime        model  CPU_ENERGY (J)  \
# 0       2024-06-08 21:42:00.400         idle         idle   516616.142639
# 1       2024-06-08 21:42:00.400         idle         idle   516616.207123
# 2       2024-06-08 21:42:00.600         idle         idle   516627.494354
# 3       2024-06-08 21:42:00.800         idle         idle   516639.257111
# 4       2024-06-08 21:42:01.000         idle         idle   516651.727112
# ...                         ...          ...          ...             ...
# 192830  2024-06-11 19:25:43.190  torchscript  pythia-410m   455249.594849
# 192831  2024-06-11 19:25:43.390  torchscript  pythia-410m   455253.705002
# 192832  2024-06-11 19:25:43.591  torchscript  pythia-410m   455258.060974
# 192833  2024-06-11 19:25:43.791  torchscript  pythia-410m   455262.225143
# 192834  2024-06-11 19:25:43.991  torchscript  pythia-410m   455266.310989
#
#         TOTAL_MEMORY  TOTAL_SWAP  USED_MEMORY  USED_SWAP  AVG_CPU_USAGE_SAMP  \
# 0        66575933440  2147479552   2241388544          0            5.237742
# 1        66575933440  2147479552   2246549504          0            5.237742
# 2        66575933440  2147479552   2353451008          0            4.872685
# 3        66575933440  2147479552   2402861056          0            4.872685
# 4        66575933440  2147479552   2452594688          0            6.209758
# ...              ...         ...          ...        ...                 ...
# 192830   66575949824  2147479552   9003851776          0            0.000000
# 192831   66575949824  2147479552   9003851776          0            0.156250
# 192832   66575949824  2147479552   9003851776          0            0.000000
# 192833   66575949824  2147479552   9003851776          0            0.148810
# 192834   66575949824  2147479552   8988459008          0            0.156250
#
#                           label  avg_TOTAL_MEMORY  avg_TOTAL_SWAP  \
# 0                     idle_idle      6.657593e+10    2.147480e+09
# 1                     idle_idle      6.657593e+10    2.147480e+09
# 2                     idle_idle      6.657593e+10    2.147480e+09
# 3                     idle_idle      6.657593e+10    2.147480e+09
# 4                     idle_idle      6.657593e+10    2.147480e+09
# ...                         ...               ...             ...
# 192830  torchscript_pythia-410m      6.657595e+10    2.147480e+09
# 192831  torchscript_pythia-410m      6.657595e+10    2.147480e+09
# 192832  torchscript_pythia-410m      6.657595e+10    2.147480e+09
# 192833  torchscript_pythia-410m      6.657595e+10    2.147480e+09
# 192834  torchscript_pythia-410m      6.657595e+10    2.147480e+09
#
#         avg_USED_MEMORY  avg_USED_SWAP  avg_cpu_usage_config       energy  \
# 0          2.794639e+09            0.0              0.143838  5356.125122
# 1          2.794639e+09            0.0              0.143838  5356.125122
# 2          2.794639e+09            0.0              0.143838  5356.125122
# 3          2.794639e+09            0.0              0.143838  5356.125122
# 4          2.794639e+09            0.0              0.143838  5356.125122
# ...                 ...            ...                   ...          ...
# 192830     9.000287e+09            0.0              0.278354  2176.047501
# 192831     9.000287e+09            0.0              0.278354  2176.047501
# 192832     9.000287e+09            0.0              0.278354  2176.047501
# 192833     9.000287e+09            0.0              0.278354  2176.047501
# 192834     9.000287e+09            0.0              0.278354  2176.047501
#
#         avg_used_memory_pct_config  experiment
# 0                         4.197672           1
# 1                         4.197672           1
# 2                         4.197672           1
# 3                         4.197672           1
# 4                         4.197672           1
# ...                            ...         ...
# 192830                   13.518826           9
# 192831                   13.518826           9
# 192832                   13.518826           9
# 192833                   13.518826           9
# 192834                   13.518826           9
#
# [150317 rows x 18 columns]

# %%
#condition = energi_plot['label'].str.endswith('idle')

#energi_plot = remove_condition_rows( condition, energi_plot)
#energi_plot

# %%
#energi_plot.rename(columns={'energy': 'Energy (Energibridge) [J]'}, inplace=True)
#energi_plot.rename(columns={'AVG_CPU_USAGE_CONFIG': 'CPU usage (Energibridge) [%]'}, inplace=True)
#energi_plot.rename(columns={'avg_USED_MEMORY': 'Used memory (Energibridge) [B]'}, inplace=True)

# %%
energi_plot.columns
# Out:
# Index(['time', 'runtime', 'model', 'CPU_ENERGY (J)', 'TOTAL_MEMORY',
#        'TOTAL_SWAP', 'USED_MEMORY', 'USED_SWAP', 'AVG_CPU_USAGE_SAMP', 'label',
#        'avg_TOTAL_MEMORY', 'avg_TOTAL_SWAP', 'avg_USED_MEMORY',
#        'avg_USED_SWAP', 'avg_cpu_usage_config', 'energy',
#        'avg_used_memory_pct_config', 'experiment'],
#       dtype='object')

# %%
# Assuming combined_df is already created and contains the data
#variables_to_plot = ['diff_CPU_ENERGY (J)', 'avg_diff_CPU_ENERGY (J)', 'avg_TOTAL_MEMORY', 'minus_avg_USED_MEMORY', 'avg_TOTAL_SWAP']

variables_to_plot = [ 'Energy (Energibridge) [J]', "CPU usage (Energibridge) [%]",  'Used memory (Energibridge) [B]',]
variables_to_plot = [ 'energy', "avg_cpu_usage_config",  'avg_USED_MEMORY','avg_used_memory_pct_config']

# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']
colors=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]
colors = colors[:num_models]
# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label' : runtime_model
    grouped = energi_plot.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    #plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.xlim([0,energi_plot[variable].max()*1.1])
    
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.grid(True)
    plt.tight_layout()  # Adjust layout to make room for labels
    #plt.savefig(save_dir+"energi_"+variable)

plt.show()

# %% [markdown]
# ### Normality test

# %%
configs
# Out:
# ['torch_pythia1-4b',
#  'torch_tinyllama',
#  'torch_codeparrot-small',
#  'torch_pythia-410m',
#  'onnx_pythia1-4b',
#  'onnx_tinyllama',
#  'onnx_codeparrot-small',
#  'onnx_pythia-410m',
#  'torchscript_pythia1-4b',
#  'torchscript_tinyllama',
#  'torchscript_codeparrot-small',
#  'torchscript_pythia-410m']

# %%
cpu_aggregated = energi_plot.groupby(['label', 'experiment'])['energy'].mean().reset_index()
cpu_aggregated
# Out:
#                      label  experiment       energy
# 0                idle_idle           1  5356.125122
# 1                idle_idle           2  5350.155334
# 2                idle_idle           3  5174.852402
# 3                idle_idle           4  5180.039169
# 4                idle_idle           5  5366.871078
# ..                     ...         ...          ...
# 125  torchscript_tinyllama           6  2479.216080
# 126  torchscript_tinyllama           7  2528.263107
# 127  torchscript_tinyllama           8  2645.645905
# 128  torchscript_tinyllama           9  2569.570862
# 129  torchscript_tinyllama          10  2589.686050
#
# [130 rows x 3 columns]

# %%
for c in configs:
    print(c)
    values = shapiro(cpu_aggregated[cpu_aggregated['label'].str.startswith(c, na=False)]['energy'])
    print(values)
# Out:
# torch_pythia1-4b
# ShapiroResult(statistic=0.944939911365509, pvalue=0.6091671586036682)
# torch_tinyllama
# ShapiroResult(statistic=0.9551149606704712, pvalue=0.7290613055229187)
# torch_codeparrot-small
# ShapiroResult(statistic=0.9818145632743835, pvalue=0.9741341471672058)
# torch_pythia-410m
# ShapiroResult(statistic=0.9451891779899597, pvalue=0.612055778503418)
# onnx_pythia1-4b
# ShapiroResult(statistic=0.5012240409851074, pvalue=3.7589488783851266e-06)
# onnx_tinyllama
# ShapiroResult(statistic=0.5922608375549316, pvalue=4.47266866103746e-05)
# onnx_codeparrot-small
# ShapiroResult(statistic=0.5169402956962585, pvalue=5.7489955906930845e-06)
# onnx_pythia-410m
# ShapiroResult(statistic=0.7549026012420654, pvalue=0.0040946705266833305)
# torchscript_pythia1-4b
# ShapiroResult(statistic=0.48267871141433716, pvalue=2.2798833470005775e-06)
# torchscript_tinyllama
# ShapiroResult(statistic=0.9515121579170227, pvalue=0.6864123940467834)
# torchscript_codeparrot-small
# ShapiroResult(statistic=0.9362047910690308, pvalue=0.5116059184074402)
# torchscript_pythia-410m
# ShapiroResult(statistic=0.870549738407135, pvalue=0.10145116597414017)

# %%
from scipy.stats import levene

v = levene(cpu_aggregated[cpu_aggregated['label'].str.startswith(c[0], na=False)]['energy'],
          cpu_aggregated[cpu_aggregated['label'].str.startswith(c[1], na=False)]['energy'],)
print(v)
# Out:
# LeveneResult(statistic=9.482818671510397, pvalue=0.0025803516359201775)

# %%
shapiro(energi_plot['energy'])
# Out:
# D:\GAISSA\energy-repo\my_env\lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=0.8670344948768616, pvalue=0.0)

# %%
# Out:
# ShapiroResult(statistic=0.9551149606704712, pvalue=0.7290613055229187)

# %% [markdown]
# ## Nvidia

# %%
# Path where the CSV files are stored
path = "D:/GAISSA/energy-repo/last_repo/june_gpu/"  # Adjust this path to your CSV files location
all_files_nvidia = glob.glob(path + "/results_*/processed/nvidia*_processed.csv")
all_files_nvidia
# Out:
# ['D:/GAISSA/energy-repo/last_repo/june_gpu\\results_1\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_10\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_2\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_3\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_4\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_5\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_6\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_7\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_8\\processed\\nvidia_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_9\\processed\\nvidia_processed.csv']

# %%
result_numbers = []

li = []
for my_file in all_files_nvidia:
    # The regex pattern to find "results_" followed by one or more digits
    df = pd.read_csv(my_file, index_col=None, header=0)
    
    match = re.search(r'results_(\d+)', my_file)
    if match:
        # Append the found number to the list
        result_numbers.append(int(match.group(1)))

    df['experiment'] = result_numbers[-1]
    li.append(df)

print(result_numbers)
# Combine all data into one DataFrame
nvidia_df = pd.concat(li, axis=0, ignore_index=True)
nvidia_df
# Out:
# [1, 10, 2, 3, 4, 5, 6, 7, 8, 9]
#                            time      runtime       model  \
# 0       2024-06-08 21:47:00.468        torch  pythia1-4b
# 1       2024-06-08 21:47:00.571        torch  pythia1-4b
# 2       2024-06-08 21:47:00.672        torch  pythia1-4b
# 3       2024-06-08 21:47:00.773        torch  pythia1-4b
# 4       2024-06-08 21:47:00.874        torch  pythia1-4b
# ...                         ...          ...         ...
# 354446  2024-06-11 19:27:33.098  torchscript        phi2
# 354447  2024-06-11 19:27:33.199  torchscript        phi2
# 354448  2024-06-11 19:27:33.307  torchscript        phi2
# 354449  2024-06-11 19:27:33.408  torchscript        phi2
# 354450  2024-06-11 19:27:33.509  torchscript        phi2
#
#          utilization.gpu [%]   utilization.memory [%]   memory.total [MiB]  \
# 0                          0                        2                24564
# 1                          0                        2                24564
# 2                          0                        2                24564
# 3                          0                        2                24564
# 4                          0                        2                24564
# ...                      ...                      ...                  ...
# 354446                    13                        8                24564
# 354447                     0                        0                24564
# 354448                     0                        0                24564
# 354449                     0                        0                24564
# 354450                     0                        0                24564
#
#          memory.used [MiB]   power.draw [W]   power.max_limit [W]  \
# 0                       65            11.65                 500.0
# 1                       65            11.66                 500.0
# 2                       65            11.67                 500.0
# 3                       65            11.68                 500.0
# 4                       65            11.70                 500.0
# ...                    ...              ...                   ...
# 354446               14604            75.50                 500.0
# 354447               14604            75.53                 500.0
# 354448               14604            75.61                 500.0
# 354449               14604            75.67                 500.0
# 354450               14604            66.75                 500.0
#
#          temperature.gpu  ... used_memory_pct_mib  avg_utilization_gpu_config  \
# 0                     37  ...            0.264615                   73.584680
# 1                     37  ...            0.264615                   73.584680
# 2                     37  ...            0.264615                   73.584680
# 3                     37  ...            0.264615                   73.584680
# 4                     37  ...            0.264615                   73.584680
# ...                  ...  ...                 ...                         ...
# 354446                43  ...           59.452858                    5.393911
# 354447                42  ...           59.452858                    5.393911
# 354448                42  ...           59.452858                    5.393911
# 354449                42  ...           59.452858                    5.393911
# 354450                42  ...           59.452858                    5.393911
#
#         avg_utilization_memory_config  avg_memory_used_config  \
# 0                           67.165711             6061.018760
# 1                           67.165711             6061.018760
# 2                           67.165711             6061.018760
# 3                           67.165711             6061.018760
# 4                           67.165711             6061.018760
# ...                               ...                     ...
# 354446                       2.355166            14531.867159
# 354447                       2.355166            14531.867159
# 354448                       2.355166            14531.867159
# 354449                       2.355166            14531.867159
# 354450                       2.355166            14531.867159
#
#         avg_power_draw_config  avg_temperature_gpu_config  \
# 0                  178.655961                   49.400730
# 1                  178.655961                   49.400730
# 2                  178.655961                   49.400730
# 3                  178.655961                   49.400730
# 4                  178.655961                   49.400730
# ...                       ...                         ...
# 354446              73.543976                   44.414207
# 354447              73.543976                   44.414207
# 354448              73.543976                   44.414207
# 354449              73.543976                   44.414207
# 354450              73.543976                   44.414207
#
#         avg_used_memory_pct_mib  config_duration        energy  experiment
# 0                     24.674397          193.242  34523.835300           1
# 1                     24.674397          193.242  34523.835300           1
# 2                     24.674397          193.242  34523.835300           1
# 3                     24.674397          193.242  34523.835300           1
# 4                     24.674397          193.242  34523.835300           1
# ...                         ...              ...           ...         ...
# 354446                59.159205          109.296   8038.062403           9
# 354447                59.159205          109.296   8038.062403           9
# 354448                59.159205          109.296   8038.062403           9
# 354449                59.159205          109.296   8038.062403           9
# 354450                59.159205          109.296   8038.062403           9
#
# [354451 rows x 21 columns]

# %%
# ## add number of experiment

# # List to hold data from each file
# li = []

# # Read each file and append to list
# n=1
# for filename in all_files_nvidia:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     df['experiment'] = n
#     li.append(df)
#     n+=1
    

# # Combine all data into one DataFrame
# nvidia_df = pd.concat(li, axis=0, ignore_index=True)
# nvidia_df

# %%
nvidia_df.columns
# Out:
# Index(['time', 'runtime', 'model', ' utilization.gpu [%]',
#        ' utilization.memory [%]', ' memory.total [MiB]', ' memory.used [MiB]',
#        ' power.draw [W]', ' power.max_limit [W]', ' temperature.gpu', 'label',
#        'used_memory_pct_mib', 'avg_utilization_gpu_config',
#        'avg_utilization_memory_config', 'avg_memory_used_config',
#        'avg_power_draw_config', 'avg_temperature_gpu_config',
#        'avg_used_memory_pct_mib', 'config_duration', 'energy', 'experiment'],
#       dtype='object')

# %%
#variables_to_plot = ['diff_CPU_ENERGY (J)','avg_diff_CPU_ENERGY (J)', 'avg_TOTAL_MEMORY', 'avg_TOTAL_SWAP', 'minus_avg_USED_MEMORY', 'minus_avg_USED_SWAP',]
# nvidia variables to plot
#variables_to_plot = ['energy','config_duration','avg_ utilization.gpu [%]','avg_ utilization.memory [%]','avg_ memory.used [MiB]' ,'avg_ temperature.gpu']

#variables_to_plot

# %%
condition = nvidia_df['label'].str.endswith('phi2')
#remove_condition_rows( condition, energi_df)
#energi_df = energi_df[~condition]
nvidia_plot = remove_condition_rows( condition, nvidia_df)
nvidia_plot
# Out:
#                            time      runtime        model  \
# 0       2024-06-08 21:47:00.468        torch   pythia1-4b
# 1       2024-06-08 21:47:00.571        torch   pythia1-4b
# 2       2024-06-08 21:47:00.672        torch   pythia1-4b
# 3       2024-06-08 21:47:00.773        torch   pythia1-4b
# 4       2024-06-08 21:47:00.874        torch   pythia1-4b
# ...                         ...          ...          ...
# 353362  2024-06-11 19:25:43.548  torchscript  pythia-410m
# 353363  2024-06-11 19:25:43.649  torchscript  pythia-410m
# 353364  2024-06-11 19:25:43.750  torchscript  pythia-410m
# 353365  2024-06-11 19:25:43.851  torchscript  pythia-410m
# 353366  2024-06-11 19:25:43.951  torchscript  pythia-410m
#
#          utilization.gpu [%]   utilization.memory [%]   memory.total [MiB]  \
# 0                          0                        2                24564
# 1                          0                        2                24564
# 2                          0                        2                24564
# 3                          0                        2                24564
# 4                          0                        2                24564
# ...                      ...                      ...                  ...
# 353362                     3                        1                24564
# 353363                     0                        0                24564
# 353364                     0                        0                24564
# 353365                     0                        0                24564
# 353366                     0                        0                24564
#
#          memory.used [MiB]   power.draw [W]   power.max_limit [W]  \
# 0                       65            11.65                 500.0
# 1                       65            11.66                 500.0
# 2                       65            11.67                 500.0
# 3                       65            11.68                 500.0
# 4                       65            11.70                 500.0
# ...                    ...              ...                   ...
# 353362               13602            62.51                 500.0
# 353363               13602            62.50                 500.0
# 353364               13602            62.46                 500.0
# 353365               13602            62.40                 500.0
# 353366               13602            61.19                 500.0
#
#          temperature.gpu  ... used_memory_pct_mib  avg_utilization_gpu_config  \
# 0                     37  ...            0.264615                   73.584680
# 1                     37  ...            0.264615                   73.584680
# 2                     37  ...            0.264615                   73.584680
# 3                     37  ...            0.264615                   73.584680
# 4                     37  ...            0.264615                   73.584680
# ...                  ...  ...                 ...                         ...
# 353362                47  ...           55.373718                    1.213198
# 353363                47  ...           55.373718                    1.213198
# 353364                47  ...           55.373718                    1.213198
# 353365                47  ...           55.373718                    1.213198
# 353366                47  ...           55.373718                    1.213198
#
#         avg_utilization_memory_config  avg_memory_used_config  \
# 0                           67.165711              6061.01876
# 1                           67.165711              6061.01876
# 2                           67.165711              6061.01876
# 3                           67.165711              6061.01876
# 4                           67.165711              6061.01876
# ...                               ...                     ...
# 353362                       0.327919             13602.55736
# 353363                       0.327919             13602.55736
# 353364                       0.327919             13602.55736
# 353365                       0.327919             13602.55736
# 353366                       0.327919             13602.55736
#
#         avg_power_draw_config  avg_temperature_gpu_config  \
# 0                  178.655961                   49.400730
# 1                  178.655961                   49.400730
# 2                  178.655961                   49.400730
# 3                  178.655961                   49.400730
# 4                  178.655961                   49.400730
# ...                       ...                         ...
# 353362              64.916294                   52.826396
# 353363              64.916294                   52.826396
# 353364              64.916294                   52.826396
# 353365              64.916294                   52.826396
# 353366              64.916294                   52.826396
#
#         avg_used_memory_pct_mib  config_duration        energy  experiment
# 0                     24.674397          193.242  34523.835300           1
# 1                     24.674397          193.242  34523.835300           1
# 2                     24.674397          193.242  34523.835300           1
# 3                     24.674397          193.242  34523.835300           1
# 4                     24.674397          193.242  34523.835300           1
# ...                         ...              ...           ...         ...
# 353362                55.375987           99.293   6445.733621           9
# 353363                55.375987           99.293   6445.733621           9
# 353364                55.375987           99.293   6445.733621           9
# 353365                55.375987           99.293   6445.733621           9
# 353366                55.375987           99.293   6445.733621           9
#
# [268888 rows x 21 columns]

# %%
#condition = nvidia_plot['label'].str.endswith('idle')

#nvidia_plot = remove_condition_rows( condition, nvidia_plot)
#nvidia_plot

# %%
# #variables_to_plot = ['energy','config_duration','avg_ utilization.gpu [%]','avg_ utilization.memory [%]','avg_ memory.used [MiB]' ,'avg_ temperature.gpu']

# nvidia_plot.rename(columns={'energy': 'Energy (Nvidia-smi) [J]'}, inplace=True)
# nvidia_plot.rename(columns={'config_duration': 'Execution time (Nvidia-smi) [s]'}, inplace=True)
# nvidia_plot.rename(columns={'avg_ utilization.gpu [%]': 'GPU usage (Nvidia-smi) [%]'}, inplace=True)
# nvidia_plot.rename(columns={'avg_ utilization.memory [%]': 'Used memory (Nvidia-smi) [%]'}, inplace=True)
# nvidia_plot.rename(columns={'avg_ memory.used [MiB]': 'Used GPU memory (Nvidia-smi) [MiB]'}, inplace=True)
# nvidia_plot.rename(columns={'avg_ temperature.gpu': 'GPU temperature (Nvidia-smi) [°]'}, inplace=True)

# variables_to_plot = ['Energy (Nvidia-smi) [J]','Execution time (Nvidia-smi) [s]','GPU usage (Nvidia-smi) [%]','Used memory (Nvidia-smi) [%]','Used GPU memory (Nvidia-smi) [MiB]' ,'GPU temperature (Nvidia-smi) [°]']

# %%
nvidia_plot.columns
# Out:
# Index(['time', 'runtime', 'model', ' utilization.gpu [%]',
#        ' utilization.memory [%]', ' memory.total [MiB]', ' memory.used [MiB]',
#        ' power.draw [W]', ' power.max_limit [W]', ' temperature.gpu', 'label',
#        'used_memory_pct_mib', 'avg_utilization_gpu_config',
#        'avg_utilization_memory_config', 'avg_memory_used_config',
#        'avg_power_draw_config', 'avg_temperature_gpu_config',
#        'avg_used_memory_pct_mib', 'config_duration', 'energy', 'experiment'],
#       dtype='object')

# %%
# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']
colors=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]
colors = colors[:num_models]

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

#variables_to_plot = ['energy','config_duration','avg_ utilization.gpu [%]','avg_ utilization.memory [%]','avg_ memory.used [MiB]' ,'avg_ temperature.gpu']
#variables_to_plot = ['Energy (Nvidia-smi) [J]','Execution time (Nvidia-smi) [s]','GPU usage (Nvidia-smi) [%]','Used memory (Nvidia-smi) [%]','Used GPU memory (Nvidia-smi) [MiB]' ,'GPU temperature (Nvidia-smi) [°]']
variables_to_plot = ['energy','config_duration','avg_utilization_gpu_config','avg_utilization_memory_config','avg_memory_used_config' ,
                     'avg_power_draw_config','avg_temperature_gpu_config','avg_used_memory_pct_mib']



n=0
# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    grouped = nvidia_plot.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    #plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')

    plt.xlim([0,nvidia_plot[variable].max()*1.1])
    plt.grid(True)
    
    plt.tight_layout()  # Adjust layout to make room for labels
    
    #plt.savefig(save_dir + "nvidia_"+variable)
    n+=1
plt.show()

# %% [markdown]
# ## Wattmeter

# %%
# Path where the CSV files are stored
path = "D:/GAISSA/energy-repo/last_repo/june_gpu/"  # Adjust this path to your CSV files location
all_files_wattmeter = glob.glob(path + "/results_*/processed/wattmeter*_processed.csv")
all_files_wattmeter
# Out:
# ['D:/GAISSA/energy-repo/last_repo/june_gpu\\results_1\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_10\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_2\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_3\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_4\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_5\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_6\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_7\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_8\\processed\\wattmeter_processed.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_9\\processed\\wattmeter_processed.csv']

# %%
result_numbers = []

li = []
for my_file in all_files_wattmeter:
    # The regex pattern to find "results_" followed by one or more digits
    df = pd.read_csv(my_file, index_col=None, header=0)
    
    match = re.search(r'results_(\d+)', my_file)
    if match:
        # Append the found number to the list
        result_numbers.append(int(match.group(1)))

    df['experiment'] = result_numbers[-1]
    li.append(df)

print(result_numbers)
# Combine all data into one DataFrame
wattmeter_df = pd.concat(li, axis=0, ignore_index=True)
wattmeter_df
# Out:
# [1, 10, 2, 3, 4, 5, 6, 7, 8, 9]
#                              time      runtime       model  Current  \
# 0      2024-06-08 21:47:02.854518        torch  pythia1-4b      717
# 1      2024-06-08 21:47:03.429127        torch  pythia1-4b      717
# 2      2024-06-08 21:47:04.017249        torch  pythia1-4b      812
# 3      2024-06-08 21:47:04.591239        torch  pythia1-4b      812
# 4      2024-06-08 21:47:05.163254        torch  pythia1-4b      812
# ...                           ...          ...         ...      ...
# 41433  2024-06-11 19:27:30.645104  torchscript        phi2      863
# 41434  2024-06-11 19:27:31.221117  torchscript        phi2      863
# 41435  2024-06-11 19:27:31.799037  torchscript        phi2      695
# 41436  2024-06-11 19:27:32.378849  torchscript        phi2      695
# 41437  2024-06-11 19:27:32.961081  torchscript        phi2      695
#
#        PowerFactor   Phase  Energy  EnergyNR  Load             label  \
# 0             1.00  336.26  120086    120086   174  torch_pythia1-4b
# 1             1.00  336.26  120086    120086   174  torch_pythia1-4b
# 2             0.91  335.38  120086    120086   176  torch_pythia1-4b
# 3             0.91  335.38  120086    120086   176  torch_pythia1-4b
# 4             0.91  335.38  120086    120086   176  torch_pythia1-4b
# ...            ...     ...     ...       ...   ...               ...
# 41433         0.64  325.91  128705    128705   132  torchscript_phi2
# 41434         0.64  325.91  128705    128705   132  torchscript_phi2
# 41435         0.73  326.06  128705    128705   123  torchscript_phi2
# 41436         0.73  326.06  128705    128705   123  torchscript_phi2
# 41437         0.73  326.06  128705    128705   123  torchscript_phi2
#
#        energy_joules  energyNR_joules  energy_joules_config  \
# 0          432309600        432309600                 54000
# 1          432309600        432309600                 54000
# 2          432309600        432309600                 54000
# 3          432309600        432309600                 54000
# 4          432309600        432309600                 54000
# ...              ...              ...                   ...
# 41433      463338000        463338000                 18000
# 41434      463338000        463338000                 18000
# 41435      463338000        463338000                 18000
# 41436      463338000        463338000                 18000
# 41437      463338000        463338000                 18000
#
#        energyNR_joules_config  avg_Current  avg_PowerFactor   avg_Phase  \
# 0                       54000  1278.477341         0.931662  343.706465
# 1                       54000  1278.477341         0.931662  343.706465
# 2                       54000  1278.477341         0.931662  343.706465
# 3                       54000  1278.477341         0.931662  343.706465
# 4                       54000  1278.477341         0.931662  343.706465
# ...                       ...          ...              ...         ...
# 41433                   18000   757.942529         0.779713  323.222471
# 41434                   18000   757.942529         0.779713  323.222471
# 41435                   18000   757.942529         0.779713  323.222471
# 41436                   18000   757.942529         0.779713  323.222471
# 41437                   18000   757.942529         0.779713  323.222471
#
#          avg_Load  experiment
# 0      284.371601           1
# 1      284.371601           1
# 2      284.371601           1
# 3      284.371601           1
# 4      284.371601           1
# ...           ...         ...
# 41433  150.931034           9
# 41434  150.931034           9
# 41435  150.931034           9
# 41436  150.931034           9
# 41437  150.931034           9
#
# [41438 rows x 19 columns]

# %%
# ## add experiments number
# # List to hold data from each file
# li = []

# # Read each file and append to list
# n=1
# for filename in all_files_wattmeter:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     df['experiment'] = n
#     li.append(df)
#     n+=1
    

# # Combine all data into one DataFrame
# wattmeter_df = pd.concat(li, axis=0, ignore_index=True)
# wattmeter_df

# %%
wattmeter_df.columns
# Out:
# Index(['time', 'runtime', 'model', 'Current', 'PowerFactor', 'Phase', 'Energy',
#        'EnergyNR', 'Load', 'label', 'energy_joules', 'energyNR_joules',
#        'energy_joules_config', 'energyNR_joules_config', 'avg_Current',
#        'avg_PowerFactor', 'avg_Phase', 'avg_Load', 'experiment'],
#       dtype='object')

# %%
variables_to_plot = ['energy_joules_config', 'avg_Current', 'avg_PowerFactor', 'avg_Phase', 'avg_Load',]

# %%
condition = wattmeter_df['label'].str.endswith('phi2')
#remove_condition_rows( condition, energi_df)
#energi_df = energi_df[~condition]
wattmeter_plot = remove_condition_rows( condition, wattmeter_df)
wattmeter_plot
# Out:
#                              time      runtime        model  Current  \
# 0      2024-06-08 21:47:02.854518        torch   pythia1-4b      717
# 1      2024-06-08 21:47:03.429127        torch   pythia1-4b      717
# 2      2024-06-08 21:47:04.017249        torch   pythia1-4b      812
# 3      2024-06-08 21:47:04.591239        torch   pythia1-4b      812
# 4      2024-06-08 21:47:05.163254        torch   pythia1-4b      812
# ...                           ...          ...          ...      ...
# 41259  2024-06-11 19:25:41.122919  torchscript  pythia-410m      649
# 41260  2024-06-11 19:25:41.702703  torchscript  pythia-410m      649
# 41261  2024-06-11 19:25:42.289644  torchscript  pythia-410m      643
# 41262  2024-06-11 19:25:42.865670  torchscript  pythia-410m      643
# 41263  2024-06-11 19:25:43.441352  torchscript  pythia-410m      643
#
#        PowerFactor   Phase  Energy  EnergyNR  Load                    label  \
# 0             1.00  336.26  120086    120086   174         torch_pythia1-4b
# 1             1.00  336.26  120086    120086   174         torch_pythia1-4b
# 2             0.91  335.38  120086    120086   176         torch_pythia1-4b
# 3             0.91  335.38  120086    120086   176         torch_pythia1-4b
# 4             0.91  335.38  120086    120086   176         torch_pythia1-4b
# ...            ...     ...     ...       ...   ...                      ...
# 41259         0.81  325.63  128700    128700   127  torchscript_pythia-410m
# 41260         0.81  325.63  128700    128700   127  torchscript_pythia-410m
# 41261         0.83  324.62  128700    128700   128  torchscript_pythia-410m
# 41262         0.83  324.62  128700    128700   128  torchscript_pythia-410m
# 41263         0.83  324.62  128700    128700   128  torchscript_pythia-410m
#
#        energy_joules  energyNR_joules  energy_joules_config  \
# 0          432309600        432309600                 54000
# 1          432309600        432309600                 54000
# 2          432309600        432309600                 54000
# 3          432309600        432309600                 54000
# 4          432309600        432309600                 54000
# ...              ...              ...                   ...
# 41259      463320000        463320000                 14400
# 41260      463320000        463320000                 14400
# 41261      463320000        463320000                 14400
# 41262      463320000        463320000                 14400
# 41263      463320000        463320000                 14400
#
#        energyNR_joules_config  avg_Current  avg_PowerFactor   avg_Phase  \
# 0                       54000  1278.477341         0.931662  343.706465
# 1                       54000  1278.477341         0.931662  343.706465
# 2                       54000  1278.477341         0.931662  343.706465
# 3                       54000  1278.477341         0.931662  343.706465
# 4                       54000  1278.477341         0.931662  343.706465
# ...                       ...          ...              ...         ...
# 41259                   14400   680.798817         0.837515  325.907041
# 41260                   14400   680.798817         0.837515  325.907041
# 41261                   14400   680.798817         0.837515  325.907041
# 41262                   14400   680.798817         0.837515  325.907041
# 41263                   14400   680.798817         0.837515  325.907041
#
#          avg_Load  experiment
# 0      284.371601           1
# 1      284.371601           1
# 2      284.371601           1
# 3      284.371601           1
# 4      284.371601           1
# ...           ...         ...
# 41259  138.136095           9
# 41260  138.136095           9
# 41261  138.136095           9
# 41262  138.136095           9
# 41263  138.136095           9
#
# [31803 rows x 19 columns]

# %%
#condition = wattmeter_plot['label'].str.endswith('idle')

#wattmeter_plot = remove_condition_rows( condition, wattmeter_plot)
#wattmeter_plot

# %%
# wattmeter_plot.rename(columns={'energy_joules_config': 'Energy (Wattmeter) [J]'}, inplace=True)
# wattmeter_plot.rename(columns={'avg_Current': 'Current [mA]'}, inplace=True)
# wattmeter_plot.rename(columns={'avg_PowerFactor': 'Power Factor [-]'}, inplace=True)
# wattmeter_plot.rename(columns={'avg_Phase': 'Phase [°]'}, inplace=True)
# wattmeter_plot.rename(columns={'avg_Load': 'Load [W]'}, inplace=True)

# variables_to_plot = ['Energy (Wattmeter) [J]','Current [mA]','Power Factor [-]','Phase [°]' ,'Load [W]']

# %%
# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']
colors=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]
colors = colors[:num_models]

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

#variables_to_plot = ['Energy (Wattmeter) [J]','Current [mA]','Power Factor [-]','Phase [°]' ,'Load [W]']
variables_to_plot = ['energy_joules_config','avg_Current','avg_PowerFactor','avg_Phase' ,'avg_Load']



# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    grouped = wattmeter_plot.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.xlim([0,wattmeter_plot[variable].max()*1.1])
    plt.grid(True)
    
    plt.tight_layout()  # Adjust layout to make room for labels
    #plt.savefig(save_dir + "wattmeter_"+variable)

plt.show()

# %% [markdown]
# ## CPU energy + GPU energy

# %%
print(energi_df['energy'].max())
print(nvidia_df['energy'].max())
print(wattmeter_df['energy_joules_config'].max())
# Out:
# 29052.721954345703
# 68359.50135909596
# 122400

# %% [markdown]
# ### box plots

# %%
energi_df.columns
# Out:
# Index(['time', 'runtime', 'model', 'CPU_ENERGY (J)', 'TOTAL_MEMORY',
#        'TOTAL_SWAP', 'USED_MEMORY', 'USED_SWAP', 'AVG_CPU_USAGE_SAMP', 'label',
#        'avg_TOTAL_MEMORY', 'avg_TOTAL_SWAP', 'avg_USED_MEMORY',
#        'avg_USED_SWAP', 'avg_cpu_usage_config', 'energy',
#        'avg_used_memory_pct_config', 'experiment'],
#       dtype='object')

# %%
energy_energi = energi_df[['runtime','model','label','energy','experiment']]
energy_energi
# Out:
#             runtime model             label       energy  experiment
# 0              idle  idle         idle_idle  5356.125122           1
# 1              idle  idle         idle_idle  5356.125122           1
# 2              idle  idle         idle_idle  5356.125122           1
# 3              idle  idle         idle_idle  5356.125122           1
# 4              idle  idle         idle_idle  5356.125122           1
# ...             ...   ...               ...          ...         ...
# 193376  torchscript  phi2  torchscript_phi2  2812.548523           9
# 193377  torchscript  phi2  torchscript_phi2  2812.548523           9
# 193378  torchscript  phi2  torchscript_phi2  2812.548523           9
# 193379  torchscript  phi2  torchscript_phi2  2812.548523           9
# 193380  torchscript  phi2  torchscript_phi2  2812.548523           9
#
# [193381 rows x 5 columns]

# %%
nvidia_df.columns
# Out:
# Index(['time', 'runtime', 'model', ' utilization.gpu [%]',
#        ' utilization.memory [%]', ' memory.total [MiB]', ' memory.used [MiB]',
#        ' power.draw [W]', ' power.max_limit [W]', ' temperature.gpu', 'label',
#        'used_memory_pct_mib', 'avg_utilization_gpu_config',
#        'avg_utilization_memory_config', 'avg_memory_used_config',
#        'avg_power_draw_config', 'avg_temperature_gpu_config',
#        'avg_used_memory_pct_mib', 'config_duration', 'energy', 'experiment'],
#       dtype='object')

# %%
energy_nvidia = nvidia_df[['runtime','model','label','energy','experiment']]
energy_nvidia
# Out:
#             runtime       model             label        energy  experiment
# 0             torch  pythia1-4b  torch_pythia1-4b  34523.835300           1
# 1             torch  pythia1-4b  torch_pythia1-4b  34523.835300           1
# 2             torch  pythia1-4b  torch_pythia1-4b  34523.835300           1
# 3             torch  pythia1-4b  torch_pythia1-4b  34523.835300           1
# 4             torch  pythia1-4b  torch_pythia1-4b  34523.835300           1
# ...             ...         ...               ...           ...         ...
# 354446  torchscript        phi2  torchscript_phi2   8038.062403           9
# 354447  torchscript        phi2  torchscript_phi2   8038.062403           9
# 354448  torchscript        phi2  torchscript_phi2   8038.062403           9
# 354449  torchscript        phi2  torchscript_phi2   8038.062403           9
# 354450  torchscript        phi2  torchscript_phi2   8038.062403           9
#
# [354451 rows x 5 columns]

# %%
cpu_aggregated = energy_energi.groupby(['label', 'experiment'])['energy'].mean().reset_index()
cpu_aggregated
# Out:
#                      label  experiment       energy
# 0                idle_idle           1  5356.125122
# 1                idle_idle           2  5350.155334
# 2                idle_idle           3  5174.852402
# 3                idle_idle           4  5180.039169
# 4                idle_idle           5  5366.871078
# ..                     ...         ...          ...
# 155  torchscript_tinyllama           6  2479.216080
# 156  torchscript_tinyllama           7  2528.263107
# 157  torchscript_tinyllama           8  2645.645905
# 158  torchscript_tinyllama           9  2569.570862
# 159  torchscript_tinyllama          10  2589.686050
#
# [160 rows x 3 columns]

# %%
gpu_aggregated = energy_nvidia.groupby(['label', 'experiment'])['energy'].mean().reset_index()
gpu_aggregated
# Out:
#                      label  experiment        energy
# 0    onnx_codeparrot-small           1  15938.552931
# 1    onnx_codeparrot-small           2  13823.850824
# 2    onnx_codeparrot-small           3  13896.811929
# 3    onnx_codeparrot-small           4  16083.457295
# 4    onnx_codeparrot-small           5  13918.800235
# ..                     ...         ...           ...
# 145  torchscript_tinyllama           6   7022.551625
# 146  torchscript_tinyllama           7   7052.688061
# 147  torchscript_tinyllama           8   6716.034659
# 148  torchscript_tinyllama           9   7063.159418
# 149  torchscript_tinyllama          10   6554.013410
#
# [150 rows x 3 columns]

# %%
# Merge the aggregated dataframes
merged_df = pd.merge(cpu_aggregated, gpu_aggregated, on=['label', 'experiment'], how='outer')
merged_df
# Out:
#                      label  experiment     energy_x     energy_y
# 0                idle_idle           1  5356.125122          NaN
# 1                idle_idle           2  5350.155334          NaN
# 2                idle_idle           3  5174.852402          NaN
# 3                idle_idle           4  5180.039169          NaN
# 4                idle_idle           5  5366.871078          NaN
# ..                     ...         ...          ...          ...
# 155  torchscript_tinyllama           6  2479.216080  7022.551625
# 156  torchscript_tinyllama           7  2528.263107  7052.688061
# 157  torchscript_tinyllama           8  2645.645905  6716.034659
# 158  torchscript_tinyllama           9  2569.570862  7063.159418
# 159  torchscript_tinyllama          10  2589.686050  6554.013410
#
# [160 rows x 4 columns]

# %%
merged_df.fillna(0, inplace=True)
merged_df
# Out:
#                      label  experiment     energy_x     energy_y
# 0                idle_idle           1  5356.125122     0.000000
# 1                idle_idle           2  5350.155334     0.000000
# 2                idle_idle           3  5174.852402     0.000000
# 3                idle_idle           4  5180.039169     0.000000
# 4                idle_idle           5  5366.871078     0.000000
# ..                     ...         ...          ...          ...
# 155  torchscript_tinyllama           6  2479.216080  7022.551625
# 156  torchscript_tinyllama           7  2528.263107  7052.688061
# 157  torchscript_tinyllama           8  2645.645905  6716.034659
# 158  torchscript_tinyllama           9  2569.570862  7063.159418
# 159  torchscript_tinyllama          10  2589.686050  6554.013410
#
# [160 rows x 4 columns]

# %%
#merged_df.loc[merged_df['label'] == 'idle_idle']

# %%
#merged_df.loc[merged_df['label'] == 'onnx_tinyllama']

# %%
path
# Out:
# 'D:/GAISSA/energy-repo/last_repo/june_gpu/'

# %%
# merged_df.rename(columns={'energy_x': 'CPU energy (config) [J]'}, inplace=True)
# merged_df.rename(columns={'energy_y': 'GPU energy (config) [J]'}, inplace=True)
# merged_df['Total energy [J]'] = merged_df['CPU energy (config) [J]'] + merged_df['GPU energy (config) [J]'] 
merged_df.rename(columns={'energy_x': 'CPU_energy'}, inplace=True)
merged_df.rename(columns={'energy_y': 'GPU_energy'}, inplace=True)
merged_df['global_energy'] = merged_df['CPU_energy'] + merged_df['GPU_energy'] 
merged_df
# Out:
#                      label  experiment   CPU_energy   GPU_energy  \
# 0                idle_idle           1  5356.125122     0.000000
# 1                idle_idle           2  5350.155334     0.000000
# 2                idle_idle           3  5174.852402     0.000000
# 3                idle_idle           4  5180.039169     0.000000
# 4                idle_idle           5  5366.871078     0.000000
# ..                     ...         ...          ...          ...
# 155  torchscript_tinyllama           6  2479.216080  7022.551625
# 156  torchscript_tinyllama           7  2528.263107  7052.688061
# 157  torchscript_tinyllama           8  2645.645905  6716.034659
# 158  torchscript_tinyllama           9  2569.570862  7063.159418
# 159  torchscript_tinyllama          10  2589.686050  6554.013410
#
#      global_energy
# 0      5356.125122
# 1      5350.155334
# 2      5174.852402
# 3      5180.039169
# 4      5366.871078
# ..             ...
# 155    9501.767705
# 156    9580.951168
# 157    9361.680564
# 158    9632.730280
# 159    9143.699460
#
# [160 rows x 5 columns]

# %%
condition = merged_df['label'].str.endswith('phi2')
#remove_condition_rows( condition, energi_df)
#energi_df = energi_df[~condition]
merged_df_plot = remove_condition_rows( condition, merged_df)
merged_df_plot
# Out:
#                      label  experiment   CPU_energy   GPU_energy  \
# 0                idle_idle           1  5356.125122     0.000000
# 1                idle_idle           2  5350.155334     0.000000
# 2                idle_idle           3  5174.852402     0.000000
# 3                idle_idle           4  5180.039169     0.000000
# 4                idle_idle           5  5366.871078     0.000000
# ..                     ...         ...          ...          ...
# 155  torchscript_tinyllama           6  2479.216080  7022.551625
# 156  torchscript_tinyllama           7  2528.263107  7052.688061
# 157  torchscript_tinyllama           8  2645.645905  6716.034659
# 158  torchscript_tinyllama           9  2569.570862  7063.159418
# 159  torchscript_tinyllama          10  2589.686050  6554.013410
#
#      global_energy
# 0      5356.125122
# 1      5350.155334
# 2      5174.852402
# 3      5180.039169
# 4      5366.871078
# ..             ...
# 155    9501.767705
# 156    9580.951168
# 157    9361.680564
# 158    9632.730280
# 159    9143.699460
#
# [130 rows x 5 columns]

# %%
print(tables_dir)
merged_df_plot.to_csv(tables_dir+'final_energy_data.csv', index=False)
# Out:
# D:/GAISSA/energy-repo/last_repo/june_gpu/tables/

# %%
merged_df_plot
# Out:
#                      label  experiment   CPU_energy   GPU_energy  \
# 0                idle_idle           1  5356.125122     0.000000
# 1                idle_idle           2  5350.155334     0.000000
# 2                idle_idle           3  5174.852402     0.000000
# 3                idle_idle           4  5180.039169     0.000000
# 4                idle_idle           5  5366.871078     0.000000
# ..                     ...         ...          ...          ...
# 155  torchscript_tinyllama           6  2479.216080  7022.551625
# 156  torchscript_tinyllama           7  2528.263107  7052.688061
# 157  torchscript_tinyllama           8  2645.645905  6716.034659
# 158  torchscript_tinyllama           9  2569.570862  7063.159418
# 159  torchscript_tinyllama          10  2589.686050  6554.013410
#
#      global_energy
# 0      5356.125122
# 1      5350.155334
# 2      5174.852402
# 3      5180.039169
# 4      5366.871078
# ..             ...
# 155    9501.767705
# 156    9580.951168
# 157    9361.680564
# 158    9632.730280
# 159    9143.699460
#
# [130 rows x 5 columns]

# %%
# condition = merged_df_plot['label'] == 'idle_idle'
# merged_df_plot = merged_df_plot[~condition]
# merged_df_plot

# %%
variables_to_plot = ['CPU_energy','GPU_energy','global_energy']
# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']
colors=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]
colors = colors[:num_models]

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

n=0
# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    grouped = merged_df_plot.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color
        
        #median = np.median(group[variable].dropna())
        #print(name +" -> "+ str(median))

    # Customizing plot
    #plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.xlim([0,merged_df_plot[variable].max()*1.1])
    plt.grid(True)
    
    plt.tight_layout()  # Adjust layout to make room for labels
    
    plt.savefig(save_dir + "energy_"+variable)
    n+=1
plt.show()

# %% [markdown]
# ### Median values of energy

# %%
# Calculate mean values for each label
df = merged_df_plot
median_energy_values = df.groupby('label').median()

# Optionally, you might want to reset the index if you need 'label' as a column
median_energy_values.reset_index(inplace=True)

#median_energy_values = median_energy_values.drop(columns = ['experiment'])
median_energy_values
# Out:
#                            label  experiment    CPU_energy    GPU_energy  \
# 0                      idle_idle         5.5   5331.372978      0.000000
# 1          onnx_codeparrot-small         5.5   9081.845177  13986.934956
# 2               onnx_pythia-410m         5.5  21988.519135  33065.796229
# 3                onnx_pythia1-4b         5.5  26553.710274  59124.014519
# 4                 onnx_tinyllama         5.5  20832.141495  46703.842778
# 5         torch_codeparrot-small         5.5   4424.862007   8426.396317
# 6              torch_pythia-410m         5.5   8847.555695  17862.435892
# 7               torch_pythia1-4b         5.5   9833.124313  31640.409523
# 8                torch_tinyllama         5.5   8958.797241  27899.111313
# 9   torchscript_codeparrot-small         5.5   1900.725342   5820.772408
# 10       torchscript_pythia-410m         5.5   2052.937462   6125.729891
# 11        torchscript_pythia1-4b         5.5   2285.345505   6844.454184
# 12         torchscript_tinyllama         5.5   2543.364494   7057.923739
#
#     global_energy
# 0     5331.372978
# 1    23077.985648
# 2    55228.025927
# 3    85651.403900
# 4    67800.167767
# 5    12825.179010
# 6    26693.627340
# 7    41433.656472
# 8    36827.716835
# 9     7706.116044
# 10    8163.630851
# 11    9111.162026
# 12    9535.773841

# %%
# Split the 'label' column into 'runtime' and 'model'
median_energy_values[['runtime', 'model']] = median_energy_values['label'].str.split('_', n=1, expand=True)
median_energy_values
# Out:
#                            label  experiment    CPU_energy    GPU_energy  \
# 0                      idle_idle         5.5   5331.372978      0.000000
# 1          onnx_codeparrot-small         5.5   9081.845177  13986.934956
# 2               onnx_pythia-410m         5.5  21988.519135  33065.796229
# 3                onnx_pythia1-4b         5.5  26553.710274  59124.014519
# 4                 onnx_tinyllama         5.5  20832.141495  46703.842778
# 5         torch_codeparrot-small         5.5   4424.862007   8426.396317
# 6              torch_pythia-410m         5.5   8847.555695  17862.435892
# 7               torch_pythia1-4b         5.5   9833.124313  31640.409523
# 8                torch_tinyllama         5.5   8958.797241  27899.111313
# 9   torchscript_codeparrot-small         5.5   1900.725342   5820.772408
# 10       torchscript_pythia-410m         5.5   2052.937462   6125.729891
# 11        torchscript_pythia1-4b         5.5   2285.345505   6844.454184
# 12         torchscript_tinyllama         5.5   2543.364494   7057.923739
#
#     global_energy      runtime             model
# 0     5331.372978         idle              idle
# 1    23077.985648         onnx  codeparrot-small
# 2    55228.025927         onnx       pythia-410m
# 3    85651.403900         onnx        pythia1-4b
# 4    67800.167767         onnx         tinyllama
# 5    12825.179010        torch  codeparrot-small
# 6    26693.627340        torch       pythia-410m
# 7    41433.656472        torch        pythia1-4b
# 8    36827.716835        torch         tinyllama
# 9     7706.116044  torchscript  codeparrot-small
# 10    8163.630851  torchscript       pythia-410m
# 11    9111.162026  torchscript        pythia1-4b
# 12    9535.773841  torchscript         tinyllama

# %%
# Define the new order of the columns
#new_order = ['label', 'Used memory (Energibridge) [B]','CPU usage (Energibridge) [%]', 'runtime', 'model']
new_order= list(median_energy_values.columns[-2:]) + list(median_energy_values.columns[:-2])
# Reorder the columns by indexing in the new order
median_energy_values = median_energy_values[new_order]
median_energy_values
# Out:
#         runtime             model                         label  experiment  \
# 0          idle              idle                     idle_idle         5.5
# 1          onnx  codeparrot-small         onnx_codeparrot-small         5.5
# 2          onnx       pythia-410m              onnx_pythia-410m         5.5
# 3          onnx        pythia1-4b               onnx_pythia1-4b         5.5
# 4          onnx         tinyllama                onnx_tinyllama         5.5
# 5         torch  codeparrot-small        torch_codeparrot-small         5.5
# 6         torch       pythia-410m             torch_pythia-410m         5.5
# 7         torch        pythia1-4b              torch_pythia1-4b         5.5
# 8         torch         tinyllama               torch_tinyllama         5.5
# 9   torchscript  codeparrot-small  torchscript_codeparrot-small         5.5
# 10  torchscript       pythia-410m       torchscript_pythia-410m         5.5
# 11  torchscript        pythia1-4b        torchscript_pythia1-4b         5.5
# 12  torchscript         tinyllama         torchscript_tinyllama         5.5
#
#       CPU_energy    GPU_energy  global_energy
# 0    5331.372978      0.000000    5331.372978
# 1    9081.845177  13986.934956   23077.985648
# 2   21988.519135  33065.796229   55228.025927
# 3   26553.710274  59124.014519   85651.403900
# 4   20832.141495  46703.842778   67800.167767
# 5    4424.862007   8426.396317   12825.179010
# 6    8847.555695  17862.435892   26693.627340
# 7    9833.124313  31640.409523   41433.656472
# 8    8958.797241  27899.111313   36827.716835
# 9    1900.725342   5820.772408    7706.116044
# 10   2052.937462   6125.729891    8163.630851
# 11   2285.345505   6844.454184    9111.162026
# 12   2543.364494   7057.923739    9535.773841

# %%
median_energy_values.to_csv(tables_dir+'median_energy_values.csv', index=False)

# %%
median_energy_values = median_energy_values.drop(columns = ['label','experiment'])

# %%
median_energy_values
# Out:
#         runtime             model    CPU_energy    GPU_energy  global_energy
# 0          idle              idle   5331.372978      0.000000    5331.372978
# 1          onnx  codeparrot-small   9081.845177  13986.934956   23077.985648
# 2          onnx       pythia-410m  21988.519135  33065.796229   55228.025927
# 3          onnx        pythia1-4b  26553.710274  59124.014519   85651.403900
# 4          onnx         tinyllama  20832.141495  46703.842778   67800.167767
# 5         torch  codeparrot-small   4424.862007   8426.396317   12825.179010
# 6         torch       pythia-410m   8847.555695  17862.435892   26693.627340
# 7         torch        pythia1-4b   9833.124313  31640.409523   41433.656472
# 8         torch         tinyllama   8958.797241  27899.111313   36827.716835
# 9   torchscript  codeparrot-small   1900.725342   5820.772408    7706.116044
# 10  torchscript       pythia-410m   2052.937462   6125.729891    8163.630851
# 11  torchscript        pythia1-4b   2285.345505   6844.454184    9111.162026
# 12  torchscript         tinyllama   2543.364494   7057.923739    9535.773841

# %%
filename = tables_dir + 'median_energy_values.tex'
save_latex_table(median_energy_values,filename)
# Out:
# \begin{tabular}{llrrr}
# \toprule
# runtime & model & CPU energy & GPU energy & global energy \\
# \midrule
# idle & idle & 5331.372978 & 0.000000 & 5331.372978 \\
# onnx & codeparrot-small & 9081.845177 & 13986.934956 & 23077.985648 \\
# onnx & pythia-410m & 21988.519135 & 33065.796229 & 55228.025927 \\
# onnx & pythia1-4b & 26553.710274 & 59124.014519 & 85651.403900 \\
# onnx & tinyllama & 20832.141495 & 46703.842778 & 67800.167767 \\
# torch & codeparrot-small & 4424.862007 & 8426.396317 & 12825.179010 \\
# torch & pythia-410m & 8847.555695 & 17862.435892 & 26693.627340 \\
# torch & pythia1-4b & 9833.124313 & 31640.409523 & 41433.656472 \\
# torch & tinyllama & 8958.797241 & 27899.111313 & 36827.716835 \\
# torchscript & codeparrot-small & 1900.725342 & 5820.772408 & 7706.116044 \\
# torchscript & pythia-410m & 2052.937462 & 6125.729891 & 8163.630851 \\
# torchscript & pythia1-4b & 2285.345505 & 6844.454184 & 9111.162026 \\
# torchscript & tinyllama & 2543.364494 & 7057.923739 & 9535.773841 \\
# \bottomrule
# \end{tabular}

# %%
# # Convert DataFrame to LaTeX table
# latex_table = median_energy_values.to_latex(index=False)

# # Define the filename
#filename = tables_dir + 'median_energy_values.tex'

# # Open the file in write mode
# with open(filename, 'w') as file:
#     file.write(latex_table)
    
# # Print LaTeX table
# print(latex_table)

# %% [markdown]
# ### Mean values of energy

# %%
# Calculate mean values for each label
df = merged_df_plot
mean_values = df.groupby('label').mean()

# Optionally, you might want to reset the index if you need 'label' as a column
mean_values.reset_index(inplace=True)

mean_values = mean_values.drop(columns = ['experiment'])
mean_values
# Out:
#                            label    CPU_energy    GPU_energy  global_energy
# 0                      idle_idle   5354.569939      0.000000    5354.569939
# 1          onnx_codeparrot-small   9194.086356  14631.469502   23825.555858
# 2               onnx_pythia-410m  22350.111249  34808.775192   57158.886441
# 3                onnx_pythia1-4b  26786.079912  61798.101714   88584.181626
# 4                 onnx_tinyllama  21072.893358  48866.637895   69939.531253
# 5         torch_codeparrot-small   4422.490605   8369.469636   12791.960241
# 6              torch_pythia-410m   8855.930324  18604.837062   27460.767386
# 7               torch_pythia1-4b   9832.710625  32161.237077   41993.947702
# 8                torch_tinyllama   8952.919618  29059.657966   38012.577585
# 9   torchscript_codeparrot-small   1907.680121   5779.068408    7686.748529
# 10       torchscript_pythia-410m   2088.411020   6085.970089    8174.381109
# 11        torchscript_pythia1-4b   2430.155602   6982.055605    9412.211207
# 12         torchscript_tinyllama   2536.219955   6976.315750    9512.535706

# %%
pwd
# Out:
# 'D:\\GAISSA\\energy-repo\\last_repo\\energy-ml-serving\\experiments'

# %%
# Split the 'label' column into 'runtime' and 'model'
mean_values[['runtime', 'model']] = mean_values['label'].str.split('_', n=1, expand=True)
#df[['runtime', 'model']] = df['label'].str.split('_', n=1, expand=True)
mean_values
# Out:
#                            label    CPU_energy    GPU_energy  global_energy  \
# 0                      idle_idle   5354.569939      0.000000    5354.569939
# 1          onnx_codeparrot-small   9194.086356  14631.469502   23825.555858
# 2               onnx_pythia-410m  22350.111249  34808.775192   57158.886441
# 3                onnx_pythia1-4b  26786.079912  61798.101714   88584.181626
# 4                 onnx_tinyllama  21072.893358  48866.637895   69939.531253
# 5         torch_codeparrot-small   4422.490605   8369.469636   12791.960241
# 6              torch_pythia-410m   8855.930324  18604.837062   27460.767386
# 7               torch_pythia1-4b   9832.710625  32161.237077   41993.947702
# 8                torch_tinyllama   8952.919618  29059.657966   38012.577585
# 9   torchscript_codeparrot-small   1907.680121   5779.068408    7686.748529
# 10       torchscript_pythia-410m   2088.411020   6085.970089    8174.381109
# 11        torchscript_pythia1-4b   2430.155602   6982.055605    9412.211207
# 12         torchscript_tinyllama   2536.219955   6976.315750    9512.535706
#
#         runtime             model
# 0          idle              idle
# 1          onnx  codeparrot-small
# 2          onnx       pythia-410m
# 3          onnx        pythia1-4b
# 4          onnx         tinyllama
# 5         torch  codeparrot-small
# 6         torch       pythia-410m
# 7         torch        pythia1-4b
# 8         torch         tinyllama
# 9   torchscript  codeparrot-small
# 10  torchscript       pythia-410m
# 11  torchscript        pythia1-4b
# 12  torchscript         tinyllama

# %%
mean_values.to_csv(tables_dir+'mean_values_by_label.csv', index=False)

# %%
mean_values = mean_values.drop(columns = ['label'])
mean_values
# Out:
#       CPU_energy    GPU_energy  global_energy      runtime             model
# 0    5354.569939      0.000000    5354.569939         idle              idle
# 1    9194.086356  14631.469502   23825.555858         onnx  codeparrot-small
# 2   22350.111249  34808.775192   57158.886441         onnx       pythia-410m
# 3   26786.079912  61798.101714   88584.181626         onnx        pythia1-4b
# 4   21072.893358  48866.637895   69939.531253         onnx         tinyllama
# 5    4422.490605   8369.469636   12791.960241        torch  codeparrot-small
# 6    8855.930324  18604.837062   27460.767386        torch       pythia-410m
# 7    9832.710625  32161.237077   41993.947702        torch        pythia1-4b
# 8    8952.919618  29059.657966   38012.577585        torch         tinyllama
# 9    1907.680121   5779.068408    7686.748529  torchscript  codeparrot-small
# 10   2088.411020   6085.970089    8174.381109  torchscript       pythia-410m
# 11   2430.155602   6982.055605    9412.211207  torchscript        pythia1-4b
# 12   2536.219955   6976.315750    9512.535706  torchscript         tinyllama

# %%
filename = tables_dir + 'mean_energy_values.tex'
save_latex_table(mean_values,filename)
# Out:
# \begin{tabular}{rrrll}
# \toprule
# CPU energy & GPU energy & global energy & runtime & model \\
# \midrule
# 5354.569939 & 0.000000 & 5354.569939 & idle & idle \\
# 9194.086356 & 14631.469502 & 23825.555858 & onnx & codeparrot-small \\
# 22350.111249 & 34808.775192 & 57158.886441 & onnx & pythia-410m \\
# 26786.079912 & 61798.101714 & 88584.181626 & onnx & pythia1-4b \\
# 21072.893358 & 48866.637895 & 69939.531253 & onnx & tinyllama \\
# 4422.490605 & 8369.469636 & 12791.960241 & torch & codeparrot-small \\
# 8855.930324 & 18604.837062 & 27460.767386 & torch & pythia-410m \\
# 9832.710625 & 32161.237077 & 41993.947702 & torch & pythia1-4b \\
# 8952.919618 & 29059.657966 & 38012.577585 & torch & tinyllama \\
# 1907.680121 & 5779.068408 & 7686.748529 & torchscript & codeparrot-small \\
# 2088.411020 & 6085.970089 & 8174.381109 & torchscript & pythia-410m \\
# 2430.155602 & 6982.055605 & 9412.211207 & torchscript & pythia1-4b \\
# 2536.219955 & 6976.315750 & 9512.535706 & torchscript & tinyllama \\
# \bottomrule
# \end{tabular}

# %%
# # Convert DataFrame to LaTeX table
# latex_table = mean_values.to_latex(index=False)

# # Define the filename
# filename = tables_dir + 'mean_energy_values.tex'

# # Open the file in write mode
# with open(filename, 'w') as file:
#     file.write(latex_table)
    
# # Print LaTeX table
# print(latex_table)

# %% [markdown]
# # RQ1.2

# %% [markdown]
# ## Resource utilization: Energibridge: CPU usage, Used memory

# %%
#variables_to_plot = [ 'Energy (Energibridge) [J]', "CPU usage (Energibridge) [%]",  'Used memory (Energibridge) [B]',]

variables_to_plot = [ 'energy', "avg_cpu_usage_config",  'avg_USED_MEMORY','avg_used_memory_pct_config']

# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']
colors=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]
colors = colors[:num_models]
# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label' : runtime_model
    grouped = energi_plot.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    #plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.xlim([0,energi_plot[variable].max()*1.1])
    
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.grid(True)
    plt.tight_layout()  # Adjust layout to make room for labels
    plt.savefig(save_dir+"energi_"+variable)

plt.show()

# %%
energi_plot.head()
# Out:
#                       time runtime model  CPU_ENERGY (J)  TOTAL_MEMORY  \
# 0  2024-06-08 21:42:00.400    idle  idle   516616.142639   66575933440
# 1  2024-06-08 21:42:00.400    idle  idle   516616.207123   66575933440
# 2  2024-06-08 21:42:00.600    idle  idle   516627.494354   66575933440
# 3  2024-06-08 21:42:00.800    idle  idle   516639.257111   66575933440
# 4  2024-06-08 21:42:01.000    idle  idle   516651.727112   66575933440
#
#    TOTAL_SWAP  USED_MEMORY  USED_SWAP  AVG_CPU_USAGE_SAMP      label  \
# 0  2147479552   2241388544          0            5.237742  idle_idle
# 1  2147479552   2246549504          0            5.237742  idle_idle
# 2  2147479552   2353451008          0            4.872685  idle_idle
# 3  2147479552   2402861056          0            4.872685  idle_idle
# 4  2147479552   2452594688          0            6.209758  idle_idle
#
#    avg_TOTAL_MEMORY  avg_TOTAL_SWAP  avg_USED_MEMORY  avg_USED_SWAP  \
# 0      6.657593e+10    2.147480e+09     2.794639e+09            0.0
# 1      6.657593e+10    2.147480e+09     2.794639e+09            0.0
# 2      6.657593e+10    2.147480e+09     2.794639e+09            0.0
# 3      6.657593e+10    2.147480e+09     2.794639e+09            0.0
# 4      6.657593e+10    2.147480e+09     2.794639e+09            0.0
#
#    avg_cpu_usage_config       energy  avg_used_memory_pct_config  experiment
# 0              0.143838  5356.125122                    4.197672           1
# 1              0.143838  5356.125122                    4.197672           1
# 2              0.143838  5356.125122                    4.197672           1
# 3              0.143838  5356.125122                    4.197672           1
# 4              0.143838  5356.125122                    4.197672           1

# %%
#variables_to_plot = [ 'energy', "avg_cpu_usage_config",  'avg_USED_MEMORY','avg_used_memory_pct_config']

resource_energi = energi_plot[['label',"avg_cpu_usage_config",  'avg_USED_MEMORY','avg_used_memory_pct_config']]

resource_energi
# Out:
#                           label  avg_cpu_usage_config  avg_USED_MEMORY  \
# 0                     idle_idle              0.143838     2.794639e+09
# 1                     idle_idle              0.143838     2.794639e+09
# 2                     idle_idle              0.143838     2.794639e+09
# 3                     idle_idle              0.143838     2.794639e+09
# 4                     idle_idle              0.143838     2.794639e+09
# ...                         ...                   ...              ...
# 192830  torchscript_pythia-410m              0.278354     9.000287e+09
# 192831  torchscript_pythia-410m              0.278354     9.000287e+09
# 192832  torchscript_pythia-410m              0.278354     9.000287e+09
# 192833  torchscript_pythia-410m              0.278354     9.000287e+09
# 192834  torchscript_pythia-410m              0.278354     9.000287e+09
#
#         avg_used_memory_pct_config
# 0                         4.197672
# 1                         4.197672
# 2                         4.197672
# 3                         4.197672
# 4                         4.197672
# ...                            ...
# 192830                   13.518826
# 192831                   13.518826
# 192832                   13.518826
# 192833                   13.518826
# 192834                   13.518826
#
# [150317 rows x 4 columns]

# %% [markdown]
# ### CPU usage and Used memory

# %%
# Calculate mean values for each label
df = resource_energi
median_resource_energi = df.groupby('label').median()

# Optionally, you might want to reset the index if you need 'label' as a column
median_resource_energi.reset_index(inplace=True)

#median_energy_values = median_energy_values.drop(columns = ['experiment'])
median_resource_energi
# Out:
#                            label  avg_cpu_usage_config  avg_USED_MEMORY  \
# 0                      idle_idle              0.110316     2.495251e+09
# 1          onnx_codeparrot-small              3.991848     5.463905e+09
# 2               onnx_pythia-410m              3.422415     6.463005e+09
# 3                onnx_pythia1-4b              3.379086     4.971254e+09
# 4                 onnx_tinyllama              3.736836     5.061456e+09
# 5         torch_codeparrot-small              2.443924     3.546823e+09
# 6              torch_pythia-410m              2.491036     3.558276e+09
# 7               torch_pythia1-4b              2.993023     3.378596e+09
# 8                torch_tinyllama              2.573948     3.432273e+09
# 9   torchscript_codeparrot-small              0.158259     1.006792e+10
# 10       torchscript_pythia-410m              0.275700     1.010381e+10
# 11        torchscript_pythia1-4b              0.394041     7.035944e+09
# 12         torchscript_tinyllama              0.532322     7.227496e+09
#
#     avg_used_memory_pct_config
# 0                     3.747977
# 1                     8.207026
# 2                     9.707720
# 3                     7.467044
# 4                     7.602531
# 5                     5.327485
# 6                     5.344688
# 7                     5.074801
# 8                     5.155426
# 9                    15.122467
# 10                   15.176368
# 11                   10.568300
# 12                   10.856019

# %%
# Split the 'label' column into 'runtime' and 'model'
median_resource_energi[['runtime', 'model']] = median_resource_energi['label'].str.split('_', n=1, expand=True)
median_resource_energi
# Out:
#                            label  avg_cpu_usage_config  avg_USED_MEMORY  \
# 0                      idle_idle              0.110316     2.495251e+09
# 1          onnx_codeparrot-small              3.991848     5.463905e+09
# 2               onnx_pythia-410m              3.422415     6.463005e+09
# 3                onnx_pythia1-4b              3.379086     4.971254e+09
# 4                 onnx_tinyllama              3.736836     5.061456e+09
# 5         torch_codeparrot-small              2.443924     3.546823e+09
# 6              torch_pythia-410m              2.491036     3.558276e+09
# 7               torch_pythia1-4b              2.993023     3.378596e+09
# 8                torch_tinyllama              2.573948     3.432273e+09
# 9   torchscript_codeparrot-small              0.158259     1.006792e+10
# 10       torchscript_pythia-410m              0.275700     1.010381e+10
# 11        torchscript_pythia1-4b              0.394041     7.035944e+09
# 12         torchscript_tinyllama              0.532322     7.227496e+09
#
#     avg_used_memory_pct_config      runtime             model
# 0                     3.747977         idle              idle
# 1                     8.207026         onnx  codeparrot-small
# 2                     9.707720         onnx       pythia-410m
# 3                     7.467044         onnx        pythia1-4b
# 4                     7.602531         onnx         tinyllama
# 5                     5.327485        torch  codeparrot-small
# 6                     5.344688        torch       pythia-410m
# 7                     5.074801        torch        pythia1-4b
# 8                     5.155426        torch         tinyllama
# 9                    15.122467  torchscript  codeparrot-small
# 10                   15.176368  torchscript       pythia-410m
# 11                   10.568300  torchscript        pythia1-4b
# 12                   10.856019  torchscript         tinyllama

# %%
# Define the new order of the columns
#new_order = ['label', 'Used memory (Energibridge) [B]','CPU usage (Energibridge) [%]', 'runtime', 'model']
new_order= list(median_resource_energi.columns[-2:]) + list(median_resource_energi.columns[:-2])
# Reorder the columns by indexing in the new order
median_resource_energi = median_resource_energi[new_order]
median_resource_energi
# Out:
#         runtime             model                         label  \
# 0          idle              idle                     idle_idle
# 1          onnx  codeparrot-small         onnx_codeparrot-small
# 2          onnx       pythia-410m              onnx_pythia-410m
# 3          onnx        pythia1-4b               onnx_pythia1-4b
# 4          onnx         tinyllama                onnx_tinyllama
# 5         torch  codeparrot-small        torch_codeparrot-small
# 6         torch       pythia-410m             torch_pythia-410m
# 7         torch        pythia1-4b              torch_pythia1-4b
# 8         torch         tinyllama               torch_tinyllama
# 9   torchscript  codeparrot-small  torchscript_codeparrot-small
# 10  torchscript       pythia-410m       torchscript_pythia-410m
# 11  torchscript        pythia1-4b        torchscript_pythia1-4b
# 12  torchscript         tinyllama         torchscript_tinyllama
#
#     avg_cpu_usage_config  avg_USED_MEMORY  avg_used_memory_pct_config
# 0               0.110316     2.495251e+09                    3.747977
# 1               3.991848     5.463905e+09                    8.207026
# 2               3.422415     6.463005e+09                    9.707720
# 3               3.379086     4.971254e+09                    7.467044
# 4               3.736836     5.061456e+09                    7.602531
# 5               2.443924     3.546823e+09                    5.327485
# 6               2.491036     3.558276e+09                    5.344688
# 7               2.993023     3.378596e+09                    5.074801
# 8               2.573948     3.432273e+09                    5.155426
# 9               0.158259     1.006792e+10                   15.122467
# 10              0.275700     1.010381e+10                   15.176368
# 11              0.394041     7.035944e+09                   10.568300
# 12              0.532322     7.227496e+09                   10.856019

# %%
median_resource_energi.to_csv(tables_dir+'median_resource_energi.csv', index=False)

# %%
median_resource_energi = median_resource_energi.drop(columns = ['label'])

# %%
filename = tables_dir + 'median_resource_energi.tex'
save_latex_table(median_resource_energi,filename)
# Out:
# \begin{tabular}{llrrr}
# \toprule
# runtime & model & avg cpu usage config & avg USED MEMORY & avg used memory pct config \\
# \midrule
# idle & idle & 0.110316 & 2495250711.893333 & 3.747977 \\
# onnx & codeparrot-small & 3.991848 & 5463905331.674562 & 8.207026 \\
# onnx & pythia-410m & 3.422415 & 6463005466.982005 & 9.707720 \\
# onnx & pythia1-4b & 3.379086 & 4971254377.737481 & 7.467044 \\
# onnx & tinyllama & 3.736836 & 5061455913.057756 & 7.602531 \\
# torch & codeparrot-small & 2.443924 & 3546822779.476091 & 5.327485 \\
# torch & pythia-410m & 2.491036 & 3558275711.731656 & 5.344688 \\
# torch & pythia1-4b & 2.993023 & 3378595890.881988 & 5.074801 \\
# torch & tinyllama & 2.573948 & 3432273235.903665 & 5.155426 \\
# torchscript & codeparrot-small & 0.158259 & 10067923251.200001 & 15.122467 \\
# torchscript & pythia-410m & 0.275700 & 10103808933.019485 & 15.176368 \\
# torchscript & pythia1-4b & 0.394041 & 7035944441.013645 & 10.568300 \\
# torchscript & tinyllama & 0.532322 & 7227496185.825603 & 10.856019 \\
# \bottomrule
# \end{tabular}

# %%
# # Convert DataFrame to LaTeX table
# latex_table = median_resource_energi.to_latex(index=False)

# # Define the filename
# filename = tables_dir + 'median_resource_energi.tex'

# # Open the file in write mode
# with open(filename, 'w') as file:
#     file.write(latex_table)


# # Print LaTeX table
# print(latex_table)

# %% [markdown]
# ## Resource utilization: Nvidia:

# %%
variables_to_plot = ['Energy (Nvidia-smi) [J]','Execution time (Nvidia-smi) [s]','GPU usage (Nvidia-smi) [%]',
                     'Used memory (Nvidia-smi) [%]','Used GPU memory (Nvidia-smi) [MiB]' ,'GPU temperature (Nvidia-smi) [°]']

variables_to_plot = ['energy','config_duration','avg_utilization_gpu_config','avg_utilization_memory_config','avg_memory_used_config' ,
                     'avg_power_draw_config','avg_temperature_gpu_config','avg_used_memory_pct_mib']


# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']
colors=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]
colors = colors[:num_models]

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

n=0
# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    grouped = nvidia_plot.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    #plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')

    plt.xlim([0,nvidia_plot[variable].max()*1.1])
    plt.grid(True)
    
    plt.tight_layout()  # Adjust layout to make room for labels
    
    plt.savefig(save_dir + "nvidia_"+variable)
    n+=1
plt.show()

# %%
nvidia_plot.columns
# Out:
# Index(['time', 'runtime', 'model', ' utilization.gpu [%]',
#        ' utilization.memory [%]', ' memory.total [MiB]', ' memory.used [MiB]',
#        ' power.draw [W]', ' power.max_limit [W]', ' temperature.gpu', 'label',
#        'used_memory_pct_mib', 'avg_utilization_gpu_config',
#        'avg_utilization_memory_config', 'avg_memory_used_config',
#        'avg_power_draw_config', 'avg_temperature_gpu_config',
#        'avg_used_memory_pct_mib', 'config_duration', 'energy', 'experiment'],
#       dtype='object')

# %%
resource_nvidia = nvidia_plot[['label','config_duration','avg_utilization_gpu_config','avg_utilization_memory_config','avg_memory_used_config' ,
                     'avg_power_draw_config','avg_temperature_gpu_config','avg_used_memory_pct_mib']]
#variables_to_plot = ['Energy (Nvidia-smi) [J]','Execution time (Nvidia-smi) [s]','GPU usage (Nvidia-smi) [%]','Used memory (Nvidia-smi) [%]','Used GPU memory (Nvidia-smi) [MiB]' ,'GPU temperature (Nvidia-smi) [°]']
#variables_to_plot = ['energy','config_duration','avg_utilization_gpu_config','avg_utilization_memory_config','avg_memory_used_config' ,
#                     'avg_power_draw_config','avg_temperature_gpu_config','avg_used_memory_pct_mib']
resource_nvidia
# Out:
#                           label  config_duration  avg_utilization_gpu_config  \
# 0              torch_pythia1-4b          193.242                   73.584680
# 1              torch_pythia1-4b          193.242                   73.584680
# 2              torch_pythia1-4b          193.242                   73.584680
# 3              torch_pythia1-4b          193.242                   73.584680
# 4              torch_pythia1-4b          193.242                   73.584680
# ...                         ...              ...                         ...
# 353362  torchscript_pythia-410m           99.293                    1.213198
# 353363  torchscript_pythia-410m           99.293                    1.213198
# 353364  torchscript_pythia-410m           99.293                    1.213198
# 353365  torchscript_pythia-410m           99.293                    1.213198
# 353366  torchscript_pythia-410m           99.293                    1.213198
#
#         avg_utilization_memory_config  avg_memory_used_config  \
# 0                           67.165711              6061.01876
# 1                           67.165711              6061.01876
# 2                           67.165711              6061.01876
# 3                           67.165711              6061.01876
# 4                           67.165711              6061.01876
# ...                               ...                     ...
# 353362                       0.327919             13602.55736
# 353363                       0.327919             13602.55736
# 353364                       0.327919             13602.55736
# 353365                       0.327919             13602.55736
# 353366                       0.327919             13602.55736
#
#         avg_power_draw_config  avg_temperature_gpu_config  \
# 0                  178.655961                   49.400730
# 1                  178.655961                   49.400730
# 2                  178.655961                   49.400730
# 3                  178.655961                   49.400730
# 4                  178.655961                   49.400730
# ...                       ...                         ...
# 353362              64.916294                   52.826396
# 353363              64.916294                   52.826396
# 353364              64.916294                   52.826396
# 353365              64.916294                   52.826396
# 353366              64.916294                   52.826396
#
#         avg_used_memory_pct_mib
# 0                     24.674397
# 1                     24.674397
# 2                     24.674397
# 3                     24.674397
# 4                     24.674397
# ...                         ...
# 353362                55.375987
# 353363                55.375987
# 353364                55.375987
# 353365                55.375987
# 353366                55.375987
#
# [268888 rows x 8 columns]

# %%
# Calculate mean values for each label
df = resource_nvidia
median_resource_nvidia = df.groupby('label').median()

# Optionally, you might want to reset the index if you need 'label' as a column
median_resource_nvidia.reset_index(inplace=True)

#median_energy_values = median_energy_values.drop(columns = ['experiment'])
median_resource_nvidia
# Out:
#                            label  config_duration  avg_utilization_gpu_config  \
# 0          onnx_codeparrot-small          193.248                   23.285492
# 1               onnx_pythia-410m          452.766                   30.861945
# 2                onnx_pythia1-4b          543.585                   63.327115
# 3                 onnx_tinyllama          408.373                   64.615539
# 4         torch_codeparrot-small           95.886                   27.906118
# 5              torch_pythia-410m          190.790                   36.117865
# 6               torch_pythia1-4b          193.226                   74.532744
# 7                torch_tinyllama          191.016                   66.558777
# 8   torchscript_codeparrot-small           96.258                    0.428122
# 9        torchscript_pythia-410m           99.224                    1.252033
# 10        torchscript_pythia1-4b          102.650                    2.800197
# 11         torchscript_tinyllama          107.679                    2.147940
#
#     avg_utilization_memory_config  avg_memory_used_config  \
# 0                        5.922396            14060.011458
# 1                        7.972371            14532.744818
# 2                       24.518106            17653.619505
# 3                       25.207245            16832.976408
# 4                       11.542887            13038.983122
# 5                       18.539112            13039.000000
# 6                       67.165711             6071.998438
# 7                       52.640148             6169.000000
# 8                        0.000000            18004.000000
# 9                        0.329615            18004.000000
# 10                       1.279528            13562.078740
# 11                       0.913858            13469.905028
#
#     avg_power_draw_config  avg_temperature_gpu_config  avg_used_memory_pct_mib
# 0               72.095349                   39.756477                57.238281
# 1               72.103135                   38.453184                59.162778
# 2              108.593907                   45.403583                71.867853
# 3              113.557743                   43.995546                68.527017
# 4               87.979239                   48.785939                53.081677
# 5               93.805735                   43.592827                53.081746
# 6              163.751597                   48.241164                24.719095
# 7              146.283056                   49.748152                25.113988
# 8               60.411466                   37.318325                73.294252
# 9               61.685935                   37.034518                73.294252
# 10              66.659293                   38.140748                55.211198
# 11              65.527664                   37.163873                54.835959

# %%
# Split the 'label' column into 'runtime' and 'model'
median_resource_nvidia[['runtime', 'model']] = median_resource_nvidia['label'].str.split('_', n=1, expand=True)
median_resource_nvidia
# Out:
#                            label  config_duration  avg_utilization_gpu_config  \
# 0          onnx_codeparrot-small          193.248                   23.285492
# 1               onnx_pythia-410m          452.766                   30.861945
# 2                onnx_pythia1-4b          543.585                   63.327115
# 3                 onnx_tinyllama          408.373                   64.615539
# 4         torch_codeparrot-small           95.886                   27.906118
# 5              torch_pythia-410m          190.790                   36.117865
# 6               torch_pythia1-4b          193.226                   74.532744
# 7                torch_tinyllama          191.016                   66.558777
# 8   torchscript_codeparrot-small           96.258                    0.428122
# 9        torchscript_pythia-410m           99.224                    1.252033
# 10        torchscript_pythia1-4b          102.650                    2.800197
# 11         torchscript_tinyllama          107.679                    2.147940
#
#     avg_utilization_memory_config  avg_memory_used_config  \
# 0                        5.922396            14060.011458
# 1                        7.972371            14532.744818
# 2                       24.518106            17653.619505
# 3                       25.207245            16832.976408
# 4                       11.542887            13038.983122
# 5                       18.539112            13039.000000
# 6                       67.165711             6071.998438
# 7                       52.640148             6169.000000
# 8                        0.000000            18004.000000
# 9                        0.329615            18004.000000
# 10                       1.279528            13562.078740
# 11                       0.913858            13469.905028
#
#     avg_power_draw_config  avg_temperature_gpu_config  \
# 0               72.095349                   39.756477
# 1               72.103135                   38.453184
# 2              108.593907                   45.403583
# 3              113.557743                   43.995546
# 4               87.979239                   48.785939
# 5               93.805735                   43.592827
# 6              163.751597                   48.241164
# 7              146.283056                   49.748152
# 8               60.411466                   37.318325
# 9               61.685935                   37.034518
# 10              66.659293                   38.140748
# 11              65.527664                   37.163873
#
#     avg_used_memory_pct_mib      runtime             model
# 0                 57.238281         onnx  codeparrot-small
# 1                 59.162778         onnx       pythia-410m
# 2                 71.867853         onnx        pythia1-4b
# 3                 68.527017         onnx         tinyllama
# 4                 53.081677        torch  codeparrot-small
# 5                 53.081746        torch       pythia-410m
# 6                 24.719095        torch        pythia1-4b
# 7                 25.113988        torch         tinyllama
# 8                 73.294252  torchscript  codeparrot-small
# 9                 73.294252  torchscript       pythia-410m
# 10                55.211198  torchscript        pythia1-4b
# 11                54.835959  torchscript         tinyllama

# %%
# Define the new order of the columns
#new_order = ['label', 'Used memory (Energibridge) [B]','CPU usage (Energibridge) [%]', 'runtime', 'model']
new_order= list(median_resource_nvidia.columns[-2:]) + list(median_resource_nvidia.columns[:-2])
# Reorder the columns by indexing in the new order
median_resource_nvidia = median_resource_nvidia[new_order]
median_resource_nvidia
# Out:
#         runtime             model                         label  \
# 0          onnx  codeparrot-small         onnx_codeparrot-small
# 1          onnx       pythia-410m              onnx_pythia-410m
# 2          onnx        pythia1-4b               onnx_pythia1-4b
# 3          onnx         tinyllama                onnx_tinyllama
# 4         torch  codeparrot-small        torch_codeparrot-small
# 5         torch       pythia-410m             torch_pythia-410m
# 6         torch        pythia1-4b              torch_pythia1-4b
# 7         torch         tinyllama               torch_tinyllama
# 8   torchscript  codeparrot-small  torchscript_codeparrot-small
# 9   torchscript       pythia-410m       torchscript_pythia-410m
# 10  torchscript        pythia1-4b        torchscript_pythia1-4b
# 11  torchscript         tinyllama         torchscript_tinyllama
#
#     config_duration  avg_utilization_gpu_config  \
# 0           193.248                   23.285492
# 1           452.766                   30.861945
# 2           543.585                   63.327115
# 3           408.373                   64.615539
# 4            95.886                   27.906118
# 5           190.790                   36.117865
# 6           193.226                   74.532744
# 7           191.016                   66.558777
# 8            96.258                    0.428122
# 9            99.224                    1.252033
# 10          102.650                    2.800197
# 11          107.679                    2.147940
#
#     avg_utilization_memory_config  avg_memory_used_config  \
# 0                        5.922396            14060.011458
# 1                        7.972371            14532.744818
# 2                       24.518106            17653.619505
# 3                       25.207245            16832.976408
# 4                       11.542887            13038.983122
# 5                       18.539112            13039.000000
# 6                       67.165711             6071.998438
# 7                       52.640148             6169.000000
# 8                        0.000000            18004.000000
# 9                        0.329615            18004.000000
# 10                       1.279528            13562.078740
# 11                       0.913858            13469.905028
#
#     avg_power_draw_config  avg_temperature_gpu_config  avg_used_memory_pct_mib
# 0               72.095349                   39.756477                57.238281
# 1               72.103135                   38.453184                59.162778
# 2              108.593907                   45.403583                71.867853
# 3              113.557743                   43.995546                68.527017
# 4               87.979239                   48.785939                53.081677
# 5               93.805735                   43.592827                53.081746
# 6              163.751597                   48.241164                24.719095
# 7              146.283056                   49.748152                25.113988
# 8               60.411466                   37.318325                73.294252
# 9               61.685935                   37.034518                73.294252
# 10              66.659293                   38.140748                55.211198
# 11              65.527664                   37.163873                54.835959

# %%
median_resource_nvidia.to_csv(tables_dir+'median_resource_nvidia.csv', index=False)

# %%
median_resource_nvidia = median_resource_nvidia.drop(columns = ['label'])

# %%
filename = tables_dir + 'median_resource_nvidia.tex'
save_latex_table(median_resource_nvidia,filename)
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# runtime & model & config duration & avg utilization gpu config & avg utilization memory config & avg memory used config & avg power draw config & avg temperature gpu config & avg used memory pct mib \\
# \midrule
# onnx & codeparrot-small & 193.248000 & 23.285492 & 5.922396 & 14060.011458 & 72.095349 & 39.756477 & 57.238281 \\
# onnx & pythia-410m & 452.766000 & 30.861945 & 7.972371 & 14532.744818 & 72.103135 & 38.453184 & 59.162778 \\
# onnx & pythia1-4b & 543.585000 & 63.327115 & 24.518106 & 17653.619505 & 108.593907 & 45.403583 & 71.867853 \\
# onnx & tinyllama & 408.373000 & 64.615539 & 25.207245 & 16832.976408 & 113.557743 & 43.995546 & 68.527017 \\
# torch & codeparrot-small & 95.886000 & 27.906118 & 11.542887 & 13038.983122 & 87.979239 & 48.785939 & 53.081677 \\
# torch & pythia-410m & 190.790000 & 36.117865 & 18.539112 & 13039.000000 & 93.805735 & 43.592827 & 53.081746 \\
# torch & pythia1-4b & 193.226000 & 74.532744 & 67.165711 & 6071.998438 & 163.751597 & 48.241164 & 24.719095 \\
# torch & tinyllama & 191.016000 & 66.558777 & 52.640148 & 6169.000000 & 146.283056 & 49.748152 & 25.113988 \\
# torchscript & codeparrot-small & 96.258000 & 0.428122 & 0.000000 & 18004.000000 & 60.411466 & 37.318325 & 73.294252 \\
# torchscript & pythia-410m & 99.224000 & 1.252033 & 0.329615 & 18004.000000 & 61.685935 & 37.034518 & 73.294252 \\
# torchscript & pythia1-4b & 102.650000 & 2.800197 & 1.279528 & 13562.078740 & 66.659293 & 38.140748 & 55.211198 \\
# torchscript & tinyllama & 107.679000 & 2.147940 & 0.913858 & 13469.905028 & 65.527664 & 37.163873 & 54.835959 \\
# \bottomrule
# \end{tabular}

# %%
# # Convert DataFrame to LaTeX table
# latex_table = median_resource_nvidia.to_latex(index=False)

# # Define the filename
# filename = tables_dir + 'median_resource_nvidia.tex'

# # Open the file in write mode
# with open(filename, 'w') as file:
#     file.write(latex_table)

# # Print LaTeX table
# print(latex_table)

# %% [markdown]
# ## Other: Wattmeter: 'Current [mA]','Power Factor [-]','Phase [°]' ,'Load [W]'

# %%
#variables_to_plot = ['Energy (Wattmeter) [J]','Current [mA]','Power Factor [-]','Phase [°]' ,'Load [W]']
variables_to_plot = ['energy_joules_config','avg_Current','avg_PowerFactor','avg_Phase' ,'avg_Load']

# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']
colors=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]
colors = colors[:num_models]

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    grouped = wattmeter_plot.groupby('label')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.xlim([0,wattmeter_plot[variable].max()*1.1])
    plt.grid(True)
    
    plt.tight_layout()  # Adjust layout to make room for labels
    plt.savefig(save_dir + "wattmeter_"+variable)

plt.show()

# %%
wattmeter_plot.columns
# Out:
# Index(['time', 'runtime', 'model', 'Current', 'PowerFactor', 'Phase', 'Energy',
#        'EnergyNR', 'Load', 'label', 'energy_joules', 'energyNR_joules',
#        'energy_joules_config', 'energyNR_joules_config', 'avg_Current',
#        'avg_PowerFactor', 'avg_Phase', 'avg_Load', 'experiment'],
#       dtype='object')

# %%
#variables_to_plot = ['Energy (Wattmeter) [J]','Current [mA]','Power Factor [-]','Phase [°]' ,'Load [W]']
#variables_to_plot = ['energy_joules_config','avg_Current','avg_PowerFactor','avg_Phase' ,'avg_Load']

resource_wattmeter = wattmeter_plot[['label','avg_Current','avg_PowerFactor','avg_Phase' ,'avg_Load']]
resource_wattmeter
# Out:
#                          label  avg_Current  avg_PowerFactor   avg_Phase  \
# 0             torch_pythia1-4b  1278.477341         0.931662  343.706465
# 1             torch_pythia1-4b  1278.477341         0.931662  343.706465
# 2             torch_pythia1-4b  1278.477341         0.931662  343.706465
# 3             torch_pythia1-4b  1278.477341         0.931662  343.706465
# 4             torch_pythia1-4b  1278.477341         0.931662  343.706465
# ...                        ...          ...              ...         ...
# 41259  torchscript_pythia-410m   680.798817         0.837515  325.907041
# 41260  torchscript_pythia-410m   680.798817         0.837515  325.907041
# 41261  torchscript_pythia-410m   680.798817         0.837515  325.907041
# 41262  torchscript_pythia-410m   680.798817         0.837515  325.907041
# 41263  torchscript_pythia-410m   680.798817         0.837515  325.907041
#
#          avg_Load
# 0      284.371601
# 1      284.371601
# 2      284.371601
# 3      284.371601
# 4      284.371601
# ...           ...
# 41259  138.136095
# 41260  138.136095
# 41261  138.136095
# 41262  138.136095
# 41263  138.136095
#
# [31803 rows x 5 columns]

# %%
# Calculate mean values for each label
df = resource_wattmeter
median_resource_wattmeter = df.groupby('label').median()

# Optionally, you might want to reset the index if you need 'label' as a column
median_resource_wattmeter.reset_index(inplace=True)

#median_energy_values = median_energy_values.drop(columns = ['experiment'])
median_resource_wattmeter
# Out:
#                            label  avg_Current  avg_PowerFactor   avg_Phase  \
# 0          onnx_codeparrot-small   812.274286         0.873060  333.119314
# 1               onnx_pythia-410m   823.982036         0.897690  333.860965
# 2                onnx_pythia1-4b  1051.168699         0.928211  340.940488
# 3                 onnx_tinyllama  1029.382530         0.939639  340.806472
# 4         torch_codeparrot-small   866.060606         0.877576  333.809756
# 5              torch_pythia-410m   884.294833         0.885805  334.731261
# 6               torch_pythia1-4b  1201.219033         0.919804  341.912281
# 7                torch_tinyllama  1114.073171         0.887058  339.565655
# 8   torchscript_codeparrot-small   648.981818         0.826909  324.776091
# 9        torchscript_pythia-410m   658.680473         0.826420  324.584320
# 10        torchscript_pythia1-4b   699.505917         0.800592  323.832308
# 11         torchscript_tinyllama   696.654593         0.809778  324.116352
#
#       avg_Load
# 0   170.890052
# 1   176.895210
# 2   235.359756
# 3   236.316265
# 4   180.750000
# 5   188.335866
# 6   265.794562
# 7   242.341463
# 8   127.730303
# 9   130.511834
# 10  136.582840
# 11  138.368715

# %%
# Split the 'label' column into 'runtime' and 'model'
median_resource_wattmeter[['runtime', 'model']] = median_resource_wattmeter['label'].str.split('_', n=1, expand=True)
median_resource_wattmeter
# Out:
#                            label  avg_Current  avg_PowerFactor   avg_Phase  \
# 0          onnx_codeparrot-small   812.274286         0.873060  333.119314
# 1               onnx_pythia-410m   823.982036         0.897690  333.860965
# 2                onnx_pythia1-4b  1051.168699         0.928211  340.940488
# 3                 onnx_tinyllama  1029.382530         0.939639  340.806472
# 4         torch_codeparrot-small   866.060606         0.877576  333.809756
# 5              torch_pythia-410m   884.294833         0.885805  334.731261
# 6               torch_pythia1-4b  1201.219033         0.919804  341.912281
# 7                torch_tinyllama  1114.073171         0.887058  339.565655
# 8   torchscript_codeparrot-small   648.981818         0.826909  324.776091
# 9        torchscript_pythia-410m   658.680473         0.826420  324.584320
# 10        torchscript_pythia1-4b   699.505917         0.800592  323.832308
# 11         torchscript_tinyllama   696.654593         0.809778  324.116352
#
#       avg_Load      runtime             model
# 0   170.890052         onnx  codeparrot-small
# 1   176.895210         onnx       pythia-410m
# 2   235.359756         onnx        pythia1-4b
# 3   236.316265         onnx         tinyllama
# 4   180.750000        torch  codeparrot-small
# 5   188.335866        torch       pythia-410m
# 6   265.794562        torch        pythia1-4b
# 7   242.341463        torch         tinyllama
# 8   127.730303  torchscript  codeparrot-small
# 9   130.511834  torchscript       pythia-410m
# 10  136.582840  torchscript        pythia1-4b
# 11  138.368715  torchscript         tinyllama

# %%
# Define the new order of the columns
#new_order = ['label', 'Used memory (Energibridge) [B]','CPU usage (Energibridge) [%]', 'runtime', 'model']
new_order= list(median_resource_wattmeter.columns[-2:]) + list(median_resource_wattmeter.columns[:-2])
# Reorder the columns by indexing in the new order
median_resource_wattmeter = median_resource_wattmeter[new_order]
median_resource_wattmeter
# Out:
#         runtime             model                         label  avg_Current  \
# 0          onnx  codeparrot-small         onnx_codeparrot-small   812.274286
# 1          onnx       pythia-410m              onnx_pythia-410m   823.982036
# 2          onnx        pythia1-4b               onnx_pythia1-4b  1051.168699
# 3          onnx         tinyllama                onnx_tinyllama  1029.382530
# 4         torch  codeparrot-small        torch_codeparrot-small   866.060606
# 5         torch       pythia-410m             torch_pythia-410m   884.294833
# 6         torch        pythia1-4b              torch_pythia1-4b  1201.219033
# 7         torch         tinyllama               torch_tinyllama  1114.073171
# 8   torchscript  codeparrot-small  torchscript_codeparrot-small   648.981818
# 9   torchscript       pythia-410m       torchscript_pythia-410m   658.680473
# 10  torchscript        pythia1-4b        torchscript_pythia1-4b   699.505917
# 11  torchscript         tinyllama         torchscript_tinyllama   696.654593
#
#     avg_PowerFactor   avg_Phase    avg_Load
# 0          0.873060  333.119314  170.890052
# 1          0.897690  333.860965  176.895210
# 2          0.928211  340.940488  235.359756
# 3          0.939639  340.806472  236.316265
# 4          0.877576  333.809756  180.750000
# 5          0.885805  334.731261  188.335866
# 6          0.919804  341.912281  265.794562
# 7          0.887058  339.565655  242.341463
# 8          0.826909  324.776091  127.730303
# 9          0.826420  324.584320  130.511834
# 10         0.800592  323.832308  136.582840
# 11         0.809778  324.116352  138.368715

# %%
median_resource_wattmeter.to_csv(tables_dir+'median_resource_wattmeter.csv', index=False)

# %%
median_resource_wattmeter = median_resource_wattmeter.drop(columns = ['label'])

# %%
filename = tables_dir + 'median_resource_wattmeter.tex'
save_latex_table(median_resource_wattmeter,filename)
# Out:
# \begin{tabular}{llrrrr}
# \toprule
# runtime & model & avg Current & avg PowerFactor & avg Phase & avg Load \\
# \midrule
# onnx & codeparrot-small & 812.274286 & 0.873060 & 333.119314 & 170.890052 \\
# onnx & pythia-410m & 823.982036 & 0.897690 & 333.860965 & 176.895210 \\
# onnx & pythia1-4b & 1051.168699 & 0.928211 & 340.940488 & 235.359756 \\
# onnx & tinyllama & 1029.382530 & 0.939639 & 340.806472 & 236.316265 \\
# torch & codeparrot-small & 866.060606 & 0.877576 & 333.809756 & 180.750000 \\
# torch & pythia-410m & 884.294833 & 0.885805 & 334.731261 & 188.335866 \\
# torch & pythia1-4b & 1201.219033 & 0.919804 & 341.912281 & 265.794562 \\
# torch & tinyllama & 1114.073171 & 0.887058 & 339.565655 & 242.341463 \\
# torchscript & codeparrot-small & 648.981818 & 0.826909 & 324.776091 & 127.730303 \\
# torchscript & pythia-410m & 658.680473 & 0.826420 & 324.584320 & 130.511834 \\
# torchscript & pythia1-4b & 699.505917 & 0.800592 & 323.832308 & 136.582840 \\
# torchscript & tinyllama & 696.654593 & 0.809778 & 324.116352 & 138.368715 \\
# \bottomrule
# \end{tabular}

# %%
# # Convert DataFrame to LaTeX table
# latex_table = median_resource_wattmeter.to_latex(index=False)


# # Define the filename
# filename = tables_dir + 'median_resource_wattmeter.tex'

# # Open the file in write mode
# with open(filename, 'w') as file:
#     file.write(latex_table)


# # Print LaTeX table
# print(latex_table)

# %% [markdown]
# ## Duration

# %%
# Path where the CSV files are stored
path = "D:/GAISSA/energy-repo/last_repo/june_gpu/"  # Adjust this path to your CSV files location
all_files = glob.glob(path + "/results_*/processed/time_marks.csv")
#all_files=all_files[:4]
all_files
# Out:
# ['D:/GAISSA/energy-repo/last_repo/june_gpu\\results_1\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_10\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_2\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_3\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_4\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_5\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_6\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_7\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_8\\processed\\time_marks.csv',
#  'D:/GAISSA/energy-repo/last_repo/june_gpu\\results_9\\processed\\time_marks.csv']

# %%
result_numbers = []

li = []
for my_file in all_files:
    # The regex pattern to find "results_" followed by one or more digits
    df = pd.read_csv(my_file, index_col=None, header=0)
    
    match = re.search(r'results_(\d+)', my_file)
    if match:
        # Append the found number to the list
        result_numbers.append(int(match.group(1)))

    df['experiment'] = result_numbers[-1]
    li.append(df)

print(result_numbers)
# Combine all data into one DataFrame
time_df = pd.concat(li, axis=0, ignore_index=True)
time_df
# Out:
# [1, 10, 2, 3, 4, 5, 6, 7, 8, 9]
#                            time      runtime        model       engine  \
# 0    2024-06-08 21:41:59.000000            -         IDLE          NaN
# 1    2024-06-08 21:47:00.000000        torch        START          NaN
# 2    2024-06-08 21:47:00.919120          NaN          NaN        torch
# 3    2024-06-08 21:47:02.775654          NaN          NaN        torch
# 4    2024-06-08 21:50:13.000000        torch   pythia1-4b          NaN
# ..                          ...          ...          ...          ...
# 475  2024-06-11 19:25:43.000000  torchscript  pythia-410m          NaN
# 476  2024-06-11 19:25:44.714033          NaN          NaN  torchscript
# 477  2024-06-11 19:25:52.449075          NaN          NaN  torchscript
# 478  2024-06-11 19:27:33.000000  torchscript         phi2          NaN
# 479  2024-06-11 19:27:34.000000            -       FINISH          NaN
#
#      model_name  start_end        file                    label    duration  \
# 0           NaN        NaN      runall                     idle         NaN
# 1           NaN        NaN      runall              torch_START  301.000000
# 2    pythia1-4b        1.0  load_times         torch_pythia1-4b    0.919120
# 3    pythia1-4b        0.0  load_times         torch_pythia1-4b    1.856534
# 4           NaN        NaN      runall         torch_pythia1-4b  190.224346
# ..          ...        ...         ...                      ...         ...
# 475         NaN        NaN      runall  torchscript_pythia-410m   96.801698
# 476        phi2        1.0  load_times         torchscript_phi2    1.714033
# 477        phi2        0.0  load_times         torchscript_phi2    7.735042
# 478         NaN        NaN      runall         torchscript_phi2  100.550925
# 479         NaN        NaN      runall                   finish    1.000000
#
#                             label_time  experiment
# 0                     -_IDLE_inference           1
# 1                torch_START_inference           1
# 2                                  NaN           1
# 3                torch_pythia1-4b_load           1
# 4           torch_pythia1-4b_inference           1
# ..                                 ...         ...
# 475  torchscript_pythia-410m_inference           9
# 476                                NaN           9
# 477              torchscript_phi2_load           9
# 478         torchscript_phi2_inference           9
# 479                 -_FINISH_inference           9
#
# [480 rows x 11 columns]

# %%
# ## add number of experiment

# # List to hold data from each file
# li = []

# # Read each file and append to list
# n=1
# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     df['experiment'] = n
#     li.append(df)
#     n+=1
    

# # Combine all data into one DataFrame
# combined_df = pd.concat(li, axis=0, ignore_index=True)
# combined_df

# %%
time_df.columns
# Out:
# Index(['time', 'runtime', 'model', 'engine', 'model_name', 'start_end', 'file',
#        'label', 'duration', 'label_time', 'experiment'],
#       dtype='object')

# %%
variables_to_plot = ['duration', ]

# %%
time_df[time_df['label_time'].str.startswith('torch_', na=False) & time_df['label_time'].str.endswith('inference', na=False) ]
# Out:
#                            time runtime             model engine model_name  \
# 1    2024-06-08 21:47:00.000000   torch             START    NaN        NaN
# 4    2024-06-08 21:50:13.000000   torch        pythia1-4b    NaN        NaN
# 7    2024-06-08 21:53:25.000000   torch         tinyllama    NaN        NaN
# 10   2024-06-08 21:57:41.000000   torch              phi2    NaN        NaN
# 13   2024-06-08 21:59:17.000000   torch  codeparrot-small    NaN        NaN
# 16   2024-06-08 22:02:28.000000   torch       pythia-410m    NaN        NaN
# 49   2024-06-23 16:51:54.000000   torch             START    NaN        NaN
# 52   2024-06-23 16:55:08.000000   torch        pythia1-4b    NaN        NaN
# 55   2024-06-23 16:58:20.000000   torch         tinyllama    NaN        NaN
# 58   2024-06-23 16:59:56.000000   torch  codeparrot-small    NaN        NaN
# 61   2024-06-23 17:03:08.000000   torch       pythia-410m    NaN        NaN
# 64   2024-06-23 17:07:23.000000   torch              phi2    NaN        NaN
# 97   2024-06-09 00:03:23.000000   torch             START    NaN        NaN
# 100  2024-06-09 00:06:36.000000   torch        pythia1-4b    NaN        NaN
# 103  2024-06-09 00:09:48.000000   torch         tinyllama    NaN        NaN
# 106  2024-06-09 00:14:06.000000   torch              phi2    NaN        NaN
# 109  2024-06-09 00:15:43.000000   torch  codeparrot-small    NaN        NaN
# 112  2024-06-09 00:18:54.000000   torch       pythia-410m    NaN        NaN
# 145  2024-06-09 01:09:11.000000   torch             START    NaN        NaN
# 148  2024-06-09 01:12:24.000000   torch        pythia1-4b    NaN        NaN
# 151  2024-06-09 01:15:36.000000   torch         tinyllama    NaN        NaN
# 154  2024-06-09 01:19:53.000000   torch              phi2    NaN        NaN
# 157  2024-06-09 01:21:30.000000   torch  codeparrot-small    NaN        NaN
# 160  2024-06-09 01:24:41.000000   torch       pythia-410m    NaN        NaN
# 193  2024-06-09 02:14:44.000000   torch             START    NaN        NaN
# 196  2024-06-09 02:17:57.000000   torch        pythia1-4b    NaN        NaN
# 199  2024-06-09 02:21:09.000000   torch         tinyllama    NaN        NaN
# 202  2024-06-09 02:25:26.000000   torch              phi2    NaN        NaN
# 205  2024-06-09 02:27:02.000000   torch  codeparrot-small    NaN        NaN
# 208  2024-06-09 02:30:13.000000   torch       pythia-410m    NaN        NaN
# 241  2024-06-09 03:17:05.000000   torch             START    NaN        NaN
# 244  2024-06-09 03:20:18.000000   torch        pythia1-4b    NaN        NaN
# 247  2024-06-09 03:23:29.000000   torch         tinyllama    NaN        NaN
# 250  2024-06-09 03:27:46.000000   torch              phi2    NaN        NaN
# 253  2024-06-09 03:29:22.000000   torch  codeparrot-small    NaN        NaN
# 256  2024-06-09 03:32:33.000000   torch       pythia-410m    NaN        NaN
# 289  2024-06-09 04:20:14.000000   torch             START    NaN        NaN
# 292  2024-06-09 04:23:27.000000   torch        pythia1-4b    NaN        NaN
# 295  2024-06-09 04:26:39.000000   torch         tinyllama    NaN        NaN
# 298  2024-06-09 04:30:55.000000   torch              phi2    NaN        NaN
# 301  2024-06-09 04:32:32.000000   torch  codeparrot-small    NaN        NaN
# 304  2024-06-09 04:35:43.000000   torch       pythia-410m    NaN        NaN
# 337  2024-06-09 05:23:26.000000   torch             START    NaN        NaN
# 340  2024-06-09 05:26:40.000000   torch        pythia1-4b    NaN        NaN
# 343  2024-06-09 05:29:51.000000   torch         tinyllama    NaN        NaN
# 346  2024-06-09 05:34:07.000000   torch              phi2    NaN        NaN
# 349  2024-06-09 05:35:43.000000   torch  codeparrot-small    NaN        NaN
# 352  2024-06-09 05:38:54.000000   torch       pythia-410m    NaN        NaN
# 385  2024-06-11 17:23:49.000000   torch             START    NaN        NaN
# 388  2024-06-11 17:27:02.000000   torch        pythia1-4b    NaN        NaN
# 391  2024-06-11 17:30:14.000000   torch         tinyllama    NaN        NaN
# 394  2024-06-11 17:31:51.000000   torch  codeparrot-small    NaN        NaN
# 397  2024-06-11 17:35:02.000000   torch       pythia-410m    NaN        NaN
# 400  2024-06-11 17:39:19.000000   torch              phi2    NaN        NaN
# 433  2024-06-11 18:27:06.000000   torch             START    NaN        NaN
# 436  2024-06-11 18:30:18.000000   torch        pythia1-4b    NaN        NaN
# 439  2024-06-11 18:33:30.000000   torch         tinyllama    NaN        NaN
# 442  2024-06-11 18:35:06.000000   torch  codeparrot-small    NaN        NaN
# 445  2024-06-11 18:38:16.000000   torch       pythia-410m    NaN        NaN
# 448  2024-06-11 18:42:32.000000   torch              phi2    NaN        NaN
#
#      start_end    file                   label    duration  \
# 1          NaN  runall             torch_START  301.000000
# 4          NaN  runall        torch_pythia1-4b  190.224346
# 7          NaN  runall         torch_tinyllama  188.823235
# 10         NaN  runall              torch_phi2  251.210585
# 13         NaN  runall  torch_codeparrot-small   94.157740
# 16         NaN  runall       torch_pythia-410m  189.240295
# 49         NaN  runall             torch_START  301.000000
# 52         NaN  runall        torch_pythia1-4b  191.272793
# 55         NaN  runall         torch_tinyllama  189.492861
# 58         NaN  runall  torch_codeparrot-small   94.716792
# 61         NaN  runall       torch_pythia-410m  189.988140
# 64         NaN  runall              torch_phi2  250.592033
# 97         NaN  runall             torch_START  301.000000
# 100        NaN  runall        torch_pythia1-4b  190.333565
# 103        NaN  runall         torch_tinyllama  188.973348
# 106        NaN  runall              torch_phi2  253.328242
# 109        NaN  runall  torch_codeparrot-small   95.105898
# 112        NaN  runall       torch_pythia-410m  189.375270
# 145        NaN  runall             torch_START  301.000000
# 148        NaN  runall        torch_pythia1-4b  190.221426
# 151        NaN  runall         torch_tinyllama  188.812102
# 154        NaN  runall              torch_phi2  252.473396
# 157        NaN  runall  torch_codeparrot-small   94.733058
# 160        NaN  runall       torch_pythia-410m  189.217078
# 193        NaN  runall             torch_START  300.000000
# 196        NaN  runall        torch_pythia1-4b  189.708705
# 199        NaN  runall         torch_tinyllama  188.824329
# 202        NaN  runall              torch_phi2  252.255236
# 205        NaN  runall  torch_codeparrot-small   94.128561
# 208        NaN  runall       torch_pythia-410m  189.274824
# 241        NaN  runall             torch_START  301.000000
# 244        NaN  runall        torch_pythia1-4b  190.340252
# 247        NaN  runall         torch_tinyllama  188.411359
# 250        NaN  runall              torch_phi2  252.464138
# 253        NaN  runall  torch_codeparrot-small   93.886774
# 256        NaN  runall       torch_pythia-410m  189.167949
# 289        NaN  runall             torch_START  301.000000
# 292        NaN  runall        torch_pythia1-4b  190.263022
# 295        NaN  runall         torch_tinyllama  188.965821
# 298        NaN  runall              torch_phi2  251.449030
# 301        NaN  runall  torch_codeparrot-small   94.893645
# 304        NaN  runall       torch_pythia-410m  189.196356
# 337        NaN  runall             torch_START  300.000000
# 340        NaN  runall        torch_pythia1-4b  190.872293
# 343        NaN  runall         torch_tinyllama  188.553905
# 346        NaN  runall              torch_phi2  250.919591
# 349        NaN  runall  torch_codeparrot-small   93.907202
# 352        NaN  runall       torch_pythia-410m  189.067788
# 385        NaN  runall             torch_START  301.000000
# 388        NaN  runall        torch_pythia1-4b  190.029049
# 391        NaN  runall         torch_tinyllama  188.697151
# 394        NaN  runall  torch_codeparrot-small   95.327082
# 397        NaN  runall       torch_pythia-410m  189.564502
# 400        NaN  runall              torch_phi2  252.635954
# 433        NaN  runall             torch_START  301.000000
# 436        NaN  runall        torch_pythia1-4b  189.646066
# 439        NaN  runall         torch_tinyllama  188.644582
# 442        NaN  runall  torch_codeparrot-small   94.652308
# 445        NaN  runall       torch_pythia-410m  188.724857
# 448        NaN  runall              torch_phi2  251.136543
#
#                            label_time  experiment
# 1               torch_START_inference           1
# 4          torch_pythia1-4b_inference           1
# 7           torch_tinyllama_inference           1
# 10               torch_phi2_inference           1
# 13   torch_codeparrot-small_inference           1
# 16        torch_pythia-410m_inference           1
# 49              torch_START_inference          10
# 52         torch_pythia1-4b_inference          10
# 55          torch_tinyllama_inference          10
# 58   torch_codeparrot-small_inference          10
# 61        torch_pythia-410m_inference          10
# 64               torch_phi2_inference          10
# 97              torch_START_inference           2
# 100        torch_pythia1-4b_inference           2
# 103         torch_tinyllama_inference           2
# 106              torch_phi2_inference           2
# 109  torch_codeparrot-small_inference           2
# 112       torch_pythia-410m_inference           2
# 145             torch_START_inference           3
# 148        torch_pythia1-4b_inference           3
# 151         torch_tinyllama_inference           3
# 154              torch_phi2_inference           3
# 157  torch_codeparrot-small_inference           3
# 160       torch_pythia-410m_inference           3
# 193             torch_START_inference           4
# 196        torch_pythia1-4b_inference           4
# 199         torch_tinyllama_inference           4
# 202              torch_phi2_inference           4
# 205  torch_codeparrot-small_inference           4
# 208       torch_pythia-410m_inference           4
# 241             torch_START_inference           5
# 244        torch_pythia1-4b_inference           5
# 247         torch_tinyllama_inference           5
# 250              torch_phi2_inference           5
# 253  torch_codeparrot-small_inference           5
# 256       torch_pythia-410m_inference           5
# 289             torch_START_inference           6
# 292        torch_pythia1-4b_inference           6
# 295         torch_tinyllama_inference           6
# 298              torch_phi2_inference           6
# 301  torch_codeparrot-small_inference           6
# 304       torch_pythia-410m_inference           6
# 337             torch_START_inference           7
# 340        torch_pythia1-4b_inference           7
# 343         torch_tinyllama_inference           7
# 346              torch_phi2_inference           7
# 349  torch_codeparrot-small_inference           7
# 352       torch_pythia-410m_inference           7
# 385             torch_START_inference           8
# 388        torch_pythia1-4b_inference           8
# 391         torch_tinyllama_inference           8
# 394  torch_codeparrot-small_inference           8
# 397       torch_pythia-410m_inference           8
# 400              torch_phi2_inference           8
# 433             torch_START_inference           9
# 436        torch_pythia1-4b_inference           9
# 439         torch_tinyllama_inference           9
# 442  torch_codeparrot-small_inference           9
# 445       torch_pythia-410m_inference           9
# 448              torch_phi2_inference           9

# %%
combined_df = time_df
# Assuming combined_df is already created and contains the data

# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)


# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(20, 6))
    # Setting vert=False makes the box plots horizontal
    plot_df = combined_df[combined_df['label_time'].str.startswith('torch_', na=False)]
    plot_df = combined_df[combined_df['label_time'].str.startswith('torch_', na=False) & combined_df['label_time'].str.endswith('inference', na=False) ]
    plot_df = combined_df[ combined_df['label_time'].str.endswith('inference', na=False) ]
    
    plot_df.boxplot(column=variable, by='label_time', grid=False, vert=False) #df[df['A'].notna()]
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.ylabel('Label')
    plt.yticks(rotation=0)  # Rotate label ticks if necessary
    plt.tight_layout()  # Adjust layout to make room for labels
    #plt.xlim([0,20])
    #plt.savefig(path+"duration_runall")
plt.show()

# %%
# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    plot_df = combined_df[ combined_df['label_time'].str.endswith('inference', na=False) ]
    
    grouped = plot_df.groupby('label_time')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.tight_layout()  # Adjust layout to make room for labels

plt.show()

# %%
condition = time_df['label'].str.endswith('phi2')
#remove_condition_rows( condition, energi_df)
#energi_df = energi_df[~condition]
time_plot = remove_condition_rows( condition, time_df)
time_plot
# Out:
#                            time      runtime             model       engine  \
# 0    2024-06-08 21:41:59.000000            -              IDLE          NaN
# 1    2024-06-08 21:47:00.000000        torch             START          NaN
# 2    2024-06-08 21:47:00.919120          NaN               NaN        torch
# 3    2024-06-08 21:47:02.775654          NaN               NaN        torch
# 4    2024-06-08 21:50:13.000000        torch        pythia1-4b          NaN
# ..                          ...          ...               ...          ...
# 472  2024-06-11 19:24:04.000000  torchscript  codeparrot-small          NaN
# 473  2024-06-11 19:24:05.129227          NaN               NaN  torchscript
# 474  2024-06-11 19:24:06.198302          NaN               NaN  torchscript
# 475  2024-06-11 19:25:43.000000  torchscript       pythia-410m          NaN
# 479  2024-06-11 19:27:34.000000            -            FINISH          NaN
#
#       model_name  start_end        file                         label  \
# 0            NaN        NaN      runall                          idle
# 1            NaN        NaN      runall                   torch_START
# 2     pythia1-4b        1.0  load_times              torch_pythia1-4b
# 3     pythia1-4b        0.0  load_times              torch_pythia1-4b
# 4            NaN        NaN      runall              torch_pythia1-4b
# ..           ...        ...         ...                           ...
# 472          NaN        NaN      runall  torchscript_codeparrot-small
# 473  pythia-410m        1.0  load_times       torchscript_pythia-410m
# 474  pythia-410m        0.0  load_times       torchscript_pythia-410m
# 475          NaN        NaN      runall       torchscript_pythia-410m
# 479          NaN        NaN      runall                        finish
#
#        duration                              label_time  experiment
# 0           NaN                        -_IDLE_inference           1
# 1    301.000000                   torch_START_inference           1
# 2      0.919120                                     NaN           1
# 3      1.856534                   torch_pythia1-4b_load           1
# 4    190.224346              torch_pythia1-4b_inference           1
# ..          ...                                     ...         ...
# 472   94.919234  torchscript_codeparrot-small_inference           9
# 473    1.129227                                     NaN           9
# 474    1.069075            torchscript_pythia-410m_load           9
# 475   96.801698       torchscript_pythia-410m_inference           9
# 479    1.000000                      -_FINISH_inference           9
#
# [410 rows x 11 columns]

# %%
condition = time_plot['label'].str.startswith('-')
#remove_condition_rows( condition, energi_df)
#energi_df = energi_df[~condition]
time_plot = remove_condition_rows( condition, time_plot)

condition = time_plot['label'].str.startswith('idle')
time_plot = remove_condition_rows( condition, time_plot)

condition = time_plot['label'].str.startswith('finish')
time_plot = remove_condition_rows( condition, time_plot)

condition = time_plot['label'].str.endswith('START')
time_plot = remove_condition_rows( condition, time_plot)

time_plot
# Out:
#                            time      runtime             model       engine  \
# 2    2024-06-08 21:47:00.919120          NaN               NaN        torch
# 3    2024-06-08 21:47:02.775654          NaN               NaN        torch
# 4    2024-06-08 21:50:13.000000        torch        pythia1-4b          NaN
# 5    2024-06-08 21:50:14.825155          NaN               NaN        torch
# 6    2024-06-08 21:50:16.176765          NaN               NaN        torch
# ..                          ...          ...               ...          ...
# 471  2024-06-11 19:22:29.080766          NaN               NaN  torchscript
# 472  2024-06-11 19:24:04.000000  torchscript  codeparrot-small          NaN
# 473  2024-06-11 19:24:05.129227          NaN               NaN  torchscript
# 474  2024-06-11 19:24:06.198302          NaN               NaN  torchscript
# 475  2024-06-11 19:25:43.000000  torchscript       pythia-410m          NaN
#
#            model_name  start_end        file                         label  \
# 2          pythia1-4b        1.0  load_times              torch_pythia1-4b
# 3          pythia1-4b        0.0  load_times              torch_pythia1-4b
# 4                 NaN        NaN      runall              torch_pythia1-4b
# 5           tinyllama        1.0  load_times               torch_tinyllama
# 6           tinyllama        0.0  load_times               torch_tinyllama
# ..                ...        ...         ...                           ...
# 471  codeparrot-small        0.0  load_times  torchscript_codeparrot-small
# 472               NaN        NaN      runall  torchscript_codeparrot-small
# 473       pythia-410m        1.0  load_times       torchscript_pythia-410m
# 474       pythia-410m        0.0  load_times       torchscript_pythia-410m
# 475               NaN        NaN      runall       torchscript_pythia-410m
#
#        duration                              label_time  experiment
# 2      0.919120                                     NaN           1
# 3      1.856534                   torch_pythia1-4b_load           1
# 4    190.224346              torch_pythia1-4b_inference           1
# 5      1.825155                                     NaN           1
# 6      1.351610                    torch_tinyllama_load           1
# ..          ...                                     ...         ...
# 471    0.405349       torchscript_codeparrot-small_load           9
# 472   94.919234  torchscript_codeparrot-small_inference           9
# 473    1.129227                                     NaN           9
# 474    1.069075            torchscript_pythia-410m_load           9
# 475   96.801698       torchscript_pythia-410m_inference           9
#
# [360 rows x 11 columns]

# %%
combined_df = time_plot
# Define some colors for the boxes
colors = ['blue', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'orange', 'yellow', 'cyan']
colors=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]
colors = colors[:num_models]

# Make the color list cyclic in case there are more groups than colors
color_cycle = itertools.cycle(colors)

# Generate box plots
for variable in variables_to_plot:
    plt.figure(figsize=(10, 6))
    
    # Group data by 'label'
    plot_df = combined_df[ combined_df['label_time'].str.endswith('inference', na=False) ]
    
    grouped = plot_df.groupby('label_time')
    
    # We need to know the number of groups
    num_groups = len(grouped)
    
    # Creating a box for each group
    for i, (name, group) in enumerate(grouped):
        # Plot only the part of the data for this group
        # `positions` gives the position of the box in the plot
        plt.boxplot(group[variable].dropna(), positions=[i], widths=0.6, vert=False, patch_artist=True,
                    boxprops=dict(facecolor=next(color_cycle)))  # Use cyclic color

    # Customizing plot
    plt.title(f'Box Plot of {variable} by Label')
    plt.xlabel(variable)
    plt.yticks(np.arange(num_groups), grouped.groups.keys())  # Set y-ticks to group names
    plt.ylabel('Label')
    plt.xlim([0,combined_df['duration'].max()*1.1])
    plt.grid(True)
    
    plt.tight_layout()  # Adjust layout to make room for labels
    plt.savefig(save_dir+ "duration_marks.png")

plt.show()
